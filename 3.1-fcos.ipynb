# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Tue Feb 13 22:54:07 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:5E:00.0 Off |                    0 |
# | N/A   46C    P0              27W /  70W |   1255MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     20010      C   /work/van-speech-nlp/jenv/bin/python       1250MiB |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Forestfire2024-1 to coco-mmdetection:: 100%|██████████| 151008/151008 [00:06<00:00, 24819.90it/s]
# Extracting Dataset Version Zip to Forestfire2024-1 in coco-mmdetection:: 100%|██████████| 681/681 [00:05<00:00, 115.03it/s]
# dataset classes: ['Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris']
# dataset size: 471
# dataset classes: ['Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris']
# dataset size: 67

# %%
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/fcos/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco.py"

CUSTOM_CONFIG = f"""
_base_ = 'fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco.py'



# ========================Frequently modified parameters======================
# -----data related-----
# model = dict(
#     roi_head=dict(
#         bbox_head=dict(num_classes=4),
# ))

dataset_type = 'COCODataset'
max_epochs = 200
classes =  ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris') 

data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/'  # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris')  
num_classes = 4  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = 16  # Batch size per GPU during training
train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = 1000  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image

# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=10,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    samples_per_gpu=16,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/annotation_coco.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 32
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----model related-----
# The scaling factor that controls the depth of the network structure
deepen_factor = 0.67
# The scaling factor that controls the width of the network structure
widen_factor = 0.75
# Strides of multi-scale prior box
strides = [8, 16, 32]

norm_cfg = dict(type='BN')  # Normalization config

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)

"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
# !python tools/train.py configs/ssd/costom_ssd512.py --resume | tee ../OUT_ssd.txt
# !python tools/train.py configs/fcos/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco.py --resume | tee ../OUT_fcos.txt
# Out:
# 02/13 03:37:23 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1589419120
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1589419120
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/13 03:37:23 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=32,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     samples_per_gpu=16,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/annotation_coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'),
#     workers_per_gpu=2)
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/'
# dataset_type = 'COCODataset'
# deepen_factor = 0.67
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 1000
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=64,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_64x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     bbox_head=dict(
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='IoULoss'),
#         loss_centerness=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         loss_cls=dict(
#             alpha=0.25,
#             gamma=2.0,
#             loss_weight=1.0,
#             type='FocalLoss',
#             use_sigmoid=True),
#         num_classes=4,
#         stacked_convs=4,
#         strides=[
#             8,
#             16,
#             32,
#             64,
#             128,
#         ],
#         type='FCOSHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         add_extra_convs='on_output',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         relu_before_extra_convs=True,
#         start_level=1,
#         type='FPN'),
#     test_cfg=dict(
#         max_per_img=100,
#         min_bbox_size=0,
#         nms=dict(iou_threshold=0.5, type='nms'),
#         nms_pre=1000,
#         score_thr=0.05),
#     type='FCOS')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# norm_cfg = dict(type='BN')
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=35, norm_type=2),
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0001),
#     paramwise_cfg=dict(bias_decay_mult=0.0, bias_lr_mult=2.0),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=500,
#         factor=0.3333333333333333,
#         type='ConstantLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=24,
#         gamma=0.1,
#         milestones=[
#             16,
#             22,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = True
# save_checkpoint_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_batch_size_per_gpu = 16
# train_cfg = dict(max_epochs=1000, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 keep_ratio=True,
#                 scales=[
#                     (
#                         1333,
#                         640,
#                     ),
#                     (
#                         1333,
#                         800,
#                     ),
#                 ],
#                 type='RandomChoiceResize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 4
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         keep_ratio=True,
#         scales=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 800,
#             ),
#         ],
#         type='RandomChoiceResize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 32
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# widen_factor = 0.75
# work_dir = './work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco'
#
# 02/13 03:37:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/13 03:37:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.0.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.1.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.2.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer2.3.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.0.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.1.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.2.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.3.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.4.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.5.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.6.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.6.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.6.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.7.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.7.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.7.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.8.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.8.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.8.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.9.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.9.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.9.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.10.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.10.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.10.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.11.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.11.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.11.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.12.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.12.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.12.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.13.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.13.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.13.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.14.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.14.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.14.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.15.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.15.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.15.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.16.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.16.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.16.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.17.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.17.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.17.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.18.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.18.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.18.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.19.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.19.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.19.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.20.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.20.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.20.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.21.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.21.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.21.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.22.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.22.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer3.22.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.0.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.0.downsample.1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.1.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn1.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn2.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- backbone.layer4.2.bn3.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.0.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.0.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.1.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.1.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.2.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.lateral_convs.2.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.0.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.0.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.1.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.1.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.2.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.2.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.3.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.3.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.4.conv.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- neck.fpn_convs.4.conv.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.3.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.3.gn.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_cls.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_cls.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_reg.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_reg.bias:weight_decay=0.0
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_centerness.bias:lr=0.02
# 02/13 03:37:29 - mmengine - INFO - paramwise_options -- bbox_head.conv_centerness.bias:weight_decay=0.0
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/13 03:37:29 - mmengine - INFO - load model from: open-mmlab://resnext101_64x4d
# 02/13 03:37:29 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_64x4d
# 02/13 03:37:30 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/epoch_197.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/epoch_197.pth
# 02/13 03:37:31 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/epoch_197.pth
# 02/13 03:37:31 - mmengine - INFO - resumed epoch: 197, iter: 46492
# 02/13 03:37:31 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/13 03:37:31 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/13 03:37:31 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco.
# /work/van-speech-nlp/jenv/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 02/13 03:38:32 - mmengine - INFO - Epoch(train)  [198][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 16:24:32  time: 1.2239  data_time: 0.0122  memory: 13962  grad_norm: 3.5550  loss: 1.0608  loss_cls: 0.1169  loss_bbox: 0.3574  loss_centerness: 0.5866
# 02/13 03:39:18 - mmengine - INFO - Epoch(train)  [198][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 8:13:44  time: 0.9136  data_time: 0.0056  memory: 5979  grad_norm: 3.5563  loss: 1.0520  loss_cls: 0.1219  loss_bbox: 0.3440  loss_centerness: 0.5862
# 02/13 03:40:03 - mmengine - INFO - Epoch(train)  [198][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 5:21:42  time: 0.9060  data_time: 0.0053  memory: 6008  grad_norm: 3.5949  loss: 1.0607  loss_cls: 0.1199  loss_bbox: 0.3545  loss_centerness: 0.5863
# 02/13 03:40:49 - mmengine - INFO - Epoch(train)  [198][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:55:27  time: 0.9062  data_time: 0.0055  memory: 5979  grad_norm: 3.5600  loss: 1.0943  loss_cls: 0.1236  loss_bbox: 0.3819  loss_centerness: 0.5888
# 02/13 03:41:31 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:41:31 - mmengine - INFO - Saving checkpoint at 198 epochs
# 02/13 03:41:43 - mmengine - INFO - Epoch(val)  [198][ 50/135]    eta: 0:00:15  time: 0.1856  data_time: 0.0086  memory: 11496
# 02/13 03:41:52 - mmengine - INFO - Epoch(val)  [198][100/135]    eta: 0:00:06  time: 0.1795  data_time: 0.0020  memory: 892
# 02/13 03:41:59 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.51s).
# Accumulating evaluation results...
# DONE (t=0.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.434
# 02/13 03:42:17 - mmengine - INFO - bbox_mAP_copypaste: 0.089 0.201 0.068 0.016 0.145 0.325
# 02/13 03:42:17 - mmengine - INFO - Epoch(val) [198][135/135]    coco/bbox_mAP: 0.0890  coco/bbox_mAP_50: 0.2010  coco/bbox_mAP_75: 0.0680  coco/bbox_mAP_s: 0.0160  coco/bbox_mAP_m: 0.1450  coco/bbox_mAP_l: 0.3250  data_time: 0.0045  time: 0.1812
# 02/13 03:43:03 - mmengine - INFO - Epoch(train)  [199][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 4:43:39  time: 0.9333  data_time: 0.0068  memory: 5842  grad_norm: 3.4767  loss: 1.0622  loss_cls: 0.1218  loss_bbox: 0.3539  loss_centerness: 0.5866
# 02/13 03:43:52 - mmengine - INFO - Epoch(train)  [199][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 4:26:15  time: 0.9678  data_time: 0.0055  memory: 5959  grad_norm: 3.5244  loss: 1.0655  loss_cls: 0.1223  loss_bbox: 0.3560  loss_centerness: 0.5871
# 02/13 03:44:38 - mmengine - INFO - Epoch(train)  [199][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:55:11  time: 0.9238  data_time: 0.0054  memory: 5986  grad_norm: 3.5929  loss: 1.0819  loss_cls: 0.1245  loss_bbox: 0.3692  loss_centerness: 0.5883
# 02/13 03:45:25 - mmengine - INFO - Epoch(train)  [199][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:36:56  time: 0.9401  data_time: 0.0054  memory: 5958  grad_norm: 3.4672  loss: 1.0729  loss_cls: 0.1251  loss_bbox: 0.3616  loss_centerness: 0.5862
# 02/13 03:46:03 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:46:03 - mmengine - INFO - Saving checkpoint at 199 epochs
# 02/13 03:46:16 - mmengine - INFO - Epoch(val)  [199][ 50/135]    eta: 0:00:15  time: 0.1838  data_time: 0.0031  memory: 10594
# 02/13 03:46:25 - mmengine - INFO - Epoch(val)  [199][100/135]    eta: 0:00:06  time: 0.1817  data_time: 0.0022  memory: 892
# 02/13 03:46:32 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=18.21s).
# Accumulating evaluation results...
# DONE (t=0.37s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.200
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.439
# 02/13 03:46:50 - mmengine - INFO - bbox_mAP_copypaste: 0.090 0.200 0.070 0.015 0.146 0.326
# 02/13 03:46:50 - mmengine - INFO - Epoch(val) [199][135/135]    coco/bbox_mAP: 0.0900  coco/bbox_mAP_50: 0.2000  coco/bbox_mAP_75: 0.0700  coco/bbox_mAP_s: 0.0150  coco/bbox_mAP_m: 0.1460  coco/bbox_mAP_l: 0.3260  data_time: 0.0025  time: 0.1817
# 02/13 03:47:23 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:47:35 - mmengine - INFO - Epoch(train)  [200][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:28:10  time: 0.9008  data_time: 0.0058  memory: 5986  grad_norm: 3.5019  loss: 1.0590  loss_cls: 0.1197  loss_bbox: 0.3531  loss_centerness: 0.5862
# 02/13 03:48:23 - mmengine - INFO - Epoch(train)  [200][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:19:44  time: 0.9528  data_time: 0.0053  memory: 5939  grad_norm: 3.6529  loss: 1.0898  loss_cls: 0.1274  loss_bbox: 0.3734  loss_centerness: 0.5890
# 02/13 03:49:09 - mmengine - INFO - Epoch(train)  [200][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 3:05:42  time: 0.9258  data_time: 0.0056  memory: 5913  grad_norm: 3.5074  loss: 1.0649  loss_cls: 0.1216  loss_bbox: 0.3568  loss_centerness: 0.5865
# 02/13 03:49:54 - mmengine - INFO - Epoch(train)  [200][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 2:48:20  time: 0.9031  data_time: 0.0054  memory: 5871  grad_norm: 3.4852  loss: 1.0513  loss_cls: 0.1180  loss_bbox: 0.3477  loss_centerness: 0.5856
# 02/13 03:50:28 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:50:28 - mmengine - INFO - Saving checkpoint at 200 epochs
# 02/13 03:50:40 - mmengine - INFO - Epoch(val)  [200][ 50/135]    eta: 0:00:15  time: 0.1829  data_time: 0.0032  memory: 5986
# 02/13 03:50:49 - mmengine - INFO - Epoch(val)  [200][100/135]    eta: 0:00:06  time: 0.1804  data_time: 0.0023  memory: 892
# 02/13 03:50:56 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.37s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.147
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.330
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.441
# 02/13 03:51:14 - mmengine - INFO - bbox_mAP_copypaste: 0.090 0.201 0.071 0.015 0.147 0.330
# 02/13 03:51:14 - mmengine - INFO - Epoch(val) [200][135/135]    coco/bbox_mAP: 0.0900  coco/bbox_mAP_50: 0.2010  coco/bbox_mAP_75: 0.0710  coco/bbox_mAP_s: 0.0150  coco/bbox_mAP_m: 0.1470  coco/bbox_mAP_l: 0.3300  data_time: 0.0026  time: 0.1813
# 02/13 03:52:00 - mmengine - INFO - Epoch(train)  [201][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 2:31:23  time: 0.9220  data_time: 0.0067  memory: 5958  grad_norm: 3.4657  loss: 1.0745  loss_cls: 0.1236  loss_bbox: 0.3635  loss_centerness: 0.5873
# 02/13 03:52:46 - mmengine - INFO - Epoch(train)  [201][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 2:23:45  time: 0.9286  data_time: 0.0054  memory: 5958  grad_norm: 3.4398  loss: 1.0681  loss_cls: 0.1209  loss_bbox: 0.3597  loss_centerness: 0.5875
# 02/13 03:53:31 - mmengine - INFO - Epoch(train)  [201][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 2:12:00  time: 0.9016  data_time: 0.0054  memory: 5858  grad_norm: 3.4834  loss: 1.0663  loss_cls: 0.1223  loss_bbox: 0.3571  loss_centerness: 0.5870
# 02/13 03:54:18 - mmengine - INFO - Epoch(train)  [201][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 2:07:23  time: 0.9359  data_time: 0.0053  memory: 5958  grad_norm: 3.5617  loss: 1.0774  loss_cls: 0.1233  loss_bbox: 0.3664  loss_centerness: 0.5876
# 02/13 03:54:51 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:54:51 - mmengine - INFO - Saving checkpoint at 201 epochs
# 02/13 03:55:04 - mmengine - INFO - Epoch(val)  [201][ 50/135]    eta: 0:00:15  time: 0.1836  data_time: 0.0029  memory: 5939
# 02/13 03:55:13 - mmengine - INFO - Epoch(val)  [201][100/135]    eta: 0:00:06  time: 0.1837  data_time: 0.0023  memory: 892
# 02/13 03:55:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.65s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.437
# 02/13 03:55:38 - mmengine - INFO - bbox_mAP_copypaste: 0.090 0.203 0.070 0.016 0.146 0.325
# 02/13 03:55:38 - mmengine - INFO - Epoch(val) [201][135/135]    coco/bbox_mAP: 0.0900  coco/bbox_mAP_50: 0.2030  coco/bbox_mAP_75: 0.0700  coco/bbox_mAP_s: 0.0160  coco/bbox_mAP_m: 0.1460  coco/bbox_mAP_l: 0.3250  data_time: 0.0025  time: 0.1834
# 02/13 03:55:38 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_187.pth is removed
# 02/13 03:55:39 - mmengine - INFO - The best checkpoint with 0.2030 coco/bbox_mAP_50 at 201 epoch is saved to best_coco_bbox_mAP_50_epoch_201.pth.
# 02/13 03:56:29 - mmengine - INFO - Epoch(train)  [202][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:57:56  time: 0.9263  data_time: 0.0064  memory: 5858  grad_norm: 3.4756  loss: 1.0494  loss_cls: 0.1145  loss_bbox: 0.3492  loss_centerness: 0.5856
# 02/13 03:57:14 - mmengine - INFO - Epoch(train)  [202][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:49:58  time: 0.9064  data_time: 0.0055  memory: 5986  grad_norm: 3.7334  loss: 1.0663  loss_cls: 0.1227  loss_bbox: 0.3561  loss_centerness: 0.5875
# 02/13 03:57:59 - mmengine - INFO - Epoch(train)  [202][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:41:53  time: 0.9011  data_time: 0.0053  memory: 5958  grad_norm: 3.5952  loss: 1.0558  loss_cls: 0.1198  loss_bbox: 0.3501  loss_centerness: 0.5859
# 02/13 03:58:45 - mmengine - INFO - Epoch(train)  [202][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:36:13  time: 0.9141  data_time: 0.0066  memory: 5871  grad_norm: 3.4633  loss: 1.0811  loss_cls: 0.1262  loss_bbox: 0.3674  loss_centerness: 0.5875
# 02/13 03:59:17 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 03:59:17 - mmengine - INFO - Saving checkpoint at 202 epochs
# 02/13 03:59:30 - mmengine - INFO - Epoch(val)  [202][ 50/135]    eta: 0:00:15  time: 0.1845  data_time: 0.0031  memory: 5986
# 02/13 03:59:39 - mmengine - INFO - Epoch(val)  [202][100/135]    eta: 0:00:06  time: 0.1830  data_time: 0.0023  memory: 892
# 02/13 03:59:45 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.27s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.76s).
# Accumulating evaluation results...
# DONE (t=0.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.436
# 02/13 04:00:04 - mmengine - INFO - bbox_mAP_copypaste: 0.089 0.201 0.069 0.015 0.146 0.325
# 02/13 04:00:04 - mmengine - INFO - Epoch(val) [202][135/135]    coco/bbox_mAP: 0.0890  coco/bbox_mAP_50: 0.2010  coco/bbox_mAP_75: 0.0690  coco/bbox_mAP_s: 0.0150  coco/bbox_mAP_m: 0.1460  coco/bbox_mAP_l: 0.3250  data_time: 0.0026  time: 0.1827
# 02/13 04:00:50 - mmengine - INFO - Epoch(train)  [203][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:26:52  time: 0.9145  data_time: 0.0061  memory: 5913  grad_norm: 3.5976  loss: 1.0620  loss_cls: 0.1246  loss_bbox: 0.3502  loss_centerness: 0.5872
# 02/13 04:01:37 - mmengine - INFO - Epoch(train)  [203][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:25:25  time: 0.9400  data_time: 0.0072  memory: 5986  grad_norm: 3.5691  loss: 1.0833  loss_cls: 0.1226  loss_bbox: 0.3734  loss_centerness: 0.5874
# 02/13 04:02:25 - mmengine - INFO - Epoch(train)  [203][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:27:03  time: 0.9658  data_time: 0.0054  memory: 5871  grad_norm: 3.6771  loss: 1.0651  loss_cls: 0.1231  loss_bbox: 0.3551  loss_centerness: 0.5869
# 02/13 04:03:12 - mmengine - INFO - Epoch(train)  [203][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:25:03  time: 0.9353  data_time: 0.0055  memory: 5958  grad_norm: 3.3912  loss: 1.0519  loss_cls: 0.1165  loss_bbox: 0.3504  loss_centerness: 0.5851
# 02/13 04:03:43 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# ...
# 02/13 04:07:36 - mmengine - INFO - Epoch(train)  [204][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:12:19  time: 0.9333  data_time: 0.0055  memory: 5986  grad_norm: 3.4583  loss: 1.0796  loss_cls: 0.1239  loss_bbox: 0.3681  loss_centerness: 0.5876
# 02/13 04:08:10 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:08:10 - mmengine - INFO - Saving checkpoint at 204 epochs
# 02/13 04:08:22 - mmengine - INFO - Epoch(val)  [204][ 50/135]    eta: 0:00:15  time: 0.1836  data_time: 0.0027  memory: 5986
# 02/13 04:08:31 - mmengine - INFO - Epoch(val)  [204][100/135]    eta: 0:00:06  time: 0.1823  data_time: 0.0023  memory: 892
# 02/13 04:08:37 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.34s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.440
# 02/13 04:08:55 - mmengine - INFO - bbox_mAP_copypaste: 0.091 0.204 0.070 0.016 0.149 0.327
# 02/13 04:08:55 - mmengine - INFO - Epoch(val) [204][135/135]    coco/bbox_mAP: 0.0910  coco/bbox_mAP_50: 0.2040  coco/bbox_mAP_75: 0.0700  coco/bbox_mAP_s: 0.0160  coco/bbox_mAP_m: 0.1490  coco/bbox_mAP_l: 0.3270  data_time: 0.0025  time: 0.1826
# 02/13 04:08:55 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_201.pth is removed
# 02/13 04:08:57 - mmengine - INFO - The best checkpoint with 0.2040 coco/bbox_mAP_50 at 204 epoch is saved to best_coco_bbox_mAP_50_epoch_204.pth.
# 02/13 04:09:44 - mmengine - INFO - Epoch(train)  [205][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:05:18  time: 0.8802  data_time: 0.0067  memory: 5939  grad_norm: 3.4775  loss: 1.0492  loss_cls: 0.1157  loss_bbox: 0.3480  loss_centerness: 0.5855
# 02/13 04:10:28 - mmengine - INFO - Epoch(train)  [205][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:59:54  time: 0.8891  data_time: 0.0055  memory: 5858  grad_norm: 3.3883  loss: 1.0707  loss_cls: 0.1227  loss_bbox: 0.3611  loss_centerness: 0.5870
# 02/13 04:11:16 - mmengine - INFO - Epoch(train)  [205][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:01:06  time: 0.9624  data_time: 0.0054  memory: 5958  grad_norm: 3.6289  loss: 1.0434  loss_cls: 0.1170  loss_bbox: 0.3418  loss_centerness: 0.5845
# 02/13 04:12:05 - mmengine - INFO - Epoch(train)  [205][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 1:02:27  time: 0.9655  data_time: 0.0055  memory: 5913  grad_norm: 3.6217  loss: 1.0629  loss_cls: 0.1219  loss_bbox: 0.3546  loss_centerness: 0.5864
# 02/13 04:12:37 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:12:37 - mmengine - INFO - Saving checkpoint at 205 epochs
# 02/13 04:12:50 - mmengine - INFO - Epoch(val)  [205][ 50/135]    eta: 0:00:15  time: 0.1839  data_time: 0.0028  memory: 5958
# 02/13 04:12:59 - mmengine - INFO - Epoch(val)  [205][100/135]    eta: 0:00:06  time: 0.1813  data_time: 0.0022  memory: 892
# 02/13 04:13:06 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.26s).
# Accumulating evaluation results...
# DONE (t=0.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.201
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.442
# 02/13 04:13:24 - mmengine - INFO - bbox_mAP_copypaste: 0.090 0.201 0.069 0.015 0.146 0.329
# 02/13 04:13:24 - mmengine - INFO - Epoch(val) [205][135/135]    coco/bbox_mAP: 0.0900  coco/bbox_mAP_50: 0.2010  coco/bbox_mAP_75: 0.0690  coco/bbox_mAP_s: 0.0150  coco/bbox_mAP_m: 0.1460  coco/bbox_mAP_l: 0.3290  data_time: 0.0024  time: 0.1821
# 02/13 04:14:09 - mmengine - INFO - Epoch(train)  [206][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:56:14  time: 0.9055  data_time: 0.0066  memory: 5867  grad_norm: 3.5941  loss: 1.0473  loss_cls: 0.1198  loss_bbox: 0.3420  loss_centerness: 0.5855
# 02/13 04:14:55 - mmengine - INFO - Epoch(train)  [206][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:54:39  time: 0.9291  data_time: 0.0054  memory: 5986  grad_norm: 3.5546  loss: 1.0881  loss_cls: 0.1198  loss_bbox: 0.3804  loss_centerness: 0.5879
# 02/13 04:15:41 - mmengine - INFO - Epoch(train)  [206][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:51:01  time: 0.9018  data_time: 0.0053  memory: 5939  grad_norm: 3.4566  loss: 1.0605  loss_cls: 0.1189  loss_bbox: 0.3551  loss_centerness: 0.5865
# 02/13 04:16:27 - mmengine - INFO - Epoch(train)  [206][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:49:51  time: 0.9329  data_time: 0.0054  memory: 5958  grad_norm: 3.6743  loss: 1.0598  loss_cls: 0.1250  loss_bbox: 0.3484  loss_centerness: 0.5864
# 02/13 04:17:00 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:17:00 - mmengine - INFO - Saving checkpoint at 206 epochs
# 02/13 04:17:12 - mmengine - INFO - Epoch(val)  [206][ 50/135]    eta: 0:00:15  time: 0.1839  data_time: 0.0032  memory: 5958
# 02/13 04:17:21 - mmengine - INFO - Epoch(val)  [206][100/135]    eta: 0:00:06  time: 0.1799  data_time: 0.0023  memory: 892
# 02/13 04:17:28 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.33s).
# Accumulating evaluation results...
# DONE (t=0.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.445
# 02/13 04:17:46 - mmengine - INFO - bbox_mAP_copypaste: 0.092 0.207 0.071 0.017 0.150 0.329
# 02/13 04:17:46 - mmengine - INFO - Epoch(val) [206][135/135]    coco/bbox_mAP: 0.0920  coco/bbox_mAP_50: 0.2070  coco/bbox_mAP_75: 0.0710  coco/bbox_mAP_s: 0.0170  coco/bbox_mAP_m: 0.1500  coco/bbox_mAP_l: 0.3290  data_time: 0.0027  time: 0.1817
# 02/13 04:17:46 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_204.pth is removed
# 02/13 04:17:47 - mmengine - INFO - The best checkpoint with 0.2070 coco/bbox_mAP_50 at 206 epoch is saved to best_coco_bbox_mAP_50_epoch_206.pth.
# 02/13 04:18:36 - mmengine - INFO - Epoch(train)  [207][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:47:25  time: 0.9336  data_time: 0.0063  memory: 5939  grad_norm: 3.5397  loss: 1.0549  loss_cls: 0.1199  loss_bbox: 0.3496  loss_centerness: 0.5853
# 02/13 04:19:21 - mmengine - INFO - Epoch(train)  [207][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:43:47  time: 0.8968  data_time: 0.0054  memory: 5867  grad_norm: 3.5044  loss: 1.0603  loss_cls: 0.1188  loss_bbox: 0.3548  loss_centerness: 0.5867
# 02/13 04:20:07 - mmengine - INFO - Epoch(train)  [207][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:41:41  time: 0.9176  data_time: 0.0055  memory: 5913  grad_norm: 3.4700  loss: 1.0390  loss_cls: 0.1148  loss_bbox: 0.3397  loss_centerness: 0.5846
# 02/13 04:20:53 - mmengine - INFO - Epoch(train)  [207][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:39:20  time: 0.9129  data_time: 0.0054  memory: 5958  grad_norm: 3.4935  loss: 1.0630  loss_cls: 0.1215  loss_bbox: 0.3551  loss_centerness: 0.5863
# 02/13 04:21:26 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:21:26 - mmengine - INFO - Saving checkpoint at 207 epochs
# 02/13 04:21:38 - mmengine - INFO - Epoch(val)  [207][ 50/135]    eta: 0:00:15  time: 0.1813  data_time: 0.0027  memory: 5986
# 02/13 04:21:47 - mmengine - INFO - Epoch(val)  [207][100/135]    eta: 0:00:06  time: 0.1819  data_time: 0.0023  memory: 892
# 02/13 04:21:54 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.57s).
# Accumulating evaluation results...
# DONE (t=0.36s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.446
# 02/13 04:22:12 - mmengine - INFO - bbox_mAP_copypaste: 0.091 0.203 0.070 0.016 0.148 0.333
# 02/13 04:22:12 - mmengine - INFO - Epoch(val) [207][135/135]    coco/bbox_mAP: 0.0910  coco/bbox_mAP_50: 0.2030  coco/bbox_mAP_75: 0.0700  coco/bbox_mAP_s: 0.0160  coco/bbox_mAP_m: 0.1480  coco/bbox_mAP_l: 0.3330  data_time: 0.0025  time: 0.1814
# 02/13 04:22:58 - mmengine - INFO - Epoch(train)  [208][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:36:40  time: 0.9306  data_time: 0.0070  memory: 5939  grad_norm: 3.4988  loss: 1.0599  loss_cls: 0.1239  loss_bbox: 0.3491  loss_centerness: 0.5868
# 02/13 04:23:45 - mmengine - INFO - Epoch(train)  [208][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:36:30  time: 0.9452  data_time: 0.0053  memory: 5958  grad_norm: 3.4176  loss: 1.0525  loss_cls: 0.1162  loss_bbox: 0.3506  loss_centerness: 0.5857
# 02/13 04:24:30 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:24:32 - mmengine - INFO - Epoch(train)  [208][150/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:35:36  time: 0.9336  data_time: 0.0055  memory: 5858  grad_norm: 3.6280  loss: 1.0566  loss_cls: 0.1185  loss_bbox: 0.3522  loss_centerness: 0.5859
# 02/13 04:25:19 - mmengine - INFO - Epoch(train)  [208][200/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:35:20  time: 0.9439  data_time: 0.0056  memory: 5986  grad_norm: 3.6460  loss: 1.0748  loss_cls: 0.1193  loss_bbox: 0.3677  loss_centerness: 0.5878
# 02/13 04:25:53 - mmengine - INFO - Exp name: custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco_20240213_033720
# 02/13 04:25:53 - mmengine - INFO - Saving checkpoint at 208 epochs
# 02/13 04:26:06 - mmengine - INFO - Epoch(val)  [208][ 50/135]    eta: 0:00:15  time: 0.1840  data_time: 0.0031  memory: 5913
# 02/13 04:26:15 - mmengine - INFO - Epoch(val)  [208][100/135]    eta: 0:00:06  time: 0.1818  data_time: 0.0024  memory: 892
# 02/13 04:26:21 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.46s).
# Accumulating evaluation results...
# DONE (t=0.35s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.446
# 02/13 04:26:39 - mmengine - INFO - bbox_mAP_copypaste: 0.091 0.203 0.070 0.016 0.148 0.333
# 02/13 04:26:39 - mmengine - INFO - Epoch(val) [208][135/135]    coco/bbox_mAP: 0.0910  coco/bbox_mAP_50: 0.2030  coco/bbox_mAP_75: 0.0700  coco/bbox_mAP_s: 0.0160  coco/bbox_mAP_m: 0.1480  coco/bbox_mAP_l: 0.3330  data_time: 0.0026  time: 0.1824
# 02/13 04:27:26 - mmengine - INFO - Epoch(train)  [209][ 50/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:34:34  time: 0.9367  data_time: 0.0063  memory: 5958  grad_norm: 3.6265  loss: 1.0550  loss_cls: 0.1200  loss_bbox: 0.3493  loss_centerness: 0.5857
# 02/13 04:28:10 - mmengine - INFO - Epoch(train)  [209][100/236]  base_lr: 1.0000e-04 lr: 1.0000e-04  eta: 2 days, 0:30:18  time: 0.8754  data_time: 0.0057  memory: 5871  grad_norm: 3.6754  loss: 1.0803  loss_cls: 0.1220  loss_bbox: 0.3697  loss_centerness: 0.5886

# %%
print()

# %%
# Check Pytorch installation
import cv2
import os
import json
import roboflow
import random

import numpy as np

from mmdet.apis import init_detector, inference_detector

import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Check MMDetection installation
from mmengine.utils import get_git_hash
from mmengine.utils.dl_utils import collect_env as collect_base_env

import mmdet

print(mmdet.__version__)

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())

import os
HOME = os.getcwd()
print("HOME:", HOME)

from roboflow import Roboflow
rf = Roboflow(api_key="a8fzziqukkQgsmGFnKgD")
project = rf.workspace("wildfire2024").project("forestfire2024")
dataset = project.version(1).download("coco-mmdetection")

CUSTOM_WEIGHTS_PATH = f"{HOME}/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth"
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

images = list(ds.images.values())

import numpy as np

# Load the dataset
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# Define the search space for hyperparameters
param_space = {
    'CONFIDENCE_THRESHOLD': np.linspace(0.1, 1.0, 20),  # Adjust the range as needed
    'NMS_IOU_THRESHOLD': np.linspace(0.1, 1.0, 20),  # Adjust the range as needed
}

best_map = 0.0
best_params = {}

# Perform random search
for _ in range(20):  # You can adjust the number of random samples
    CONFIDENCE_THRESHOLD= np.random.choice(param_space['CONFIDENCE_THRESHOLD'])
    NMS_IOU_THRESHOLD= np.random.choice(param_space['NMS_IOU_THRESHOLD'])
    
    def callback(image: np.ndarray) -> sv.Detections:
        result = inference_detector(model, image)
        detections = sv.Detections.from_mmdetection(result)
        return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)

    mean_average_precision = sv.MeanAveragePrecision.benchmark(dataset=ds, callback=callback)

    if mean_average_precision.map50_95 > best_map:
        best_map = mean_average_precision.map50_95
        best_params = [CONFIDENCE_THRESHOLD,NMS_IOU_THRESHOLD]

print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Forestfire2024-1 to coco-mmdetection:: 100%|██████████| 151008/151008 [00:05<00:00, 27631.01it/s]
# Extracting Dataset Version Zip to Forestfire2024-1 in coco-mmdetection:: 100%|██████████| 681/681 [00:05<00:00, 126.44it/s]
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
# Best mAP: 0.3840096539781204
# Best Parameters: [0.5263157894736842, 0.8105263157894737]
