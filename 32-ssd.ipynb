# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Fri Feb 16 04:46:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       On  | 00000000:5E:00.0 Off |                    0 |
# | N/A   34C    P8              11W /  70W |      2MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Forestfire2024-1 to coco-mmdetection:: 100%|██████████| 151008/151008 [00:02<00:00, 65937.98it/s]
# Extracting Dataset Version Zip to Forestfire2024-1 in coco-mmdetection:: 100%|██████████| 681/681 [00:06<00:00, 104.17it/s]
# dataset classes: ['Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris']
# dataset size: 471
# dataset classes: ['Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris']
# dataset size: 67

# %%
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/ssd/custom_ssd512.py"

CUSTOM_CONFIG = f"""
_base_ = 'ssd300_coco.py'



# ========================Frequently modified parameters======================
# -----data related-----
# model = dict(
#     roi_head=dict(
#         bbox_head=dict(num_classes=4),
# ))

dataset_type = 'COCODataset'
max_epochs = 200
classes =  ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris') 

data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/'  # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris')  
num_classes = 4  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = 16  # Batch size per GPU during training
train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = 1000  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image

# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=10,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    samples_per_gpu=16,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/annotation_coco.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 32
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----model related-----
# The scaling factor that controls the depth of the network structure
deepen_factor = 0.67
# The scaling factor that controls the width of the network structure
widen_factor = 0.75
# Strides of multi-scale prior box
strides = [8, 16, 32]

norm_cfg = dict(type='BN')  # Normalization config

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)

"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
# !python tools/train.py configs/ssd/costom_ssd512.py --resume | tee ../OUT_ssd.txt
# !python tools/train.py configs/ssd/custom_ssd512.py --resume | tee ../OUT_ssd.txt
# Out:
# 02/16 04:47:27 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1368768020
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1368768020
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/16 04:47:27 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=2, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=32,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# cudnn_benchmark = True
# custom_hooks = [
#     dict(type='NumClassCheckHook'),
#     dict(interval=50, priority='VERY_LOW', type='CheckInvalidLossHook'),
# ]
# data = dict(
#     samples_per_gpu=16,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/annotation_coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'),
#     workers_per_gpu=2)
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/'
# dataset_type = 'COCODataset'
# deepen_factor = 0.67
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# input_size = 300
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 1000
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         ceil_mode=True,
#         depth=16,
#         init_cfg=dict(
#             checkpoint='open-mmlab://vgg16_caffe', type='Pretrained'),
#         out_feature_indices=(
#             22,
#             34,
#         ),
#         out_indices=(
#             3,
#             4,
#         ),
#         type='SSDVGG',
#         with_last_pool=False),
#     bbox_head=dict(
#         anchor_generator=dict(
#             basesize_ratio_range=(
#                 0.15,
#                 0.9,
#             ),
#             input_size=300,
#             ratios=[
#                 [
#                     2,
#                 ],
#                 [
#                     2,
#                     3,
#                 ],
#                 [
#                     2,
#                     3,
#                 ],
#                 [
#                     2,
#                     3,
#                 ],
#                 [
#                     2,
#                 ],
#                 [
#                     2,
#                 ],
#             ],
#             scale_major=False,
#             strides=[
#                 8,
#                 16,
#                 32,
#                 64,
#                 100,
#                 300,
#             ],
#             type='SSDAnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 0.1,
#                 0.1,
#                 0.2,
#                 0.2,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         in_channels=(
#             512,
#             1024,
#             512,
#             256,
#             256,
#             256,
#         ),
#         num_classes=4,
#         type='SSDHead'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=1,
#         std=[
#             1,
#             1,
#             1,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=(
#             512,
#             1024,
#         ),
#         l2_norm_scale=20,
#         level_paddings=(
#             1,
#             1,
#             0,
#             0,
#         ),
#         level_strides=(
#             2,
#             2,
#             1,
#             1,
#         ),
#         out_channels=(
#             512,
#             1024,
#             512,
#             256,
#             256,
#             256,
#         ),
#         type='SSDNeck'),
#     test_cfg=dict(
#         max_per_img=200,
#         min_bbox_size=0,
#         nms=dict(iou_threshold=0.45, type='nms'),
#         nms_pre=1000,
#         score_thr=0.02),
#     train_cfg=dict(
#         allowed_border=-1,
#         assigner=dict(
#             gt_max_assign_all=False,
#             ignore_iof_thr=-1,
#             min_pos_iou=0.0,
#             neg_iou_thr=0.5,
#             pos_iou_thr=0.5,
#             type='MaxIoUAssigner'),
#         debug=False,
#         neg_pos_ratio=3,
#         pos_weight=-1,
#         sampler=dict(type='PseudoSampler'),
#         smoothl1_beta=1.0),
#     type='SingleStageDetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# norm_cfg = dict(type='BN')
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     optimizer=dict(lr=0.002, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=24,
#         gamma=0.1,
#         milestones=[
#             16,
#             22,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = True
# save_checkpoint_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=False, scale=(
#                 300,
#                 300,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=False, scale=(
#         300,
#         300,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_batch_size_per_gpu = 16
# train_cfg = dict(max_epochs=1000, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=None,
#     batch_size=8,
#     dataset=dict(
#         dataset=dict(
#             ann_file='train/_annotations.coco.json',
#             backend_args=None,
#             data_prefix=dict(img='train/'),
#             data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#             filter_cfg=dict(filter_empty_gt=True, min_size=32),
#             pipeline=[
#                 dict(backend_args=None, type='LoadImageFromFile'),
#                 dict(type='LoadAnnotations', with_bbox=True),
#                 dict(
#                     mean=[
#                         123.675,
#                         116.28,
#                         103.53,
#                     ],
#                     ratio_range=(
#                         1,
#                         4,
#                     ),
#                     to_rgb=True,
#                     type='Expand'),
#                 dict(
#                     min_crop_size=0.3,
#                     min_ious=(
#                         0.1,
#                         0.3,
#                         0.5,
#                         0.7,
#                         0.9,
#                     ),
#                     type='MinIoURandomCrop'),
#                 dict(keep_ratio=False, scale=(
#                     300,
#                     300,
#                 ), type='Resize'),
#                 dict(prob=0.5, type='RandomFlip'),
#                 dict(
#                     brightness_delta=32,
#                     contrast_range=(
#                         0.5,
#                         1.5,
#                     ),
#                     hue_delta=18,
#                     saturation_range=(
#                         0.5,
#                         1.5,
#                     ),
#                     type='PhotoMetricDistortion'),
#                 dict(type='PackDetInputs'),
#             ],
#             type='CocoDataset'),
#         times=5,
#         type='RepeatDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 4
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         ratio_range=(
#             1,
#             4,
#         ),
#         to_rgb=True,
#         type='Expand'),
#     dict(
#         min_crop_size=0.3,
#         min_ious=(
#             0.1,
#             0.3,
#             0.5,
#             0.7,
#             0.9,
#         ),
#         type='MinIoURandomCrop'),
#     dict(keep_ratio=False, scale=(
#         300,
#         300,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(
#         brightness_delta=32,
#         contrast_range=(
#             0.5,
#             1.5,
#         ),
#         hue_delta=18,
#         saturation_range=(
#             0.5,
#             1.5,
#         ),
#         type='PhotoMetricDistortion'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 32
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=False, scale=(
#                 300,
#                 300,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# widen_factor = 0.75
# work_dir = './work_dirs/custom_ssd512'
#
# 02/16 04:47:32 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/16 04:47:32 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) NumClassCheckHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (VERY_LOW    ) CheckInvalidLossHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) NumClassCheckHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/16 04:47:34 - mmengine - INFO - load model from: open-mmlab://vgg16_caffe
# 02/16 04:47:34 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://vgg16_caffe
# 02/16 04:47:34 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_ssd512/epoch_56.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_ssd512/epoch_56.pth
# 02/16 04:47:35 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_ssd512/epoch_56.pth
# 02/16 04:47:35 - mmengine - INFO - resumed epoch: 56, iter: 16519
# 02/16 04:47:35 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/16 04:47:35 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/16 04:47:35 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_ssd512.
# 02/16 04:48:06 - mmengine - INFO - Epoch(train)   [57][ 50/295]  lr: 2.0000e-05  eta: 1 day, 23:53:29  time: 0.6192  data_time: 0.0235  memory: 10056  loss: 5.6452  loss_cls: 2.6737  loss_bbox: 2.9716
# 02/16 04:48:24 - mmengine - INFO - Epoch(train)   [57][100/295]  lr: 2.0000e-05  eta: 1 day, 13:52:46  time: 0.3605  data_time: 0.0104  memory: 1507  loss: 5.4254  loss_cls: 2.6321  loss_bbox: 2.7933
# 02/16 04:48:42 - mmengine - INFO - Epoch(train)   [57][150/295]  lr: 2.0000e-05  eta: 1 day, 10:28:17  time: 0.3579  data_time: 0.0093  memory: 1507  loss: 5.5296  loss_cls: 2.6831  loss_bbox: 2.8465
# 02/16 04:49:00 - mmengine - INFO - Epoch(train)   [57][200/295]  lr: 2.0000e-05  eta: 1 day, 8:53:57  time: 0.3648  data_time: 0.0100  memory: 1507  loss: 5.5500  loss_cls: 2.6504  loss_bbox: 2.8995
# 02/16 04:49:18 - mmengine - INFO - Epoch(train)   [57][250/295]  lr: 2.0000e-05  eta: 1 day, 7:56:22  time: 0.3639  data_time: 0.0101  memory: 1507  loss: 5.4658  loss_cls: 2.6708  loss_bbox: 2.7950
# 02/16 04:49:41 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:49:41 - mmengine - INFO - Saving checkpoint at 57 epochs
# 02/16 04:49:48 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.61s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.113
# 02/16 04:50:24 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 04:50:24 - mmengine - INFO - Epoch(val) [57][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0369  time: 0.3236
# 02/16 04:50:43 - mmengine - INFO - Epoch(train)   [58][ 50/295]  lr: 2.0000e-05  eta: 1 day, 8:31:51  time: 0.3825  data_time: 0.0263  memory: 9344  loss: 5.4938  loss_cls: 2.6744  loss_bbox: 2.8194
# 02/16 04:51:02 - mmengine - INFO - Epoch(train)   [58][100/295]  lr: 2.0000e-05  eta: 1 day, 7:58:18  time: 0.3645  data_time: 0.0098  memory: 1507  loss: 5.4119  loss_cls: 2.6610  loss_bbox: 2.7509
# 02/16 04:51:20 - mmengine - INFO - Epoch(train)   [58][150/295]  lr: 2.0000e-05  eta: 1 day, 7:35:35  time: 0.3709  data_time: 0.0100  memory: 1507  loss: 5.5593  loss_cls: 2.6715  loss_bbox: 2.8878
# 02/16 04:51:33 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:51:39 - mmengine - INFO - Epoch(train)   [58][200/295]  lr: 2.0000e-05  eta: 1 day, 7:15:58  time: 0.3679  data_time: 0.0098  memory: 1507  loss: 5.5895  loss_cls: 2.6680  loss_bbox: 2.9214
# 02/16 04:51:57 - mmengine - INFO - Epoch(train)   [58][250/295]  lr: 2.0000e-05  eta: 1 day, 7:01:25  time: 0.3715  data_time: 0.0107  memory: 1507  loss: 5.5857  loss_cls: 2.7157  loss_bbox: 2.8701
# 02/16 04:52:14 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:52:14 - mmengine - INFO - Saving checkpoint at 58 epochs
# 02/16 04:52:19 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.21s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.53s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.111
# 02/16 04:52:55 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 04:52:55 - mmengine - INFO - Epoch(val) [58][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0209  time: 0.3033
# 02/16 04:53:14 - mmengine - INFO - Epoch(train)   [59][ 50/295]  lr: 2.0000e-05  eta: 1 day, 6:40:54  time: 0.3745  data_time: 0.0167  memory: 1507  loss: 5.4694  loss_cls: 2.6528  loss_bbox: 2.8166
# 02/16 04:53:32 - mmengine - INFO - Epoch(train)   [59][100/295]  lr: 2.0000e-05  eta: 1 day, 6:28:54  time: 0.3628  data_time: 0.0098  memory: 1507  loss: 5.4407  loss_cls: 2.6049  loss_bbox: 2.8358
# 02/16 04:53:50 - mmengine - INFO - Epoch(train)   [59][150/295]  lr: 2.0000e-05  eta: 1 day, 6:20:31  time: 0.3693  data_time: 0.0105  memory: 1507  loss: 5.5187  loss_cls: 2.6777  loss_bbox: 2.8410
# 02/16 04:54:09 - mmengine - INFO - Epoch(train)   [59][200/295]  lr: 2.0000e-05  eta: 1 day, 6:12:53  time: 0.3683  data_time: 0.0100  memory: 1507  loss: 5.5194  loss_cls: 2.6956  loss_bbox: 2.8238
# 02/16 04:54:28 - mmengine - INFO - Epoch(train)   [59][250/295]  lr: 2.0000e-05  eta: 1 day, 6:07:44  time: 0.3742  data_time: 0.0106  memory: 1507  loss: 5.5132  loss_cls: 2.6681  loss_bbox: 2.8451
# 02/16 04:54:44 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:54:44 - mmengine - INFO - Saving checkpoint at 59 epochs
# 02/16 04:54:48 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.71s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.109
# 02/16 04:55:25 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.064
# 02/16 04:55:25 - mmengine - INFO - Epoch(val) [59][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0640  data_time: 0.0152  time: 0.1584
# 02/16 04:55:44 - mmengine - INFO - Epoch(train)   [60][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:57:58  time: 0.3771  data_time: 0.0186  memory: 1507  loss: 5.6031  loss_cls: 2.6990  loss_bbox: 2.9041
# 02/16 04:56:02 - mmengine - INFO - Epoch(train)   [60][100/295]  lr: 2.0000e-05  eta: 1 day, 5:53:19  time: 0.3703  data_time: 0.0098  memory: 1507  loss: 5.5676  loss_cls: 2.6406  loss_bbox: 2.9270
# 02/16 04:56:20 - mmengine - INFO - Epoch(train)   [60][150/295]  lr: 2.0000e-05  eta: 1 day, 5:48:21  time: 0.3669  data_time: 0.0106  memory: 1507  loss: 5.5544  loss_cls: 2.6514  loss_bbox: 2.9030
# 02/16 04:56:39 - mmengine - INFO - Epoch(train)   [60][200/295]  lr: 2.0000e-05  eta: 1 day, 5:44:16  time: 0.3691  data_time: 0.0100  memory: 1507  loss: 5.5666  loss_cls: 2.6630  loss_bbox: 2.9036
# 02/16 04:56:57 - mmengine - INFO - Epoch(train)   [60][250/295]  lr: 2.0000e-05  eta: 1 day, 5:40:15  time: 0.3677  data_time: 0.0099  memory: 1507  loss: 5.5145  loss_cls: 2.6669  loss_bbox: 2.8476
# 02/16 04:57:14 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:57:14 - mmengine - INFO - Saving checkpoint at 60 epochs
# 02/16 04:57:18 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.52s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.110
# 02/16 04:57:54 - mmengine - INFO - bbox_mAP_copypaste: 0.019 0.056 0.010 0.001 0.040 0.065
# 02/16 04:57:54 - mmengine - INFO - Epoch(val) [60][17/17]    coco/bbox_mAP: 0.0190  coco/bbox_mAP_50: 0.0560  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0187  time: 0.1603
# 02/16 04:58:14 - mmengine - INFO - Epoch(train)   [61][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:35:54  time: 0.3806  data_time: 0.0200  memory: 1507  loss: 5.5323  loss_cls: 2.6345  loss_bbox: 2.8978
# 02/16 04:58:32 - mmengine - INFO - Epoch(train)   [61][100/295]  lr: 2.0000e-05  eta: 1 day, 5:32:48  time: 0.3689  data_time: 0.0100  memory: 1507  loss: 5.5840  loss_cls: 2.6943  loss_bbox: 2.8897
# 02/16 04:58:51 - mmengine - INFO - Epoch(train)   [61][150/295]  lr: 2.0000e-05  eta: 1 day, 5:30:38  time: 0.3731  data_time: 0.0109  memory: 1507  loss: 5.4325  loss_cls: 2.6756  loss_bbox: 2.7569
# 02/16 04:59:09 - mmengine - INFO - Epoch(train)   [61][200/295]  lr: 2.0000e-05  eta: 1 day, 5:28:33  time: 0.3727  data_time: 0.0103  memory: 1507  loss: 5.4674  loss_cls: 2.7013  loss_bbox: 2.7661
# 02/16 04:59:28 - mmengine - INFO - Epoch(train)   [61][250/295]  lr: 2.0000e-05  eta: 1 day, 5:26:56  time: 0.3749  data_time: 0.0104  memory: 1507  loss: 5.5458  loss_cls: 2.6782  loss_bbox: 2.8675
# 02/16 04:59:45 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 04:59:45 - mmengine - INFO - Saving checkpoint at 61 epochs
# 02/16 04:59:49 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.21s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.71s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.112
# 02/16 05:00:26 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 05:00:26 - mmengine - INFO - Epoch(val) [61][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0154  time: 0.1591
# 02/16 05:00:29 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:00:45 - mmengine - INFO - Epoch(train)   [62][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:24:07  time: 0.3826  data_time: 0.0243  memory: 1507  loss: 5.5210  loss_cls: 2.6887  loss_bbox: 2.8324
# 02/16 05:01:03 - mmengine - INFO - Epoch(train)   [62][100/295]  lr: 2.0000e-05  eta: 1 day, 5:21:48  time: 0.3685  data_time: 0.0097  memory: 1507  loss: 5.5242  loss_cls: 2.6565  loss_bbox: 2.8677
# 02/16 05:01:22 - mmengine - INFO - Epoch(train)   [62][150/295]  lr: 2.0000e-05  eta: 1 day, 5:19:44  time: 0.3695  data_time: 0.0101  memory: 1507  loss: 5.6383  loss_cls: 2.6966  loss_bbox: 2.9417
# 02/16 05:01:40 - mmengine - INFO - Epoch(train)   [62][200/295]  lr: 2.0000e-05  eta: 1 day, 5:18:20  time: 0.3735  data_time: 0.0102  memory: 1507  loss: 5.5205  loss_cls: 2.6486  loss_bbox: 2.8719
# 02/16 05:01:59 - mmengine - INFO - Epoch(train)   [62][250/295]  lr: 2.0000e-05  eta: 1 day, 5:16:28  time: 0.3695  data_time: 0.0103  memory: 1507  loss: 5.4479  loss_cls: 2.6615  loss_bbox: 2.7864
# 02/16 05:02:16 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:02:16 - mmengine - INFO - Saving checkpoint at 62 epochs
# 02/16 05:02:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.50s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.113
# 02/16 05:02:56 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 05:02:56 - mmengine - INFO - Epoch(val) [62][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0153  time: 0.1562
# 02/16 05:03:15 - mmengine - INFO - Epoch(train)   [63][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:14:25  time: 0.3763  data_time: 0.0179  memory: 1507  loss: 5.4931  loss_cls: 2.6700  loss_bbox: 2.8231
# 02/16 05:03:33 - mmengine - INFO - Epoch(train)   [63][100/295]  lr: 2.0000e-05  eta: 1 day, 5:12:03  time: 0.3639  data_time: 0.0098  memory: 1507  loss: 5.5499  loss_cls: 2.6892  loss_bbox: 2.8607
# 02/16 05:03:52 - mmengine - INFO - Epoch(train)   [63][150/295]  lr: 2.0000e-05  eta: 1 day, 5:10:41  time: 0.3713  data_time: 0.0109  memory: 1507  loss: 5.5207  loss_cls: 2.7015  loss_bbox: 2.8192
# 02/16 05:04:10 - mmengine - INFO - Epoch(train)   [63][200/295]  lr: 2.0000e-05  eta: 1 day, 5:09:35  time: 0.3731  data_time: 0.0103  memory: 1507  loss: 5.5157  loss_cls: 2.6267  loss_bbox: 2.8890
# 02/16 05:04:29 - mmengine - INFO - Epoch(train)   [63][250/295]  lr: 2.0000e-05  eta: 1 day, 5:08:03  time: 0.3690  data_time: 0.0106  memory: 1507  loss: 5.4175  loss_cls: 2.6585  loss_bbox: 2.7590
# 02/16 05:04:45 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:04:45 - mmengine - INFO - Saving checkpoint at 63 epochs
# 02/16 05:04:50 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.21s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.55s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.111
# 02/16 05:05:26 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 05:05:26 - mmengine - INFO - Epoch(val) [63][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0194  time: 0.1605
# 02/16 05:05:45 - mmengine - INFO - Epoch(train)   [64][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:06:40  time: 0.3809  data_time: 0.0256  memory: 1507  loss: 5.4934  loss_cls: 2.6879  loss_bbox: 2.8056
# 02/16 05:06:04 - mmengine - INFO - Epoch(train)   [64][100/295]  lr: 2.0000e-05  eta: 1 day, 5:05:00  time: 0.3666  data_time: 0.0102  memory: 1507  loss: 5.3592  loss_cls: 2.6198  loss_bbox: 2.7394
# 02/16 05:06:22 - mmengine - INFO - Epoch(train)   [64][150/295]  lr: 2.0000e-05  eta: 1 day, 5:04:15  time: 0.3747  data_time: 0.0106  memory: 1507  loss: 5.5192  loss_cls: 2.6683  loss_bbox: 2.8509
# 02/16 05:06:41 - mmengine - INFO - Epoch(train)   [64][200/295]  lr: 2.0000e-05  eta: 1 day, 5:03:13  time: 0.3717  data_time: 0.0108  memory: 1507  loss: 5.5961  loss_cls: 2.7225  loss_bbox: 2.8736
# 02/16 05:07:00 - mmengine - INFO - Epoch(train)   [64][250/295]  lr: 2.0000e-05  eta: 1 day, 5:02:57  time: 0.3791  data_time: 0.0108  memory: 1507  loss: 5.5447  loss_cls: 2.6701  loss_bbox: 2.8746
# 02/16 05:07:16 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:07:16 - mmengine - INFO - Saving checkpoint at 64 epochs
# 02/16 05:07:21 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.51s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.116
# 02/16 05:07:57 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.059 0.011 0.001 0.041 0.066
# 02/16 05:07:57 - mmengine - INFO - Epoch(val) [64][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0590  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0410  coco/bbox_mAP_l: 0.0660  data_time: 0.0163  time: 0.1595
# 02/16 05:07:57 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_ssd512/best_coco_bbox_mAP_50_epoch_46.pth is removed
# 02/16 05:07:58 - mmengine - INFO - The best checkpoint with 0.0590 coco/bbox_mAP_50 at 64 epoch is saved to best_coco_bbox_mAP_50_epoch_64.pth.
# 02/16 05:08:18 - mmengine - INFO - Epoch(train)   [65][ 50/295]  lr: 2.0000e-05  eta: 1 day, 5:01:17  time: 0.3771  data_time: 0.0173  memory: 1507  loss: 5.5530  loss_cls: 2.6431  loss_bbox: 2.9099
# 02/16 05:08:36 - mmengine - INFO - Epoch(train)   [65][100/295]  lr: 2.0000e-05  eta: 1 day, 5:00:02  time: 0.3684  data_time: 0.0101  memory: 1507  loss: 5.5829  loss_cls: 2.7127  loss_bbox: 2.8702
# 02/16 05:08:44 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:08:55 - mmengine - INFO - Epoch(train)   [65][150/295]  lr: 2.0000e-05  eta: 1 day, 4:59:13  time: 0.3729  data_time: 0.0102  memory: 1507  loss: 5.5422  loss_cls: 2.6650  loss_bbox: 2.8772
# 02/16 05:09:13 - mmengine - INFO - Epoch(train)   [65][200/295]  lr: 2.0000e-05  eta: 1 day, 4:58:09  time: 0.3698  data_time: 0.0098  memory: 1507  loss: 5.4761  loss_cls: 2.6678  loss_bbox: 2.8084
# 02/16 05:09:32 - mmengine - INFO - Epoch(train)   [65][250/295]  lr: 2.0000e-05  eta: 1 day, 4:56:55  time: 0.3676  data_time: 0.0097  memory: 1507  loss: 5.4405  loss_cls: 2.6333  loss_bbox: 2.8072
# 02/16 05:09:48 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:09:48 - mmengine - INFO - Saving checkpoint at 65 epochs
# 02/16 05:09:52 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.21s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.54s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.107
# 02/16 05:10:29 - mmengine - INFO - bbox_mAP_copypaste: 0.019 0.057 0.011 0.001 0.039 0.064
# 02/16 05:10:29 - mmengine - INFO - Epoch(val) [65][17/17]    coco/bbox_mAP: 0.0190  coco/bbox_mAP_50: 0.0570  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0390  coco/bbox_mAP_l: 0.0640  data_time: 0.0191  time: 0.1609
# 02/16 05:10:48 - mmengine - INFO - Epoch(train)   [66][ 50/295]  lr: 2.0000e-05  eta: 1 day, 4:55:56  time: 0.3832  data_time: 0.0237  memory: 1507  loss: 5.5558  loss_cls: 2.6908  loss_bbox: 2.8650
# 02/16 05:11:07 - mmengine - INFO - Epoch(train)   [66][100/295]  lr: 2.0000e-05  eta: 1 day, 4:55:24  time: 0.3751  data_time: 0.0108  memory: 1507  loss: 5.5079  loss_cls: 2.6603  loss_bbox: 2.8476
# 02/16 05:11:25 - mmengine - INFO - Epoch(train)   [66][150/295]  lr: 2.0000e-05  eta: 1 day, 4:54:24  time: 0.3693  data_time: 0.0101  memory: 1507  loss: 5.4746  loss_cls: 2.6699  loss_bbox: 2.8047
# 02/16 05:11:44 - mmengine - INFO - Epoch(train)   [66][200/295]  lr: 2.0000e-05  eta: 1 day, 4:53:42  time: 0.3726  data_time: 0.0106  memory: 1507  loss: 5.5583  loss_cls: 2.7211  loss_bbox: 2.8372
# 02/16 05:12:02 - mmengine - INFO - Epoch(train)   [66][250/295]  lr: 2.0000e-05  eta: 1 day, 4:52:53  time: 0.3711  data_time: 0.0100  memory: 1507  loss: 5.5636  loss_cls: 2.6783  loss_bbox: 2.8853
# 02/16 05:12:19 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:12:19 - mmengine - INFO - Saving checkpoint at 66 epochs
# 02/16 05:12:23 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.73s).
# Accumulating evaluation results...
# DONE (t=0.50s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.111
# 02/16 05:13:00 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.058 0.011 0.001 0.040 0.065
# 02/16 05:13:00 - mmengine - INFO - Epoch(val) [66][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0580  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0192  time: 0.1632
# 02/16 05:13:19 - mmengine - INFO - Epoch(train)   [67][ 50/295]  lr: 2.0000e-05  eta: 1 day, 4:52:08  time: 0.3814  data_time: 0.0212  memory: 1507  loss: 5.6515  loss_cls: 2.6873  loss_bbox: 2.9642
# 02/16 05:13:37 - mmengine - INFO - Epoch(train)   [67][100/295]  lr: 2.0000e-05  eta: 1 day, 4:51:03  time: 0.3670  data_time: 0.0104  memory: 1507  loss: 5.4644  loss_cls: 2.6826  loss_bbox: 2.7817
# 02/16 05:13:56 - mmengine - INFO - Epoch(train)   [67][150/295]  lr: 2.0000e-05  eta: 1 day, 4:50:14  time: 0.3703  data_time: 0.0101  memory: 1507  loss: 5.5676  loss_cls: 2.6470  loss_bbox: 2.9206
# 02/16 05:14:14 - mmengine - INFO - Epoch(train)   [67][200/295]  lr: 2.0000e-05  eta: 1 day, 4:49:30  time: 0.3712  data_time: 0.0103  memory: 1507  loss: 5.5034  loss_cls: 2.6655  loss_bbox: 2.8379
# 02/16 05:14:33 - mmengine - INFO - Epoch(train)   [67][250/295]  lr: 2.0000e-05  eta: 1 day, 4:48:42  time: 0.3701  data_time: 0.0094  memory: 1507  loss: 5.5832  loss_cls: 2.6748  loss_bbox: 2.9084
# 02/16 05:14:49 - mmengine - INFO - Exp name: custom_ssd512_20240216_044723
# 02/16 05:14:49 - mmengine - INFO - Saving checkpoint at 67 epochs
# 02/16 05:14:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=35.49s).
# Accumulating evaluation results...
# DONE (t=0.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.113
# 02/16 05:15:30 - mmengine - INFO - bbox_mAP_copypaste: 0.020 0.057 0.011 0.001 0.040 0.065
# 02/16 05:15:30 - mmengine - INFO - Epoch(val) [67][17/17]    coco/bbox_mAP: 0.0200  coco/bbox_mAP_50: 0.0570  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0650  data_time: 0.0185  time: 0.1598
# 02/16 05:15:30 - mmengine - INFO - the monitored metric did not improve in the last 10 records. best score: 0.058.

# %%
print()

# %%
# Check Pytorch installation
import cv2
import os
import json
import roboflow
import random

import numpy as np

from mmdet.apis import init_detector, inference_detector

import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Check MMDetection installation
from mmengine.utils import get_git_hash
from mmengine.utils.dl_utils import collect_env as collect_base_env

import mmdet

print(mmdet.__version__)

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())

import os
HOME = os.getcwd()
print("HOME:", HOME)

from roboflow import Roboflow
rf = Roboflow(api_key="a8fzziqukkQgsmGFnKgD")
project = rf.workspace("wildfire2024").project("forestfire2024")
dataset = project.version(1).download("coco-mmdetection")

CUSTOM_WEIGHTS_PATH = f"{HOME}/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth"
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

images = list(ds.images.values())

import numpy as np

# Load the dataset
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# Define the search space for hyperparameters
param_space = {
    'CONFIDENCE_THRESHOLD': np.linspace(0.1, 1.0, 20),  # Adjust the range as needed
    'NMS_IOU_THRESHOLD': np.linspace(0.1, 1.0, 20),  # Adjust the range as needed
}

best_map = 0.0
best_params = {}

# Perform random search
for _ in range(20):  # You can adjust the number of random samples
    CONFIDENCE_THRESHOLD= np.random.choice(param_space['CONFIDENCE_THRESHOLD'])
    NMS_IOU_THRESHOLD= np.random.choice(param_space['NMS_IOU_THRESHOLD'])
    
    def callback(image: np.ndarray) -> sv.Detections:
        result = inference_detector(model, image)
        detections = sv.Detections.from_mmdetection(result)
        return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)

    mean_average_precision = sv.MeanAveragePrecision.benchmark(dataset=ds, callback=callback)

    if mean_average_precision.map50_95 > best_map:
        best_map = mean_average_precision.map50_95
        best_params = [CONFIDENCE_THRESHOLD,NMS_IOU_THRESHOLD]

print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# HOME: /work/van-speech-nlp/jindaznb/j-vis/mmdetection
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Forestfire2024-1 to coco-mmdetection:: 100%|██████████| 151008/151008 [00:02<00:00, 73855.17it/s]
# Extracting Dataset Version Zip to Forestfire2024-1 in coco-mmdetection:: 100%|██████████| 681/681 [00:08<00:00, 76.13it/s]
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 39
#      36 dataset = project.version(1).download("coco-mmdetection")
#      38 CUSTOM_WEIGHTS_PATH = f"{HOME}/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth"
# ---> 39 model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)
#      41 import supervision as sv
#      43 ds = sv.DetectionDataset.from_coco(
#      44     images_directory_path=f"{dataset.location}/test",
#      45     annotations_path=f"{dataset.location}/test/_annotations.coco.json",
#      46 )
#
# File /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/apis/inference.py:73, in init_detector(config, checkpoint, palette, device, cfg_options)
#      71     model.dataset_meta = {'classes': get_classes('coco')}
#      72 else:
# ---> 73     checkpoint = load_checkpoint(model, checkpoint, map_location='cpu')
#      74     # Weights converted from elsewhere may not have meta fields.
#      75     checkpoint_meta = checkpoint.get('meta', {})
#
# File /work/van-speech-nlp/jenv/lib/python3.10/site-packages/mmengine/runner/checkpoint.py:636, in load_checkpoint(model, filename, map_location, strict, logger, revise_keys)
#     611 def load_checkpoint(model,
#     612                     filename,
#     613                     map_location=None,
#     614                     strict=False,
#     615                     logger=None,
#     616                     revise_keys=[(r'^module\.', '')]):
#     617     """Load checkpoint from a file or URI.
#     618
#     619     Args:
#    (...)
#     634         dict or OrderedDict: The loaded checkpoint.
#     635     """
# --> 636     checkpoint = _load_checkpoint(filename, map_location, logger)
#     637     # OrderedDict is a subclass of dict
#     638     if not isinstance(checkpoint, dict):
#
# File /work/van-speech-nlp/jenv/lib/python3.10/site-packages/mmengine/runner/checkpoint.py:548, in _load_checkpoint(filename, map_location, logger)
#     531 def _load_checkpoint(filename, map_location=None, logger=None):
#     532     """Load checkpoint from somewhere (modelzoo, file, url).
#     533
#     534     Args:
#    (...)
#     546         information, which depends on the checkpoint.
#     547     """
# --> 548     return CheckpointLoader.load_checkpoint(filename, map_location, logger)
#
# File /work/van-speech-nlp/jenv/lib/python3.10/site-packages/mmengine/runner/checkpoint.py:330, in CheckpointLoader.load_checkpoint(cls, filename, map_location, logger)
#     325 class_name = checkpoint_loader.__name__
#     326 print_log(
#     327     f'Loads checkpoint by {class_name[10:]} backend from path: '
#     328     f'{filename}',
#     329     logger=logger)
# --> 330 return checkpoint_loader(filename, map_location)
#
# File /work/van-speech-nlp/jenv/lib/python3.10/site-packages/mmengine/runner/checkpoint.py:346, in load_from_local(filename, map_location)
#     344 filename = osp.expanduser(filename)
#     345 if not osp.isfile(filename):
# --> 346     raise FileNotFoundError(f'{filename} can not be found.')
#     347 checkpoint = torch.load(filename, map_location=map_location)
#     348 return checkpoint
#
# FileNotFoundError: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdetection/work_dirs/custom_fcos_x101-64x4d_fpn_gn-head_ms-640-800-2x_coco/best_coco_bbox_mAP_50_epoch_206.pth can not be found.
