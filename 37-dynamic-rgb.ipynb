# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Fri Feb 23 22:02:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:AF:00.0 Off |                    0 |
# | N/A   44C    P0              28W /  70W |      2MiB / 15360MiB |      8%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# 2024-02-23 22:02:35.337097: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-23 22:02:35.394143: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 22:02:35.394175: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 22:02:35.395536: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 22:02:35.404430: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-23 22:02:39.156876: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# set seed successfully

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="dynamic_rcnn"
base_model_name="dynamic-rcnn_r50_fpn_1x_coco"
custom_model_name=f"custom-{base_model_name}-rgb"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
dataset_location=f"/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1"
MAX_EPOCHS=200
BATCH_SIZE=8
print(CUSTOM_CONFIG_PATH)


CUSTOM_CONFIG = f"""
_base_ = './{base_model_name}.py'

# ========================Frequently modified parameters======================
# -----data related-----
model = dict(
    roi_head=dict(
        bbox_head=dict(num_classes=4),
))

dataset_type = 'COCODataset'
max_epochs = 200
classes =  ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris') 

data_root = '{dataset_location}' # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris')  
num_classes = 4  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = {BATCH_SIZE}  # Batch size per GPU during training
#train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = {MAX_EPOCHS}  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image


# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=15,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    #samples_per_gpu=1,
    #workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/_annotations.coco.json.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 8
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)
"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/configs/dynamic_rcnn/custom-dynamic-rcnn_r50_fpn_1x_coco-rgb.py

# %%
# !python tools/train.py configs/ssd/costom_ssd512.py --resume | tee ../OUT_ssd.txt
# !python tools/train.py configs/{model_folder}/{model_name}.py  | tee "../log/OUT_{model_name}_$(date +"%Y%m%d_%H%M%S").txt"
# Out:
# 02/23 23:41:53 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 744286982
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 744286982
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/23 23:41:53 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=8,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/_annotations.coco.json.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'))
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv'
# dataset_type = 'COCODataset'
# deepen_factor = 0.67
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=15,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 200
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=4,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# norm_cfg = dict(type='BN')
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = False
# save_checkpoint_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_cfg = dict(max_epochs=200, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 8
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# widen_factor = 0.75
# work_dir = './work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco'
#
# 02/23 23:41:58 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/23 23:41:58 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/23 23:42:00 - mmengine - INFO - load model from: torchvision://resnet50
# 02/23 23:42:00 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 02/23 23:42:00 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 02/23 23:42:00 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/23 23:42:00 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/23 23:42:00 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco.
# 02/23 23:42:43 - mmengine - INFO - Epoch(train)   [1][ 50/236]  lr: 1.9820e-03  eta: 11:11:31  time: 0.8545  data_time: 0.0121  memory: 5911  loss: 2.0009  loss_rpn_cls: 0.6720  loss_rpn_bbox: 0.3148  loss_cls: 0.8046  acc: 75.0000  loss_bbox: 0.2094
# 02/23 23:43:27 - mmengine - INFO - Epoch(train)   [1][100/236]  lr: 3.9840e-03  eta: 11:21:19  time: 0.8813  data_time: 0.0050  memory: 4700  loss: 1.8073  loss_rpn_cls: 0.6178  loss_rpn_bbox: 0.3119  loss_cls: 0.6194  acc: 75.7812  loss_bbox: 0.2583
# 02/23 23:44:11 - mmengine - INFO - Epoch(train)   [1][150/236]  lr: 5.9860e-03  eta: 11:25:26  time: 0.8864  data_time: 0.0061  memory: 4870  loss: 1.9269  loss_rpn_cls: 0.5823  loss_rpn_bbox: 0.3159  loss_cls: 0.5962  acc: 75.1953  loss_bbox: 0.4326
# 02/23 23:44:54 - mmengine - INFO - Epoch(train)   [1][200/236]  lr: 7.9880e-03  eta: 11:21:52  time: 0.8596  data_time: 0.0065  memory: 5120  loss: 1.9795  loss_rpn_cls: 0.4969  loss_rpn_bbox: 0.2850  loss_cls: 0.6067  acc: 76.2695  loss_bbox: 0.5910
# 02/23 23:45:32 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/23 23:45:32 - mmengine - INFO - Saving checkpoint at 1 epochs
# 02/23 23:45:42 - mmengine - INFO - Epoch(val)   [1][ 50/135]    eta: 0:00:15  time: 0.1779  data_time: 0.0058  memory: 5423
# 02/23 23:45:50 - mmengine - INFO - Epoch(val)   [1][100/135]    eta: 0:00:05  time: 0.1563  data_time: 0.0021  memory: 548
# 02/23 23:45:57 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=18.07s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.059
# 02/23 23:46:15 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.036 0.003 0.002 0.019 0.023
# 02/23 23:46:15 - mmengine - INFO - Epoch(val) [1][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0360  coco/bbox_mAP_75: 0.0030  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0190  coco/bbox_mAP_l: 0.0230  data_time: 0.0034  time: 0.1699
# 02/23 23:46:16 - mmengine - INFO - The best checkpoint with 0.0360 coco/bbox_mAP_50 at 1 epoch is saved to best_coco_bbox_mAP_50_epoch_1.pth.
# 02/23 23:46:59 - mmengine - INFO - Epoch(train)   [2][ 50/236]  lr: 1.1431e-02  eta: 11:31:41  time: 0.8274  data_time: 0.0056  memory: 4875  loss: 1.9092  loss_rpn_cls: 0.4470  loss_rpn_bbox: 0.2775  loss_cls: 0.5827  acc: 74.2188  loss_bbox: 0.6020
# 02/23 23:47:43 - mmengine - INFO - Epoch(train)   [2][100/236]  lr: 1.3433e-02  eta: 11:29:46  time: 0.8744  data_time: 0.0058  memory: 4472  loss: 1.8585  loss_rpn_cls: 0.4057  loss_rpn_bbox: 0.2684  loss_cls: 0.5820  acc: 78.9062  loss_bbox: 0.6025
# 02/23 23:48:27 - mmengine - INFO - Epoch(train)   [2][150/236]  lr: 1.5435e-02  eta: 11:29:12  time: 0.8849  data_time: 0.0060  memory: 5124  loss: 1.8750  loss_rpn_cls: 0.4205  loss_rpn_bbox: 0.2768  loss_cls: 0.5886  acc: 68.9453  loss_bbox: 0.5891
# 02/23 23:49:11 - mmengine - INFO - Epoch(train)   [2][200/236]  lr: 1.7437e-02  eta: 11:27:35  time: 0.8734  data_time: 0.0049  memory: 4697  loss: 1.8691  loss_rpn_cls: 0.4207  loss_rpn_bbox: 0.2774  loss_cls: 0.5975  acc: 78.6133  loss_bbox: 0.5735
# 02/23 23:49:42 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/23 23:49:42 - mmengine - INFO - Saving checkpoint at 2 epochs
# 02/23 23:49:51 - mmengine - INFO - Epoch(val)   [2][ 50/135]    eta: 0:00:12  time: 0.1489  data_time: 0.0023  memory: 5124
# 02/23 23:50:00 - mmengine - INFO - Epoch(val)   [2][100/135]    eta: 0:00:05  time: 0.1825  data_time: 0.0023  memory: 552
# 02/23 23:50:07 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.50s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.066
# 02/23 23:50:25 - mmengine - INFO - bbox_mAP_copypaste: 0.023 0.056 0.014 0.005 0.038 0.036
# 02/23 23:50:25 - mmengine - INFO - Epoch(val) [2][135/135]    coco/bbox_mAP: 0.0230  coco/bbox_mAP_50: 0.0560  coco/bbox_mAP_75: 0.0140  coco/bbox_mAP_s: 0.0050  coco/bbox_mAP_m: 0.0380  coco/bbox_mAP_l: 0.0360  data_time: 0.0022  time: 0.1702
# 02/23 23:50:25 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_1.pth is removed
# 02/23 23:50:25 - mmengine - INFO - The best checkpoint with 0.0560 coco/bbox_mAP_50 at 2 epoch is saved to best_coco_bbox_mAP_50_epoch_2.pth.
# 02/23 23:51:10 - mmengine - INFO - Epoch(train)   [3][ 50/236]  lr: 2.0000e-02  eta: 11:24:17  time: 0.8619  data_time: 0.0053  memory: 5116  loss: 1.7732  loss_rpn_cls: 0.3919  loss_rpn_bbox: 0.2586  loss_cls: 0.5597  acc: 75.8789  loss_bbox: 0.5629
# 02/23 23:51:54 - mmengine - INFO - Epoch(train)   [3][100/236]  lr: 2.0000e-02  eta: 11:24:07  time: 0.8879  data_time: 0.0048  memory: 4099  loss: 1.7875  loss_rpn_cls: 0.3744  loss_rpn_bbox: 0.2648  loss_cls: 0.5694  acc: 77.4414  loss_bbox: 0.5788
# 02/23 23:52:38 - mmengine - INFO - Epoch(train)   [3][150/236]  lr: 2.0000e-02  eta: 11:23:15  time: 0.8781  data_time: 0.0045  memory: 5116  loss: 1.7575  loss_rpn_cls: 0.3376  loss_rpn_bbox: 0.2526  loss_cls: 0.5598  acc: 78.5156  loss_bbox: 0.6076
# 02/23 23:53:22 - mmengine - INFO - Epoch(train)   [3][200/236]  lr: 2.0000e-02  eta: 11:21:34  time: 0.8639  data_time: 0.0053  memory: 4705  loss: 1.7858  loss_rpn_cls: 0.3783  loss_rpn_bbox: 0.2580  loss_cls: 0.5774  acc: 82.1289  loss_bbox: 0.5721
# 02/23 23:53:52 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/23 23:53:52 - mmengine - INFO - Saving checkpoint at 3 epochs
# 02/23 23:54:03 - mmengine - INFO - Epoch(val)   [3][ 50/135]    eta: 0:00:15  time: 0.1836  data_time: 0.0027  memory: 4867
# 02/23 23:54:12 - mmengine - INFO - Epoch(val)   [3][100/135]    eta: 0:00:06  time: 0.1837  data_time: 0.0027  memory: 552
# 02/23 23:54:16 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.66s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.079
# 02/23 23:54:33 - mmengine - INFO - bbox_mAP_copypaste: 0.024 0.067 0.011 0.007 0.043 0.034
# 02/23 23:54:33 - mmengine - INFO - Epoch(val) [3][135/135]    coco/bbox_mAP: 0.0240  coco/bbox_mAP_50: 0.0670  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0070  coco/bbox_mAP_m: 0.0430  coco/bbox_mAP_l: 0.0340  data_time: 0.0025  time: 0.1614
# 02/23 23:54:33 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_2.pth is removed
# 02/23 23:54:34 - mmengine - INFO - The best checkpoint with 0.0670 coco/bbox_mAP_50 at 3 epoch is saved to best_coco_bbox_mAP_50_epoch_3.pth.
# 02/23 23:55:19 - mmengine - INFO - Epoch(train)   [4][ 50/236]  lr: 2.0000e-02  eta: 11:18:55  time: 0.8656  data_time: 0.0058  memory: 4875  loss: 1.7136  loss_rpn_cls: 0.3310  loss_rpn_bbox: 0.2507  loss_cls: 0.5536  acc: 77.6367  loss_bbox: 0.5783
# 02/23 23:56:03 - mmengine - INFO - Epoch(train)   [4][100/236]  lr: 2.0000e-02  eta: 11:18:43  time: 0.8880  data_time: 0.0056  memory: 5124  loss: 1.7114  loss_rpn_cls: 0.3384  loss_rpn_bbox: 0.2507  loss_cls: 0.5431  acc: 76.3672  loss_bbox: 0.5791
# 02/23 23:56:46 - mmengine - INFO - Epoch(train)   [4][150/236]  lr: 2.0000e-02  eta: 11:16:49  time: 0.8518  data_time: 0.0041  memory: 4705  loss: 1.7030  loss_rpn_cls: 0.3361  loss_rpn_bbox: 0.2368  loss_cls: 0.5542  acc: 78.4180  loss_bbox: 0.5759
# 02/23 23:57:30 - mmengine - INFO - Epoch(train)   [4][200/236]  lr: 2.0000e-02  eta: 11:16:13  time: 0.8795  data_time: 0.0054  memory: 4106  loss: 1.6851  loss_rpn_cls: 0.3151  loss_rpn_bbox: 0.2466  loss_cls: 0.5358  acc: 75.7812  loss_bbox: 0.5876
# 02/23 23:58:00 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/23 23:58:00 - mmengine - INFO - Saving checkpoint at 4 epochs
# 02/23 23:58:11 - mmengine - INFO - Epoch(val)   [4][ 50/135]    eta: 0:00:15  time: 0.1818  data_time: 0.0030  memory: 4705
# 02/23 23:58:17 - mmengine - INFO - Epoch(val)   [4][100/135]    eta: 0:00:05  time: 0.1101  data_time: 0.0018  memory: 552
# 02/23 23:58:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.16s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.046
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.071
# 02/23 23:58:38 - mmengine - INFO - bbox_mAP_copypaste: 0.021 0.059 0.011 0.007 0.041 0.020
# 02/23 23:58:38 - mmengine - INFO - Epoch(val) [4][135/135]    coco/bbox_mAP: 0.0210  coco/bbox_mAP_50: 0.0590  coco/bbox_mAP_75: 0.0110  coco/bbox_mAP_s: 0.0070  coco/bbox_mAP_m: 0.0410  coco/bbox_mAP_l: 0.0200  data_time: 0.0022  time: 0.1329
# 02/23 23:59:21 - mmengine - INFO - Epoch(train)   [5][ 50/236]  lr: 2.0000e-02  eta: 11:13:27  time: 0.8561  data_time: 0.0064  memory: 4705  loss: 1.6255  loss_rpn_cls: 0.3032  loss_rpn_bbox: 0.2346  loss_cls: 0.5271  acc: 79.8828  loss_bbox: 0.5605
# 02/23 23:59:26 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:00:04 - mmengine - INFO - Epoch(train)   [5][100/236]  lr: 2.0000e-02  eta: 11:12:20  time: 0.8638  data_time: 0.0048  memory: 4875  loss: 1.6514  loss_rpn_cls: 0.3071  loss_rpn_bbox: 0.2315  loss_cls: 0.5392  acc: 78.6133  loss_bbox: 0.5735
# 02/24 00:00:47 - mmengine - INFO - Epoch(train)   [5][150/236]  lr: 2.0000e-02  eta: 11:11:21  time: 0.8669  data_time: 0.0052  memory: 5124  loss: 1.6689  loss_rpn_cls: 0.3194  loss_rpn_bbox: 0.2392  loss_cls: 0.5392  acc: 83.3984  loss_bbox: 0.5710
# 02/24 00:01:31 - mmengine - INFO - Epoch(train)   [5][200/236]  lr: 2.0000e-02  eta: 11:10:33  time: 0.8713  data_time: 0.0065  memory: 4875  loss: 1.6366  loss_rpn_cls: 0.3183  loss_rpn_bbox: 0.2370  loss_cls: 0.5130  acc: 76.6602  loss_bbox: 0.5684
# 02/24 00:02:01 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:02:01 - mmengine - INFO - Saving checkpoint at 5 epochs
# 02/24 00:02:11 - mmengine - INFO - Epoch(val)   [5][ 50/135]    eta: 0:00:15  time: 0.1770  data_time: 0.0031  memory: 5116
# 02/24 00:02:17 - mmengine - INFO - Epoch(val)   [5][100/135]    eta: 0:00:04  time: 0.1065  data_time: 0.0020  memory: 552
# 02/24 00:02:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.72s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.075
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.110
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.144
# 02/24 00:02:36 - mmengine - INFO - bbox_mAP_copypaste: 0.031 0.084 0.016 0.007 0.057 0.075
# 02/24 00:02:36 - mmengine - INFO - Epoch(val) [5][135/135]    coco/bbox_mAP: 0.0310  coco/bbox_mAP_50: 0.0840  coco/bbox_mAP_75: 0.0160  coco/bbox_mAP_s: 0.0070  coco/bbox_mAP_m: 0.0570  coco/bbox_mAP_l: 0.0750  data_time: 0.0024  time: 0.1298
# 02/24 00:02:36 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_3.pth is removed
# 02/24 00:02:37 - mmengine - INFO - The best checkpoint with 0.0840 coco/bbox_mAP_50 at 5 epoch is saved to best_coco_bbox_mAP_50_epoch_5.pth.
# 02/24 00:03:24 - mmengine - INFO - Epoch(train)   [6][ 50/236]  lr: 2.0000e-02  eta: 11:09:02  time: 0.8955  data_time: 0.0061  memory: 5124  loss: 1.6103  loss_rpn_cls: 0.2817  loss_rpn_bbox: 0.2312  loss_cls: 0.5148  acc: 75.8789  loss_bbox: 0.5826
# 02/24 00:04:08 - mmengine - INFO - Epoch(train)   [6][100/236]  lr: 2.0000e-02  eta: 11:08:40  time: 0.8853  data_time: 0.0063  memory: 4875  loss: 1.6040  loss_rpn_cls: 0.2953  loss_rpn_bbox: 0.2261  loss_cls: 0.5227  acc: 77.9297  loss_bbox: 0.5599
# 02/24 00:04:52 - mmengine - INFO - Epoch(train)   [6][150/236]  lr: 2.0000e-02  eta: 11:07:50  time: 0.8702  data_time: 0.0056  memory: 5116  loss: 1.5657  loss_rpn_cls: 0.2768  loss_rpn_bbox: 0.2236  loss_cls: 0.5052  acc: 79.7852  loss_bbox: 0.5601
# 02/24 00:05:36 - mmengine - INFO - Epoch(train)   [6][200/236]  lr: 2.0000e-02  eta: 11:07:26  time: 0.8852  data_time: 0.0053  memory: 4875  loss: 1.6383  loss_rpn_cls: 0.3207  loss_rpn_bbox: 0.2353  loss_cls: 0.5201  acc: 76.9531  loss_bbox: 0.5622
# 02/24 00:06:05 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:06:05 - mmengine - INFO - Saving checkpoint at 6 epochs
# 02/24 00:06:12 - mmengine - INFO - Epoch(val)   [6][ 50/135]    eta: 0:00:08  time: 0.1042  data_time: 0.0024  memory: 4472
# 02/24 00:06:17 - mmengine - INFO - Epoch(val)   [6][100/135]    eta: 0:00:03  time: 0.0977  data_time: 0.0018  memory: 552
# 02/24 00:06:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.34s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.127
# 02/24 00:06:38 - mmengine - INFO - bbox_mAP_copypaste: 0.034 0.077 0.024 0.005 0.066 0.065
# 02/24 00:06:38 - mmengine - INFO - Epoch(val) [6][135/135]    coco/bbox_mAP: 0.0340  coco/bbox_mAP_50: 0.0770  coco/bbox_mAP_75: 0.0240  coco/bbox_mAP_s: 0.0050  coco/bbox_mAP_m: 0.0660  coco/bbox_mAP_l: 0.0650  data_time: 0.0020  time: 0.0995
# 02/24 00:07:21 - mmengine - INFO - Epoch(train)   [7][ 50/236]  lr: 2.0000e-02  eta: 11:04:50  time: 0.8661  data_time: 0.0050  memory: 5116  loss: 1.6160  loss_rpn_cls: 0.2911  loss_rpn_bbox: 0.2248  loss_cls: 0.5298  acc: 77.8320  loss_bbox: 0.5703
# 02/24 00:08:06 - mmengine - INFO - Epoch(train)   [7][100/236]  lr: 2.0000e-02  eta: 11:04:26  time: 0.8852  data_time: 0.0051  memory: 4875  loss: 1.5909  loss_rpn_cls: 0.2874  loss_rpn_bbox: 0.2307  loss_cls: 0.5138  acc: 78.7109  loss_bbox: 0.5590
# 02/24 00:08:49 - mmengine - INFO - Epoch(train)   [7][150/236]  lr: 2.0000e-02  eta: 11:03:48  time: 0.8766  data_time: 0.0055  memory: 4875  loss: 1.5694  loss_rpn_cls: 0.2814  loss_rpn_bbox: 0.2203  loss_cls: 0.5060  acc: 78.3203  loss_bbox: 0.5617
# 02/24 00:09:32 - mmengine - INFO - Epoch(train)   [7][200/236]  lr: 2.0000e-02  eta: 11:02:39  time: 0.8547  data_time: 0.0052  memory: 4697  loss: 1.5588  loss_rpn_cls: 0.2736  loss_rpn_bbox: 0.2192  loss_cls: 0.5122  acc: 77.8320  loss_bbox: 0.5537
# 02/24 00:10:02 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:10:02 - mmengine - INFO - Saving checkpoint at 7 epochs
# 02/24 00:10:09 - mmengine - INFO - Epoch(val)   [7][ 50/135]    eta: 0:00:08  time: 0.0984  data_time: 0.0026  memory: 5116
# 02/24 00:10:14 - mmengine - INFO - Epoch(val)   [7][100/135]    eta: 0:00:03  time: 0.0977  data_time: 0.0021  memory: 552
# 02/24 00:10:17 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.95s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.067
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.111
# 02/24 00:10:35 - mmengine - INFO - bbox_mAP_copypaste: 0.037 0.093 0.021 0.009 0.067 0.067
# 02/24 00:10:35 - mmengine - INFO - Epoch(val) [7][135/135]    coco/bbox_mAP: 0.0370  coco/bbox_mAP_50: 0.0930  coco/bbox_mAP_75: 0.0210  coco/bbox_mAP_s: 0.0090  coco/bbox_mAP_m: 0.0670  coco/bbox_mAP_l: 0.0670  data_time: 0.0022  time: 0.0979
# 02/24 00:10:35 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_5.pth is removed
# 02/24 00:10:37 - mmengine - INFO - The best checkpoint with 0.0930 coco/bbox_mAP_50 at 7 epoch is saved to best_coco_bbox_mAP_50_epoch_7.pth.
# 02/24 00:11:23 - mmengine - INFO - Epoch(train)   [8][ 50/236]  lr: 2.0000e-02  eta: 11:01:21  time: 0.8968  data_time: 0.0053  memory: 3996  loss: 1.5735  loss_rpn_cls: 0.2594  loss_rpn_bbox: 0.2212  loss_cls: 0.5151  acc: 79.8828  loss_bbox: 0.5777
# 02/24 00:12:06 - mmengine - INFO - Epoch(train)   [8][100/236]  lr: 2.0000e-02  eta: 11:00:25  time: 0.8620  data_time: 0.0062  memory: 4106  loss: 1.5532  loss_rpn_cls: 0.2673  loss_rpn_bbox: 0.2177  loss_cls: 0.5085  acc: 79.9805  loss_bbox: 0.5597
# 02/24 00:12:52 - mmengine - INFO - Epoch(train)   [8][150/236]  lr: 2.0000e-02  eta: 11:00:22  time: 0.9044  data_time: 0.0053  memory: 5124  loss: 1.5351  loss_rpn_cls: 0.2822  loss_rpn_bbox: 0.2220  loss_cls: 0.4941  acc: 85.9375  loss_bbox: 0.5368
# 02/24 00:13:34 - mmengine - INFO - Epoch(train)   [8][200/236]  lr: 2.0000e-02  eta: 10:58:59  time: 0.8407  data_time: 0.0050  memory: 3407  loss: 1.5591  loss_rpn_cls: 0.2640  loss_rpn_bbox: 0.2217  loss_cls: 0.5045  acc: 81.4453  loss_bbox: 0.5688
# 02/24 00:13:56 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:13:56 - mmengine - INFO - Saving checkpoint at 8 epochs
# 02/24 00:14:02 - mmengine - INFO - Epoch(val)   [8][ 50/135]    eta: 0:00:08  time: 0.0993  data_time: 0.0027  memory: 5124
# 02/24 00:14:11 - mmengine - INFO - Epoch(val)   [8][100/135]    eta: 0:00:04  time: 0.1670  data_time: 0.0026  memory: 552
# 02/24 00:14:17 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.81s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.172
# 02/24 00:14:34 - mmengine - INFO - bbox_mAP_copypaste: 0.032 0.077 0.021 0.008 0.060 0.063
# 02/24 00:14:34 - mmengine - INFO - Epoch(val) [8][135/135]    coco/bbox_mAP: 0.0320  coco/bbox_mAP_50: 0.0770  coco/bbox_mAP_75: 0.0210  coco/bbox_mAP_s: 0.0080  coco/bbox_mAP_m: 0.0600  coco/bbox_mAP_l: 0.0630  data_time: 0.0025  time: 0.1420
# 02/24 00:15:19 - mmengine - INFO - Epoch(train)   [9][ 50/236]  lr: 2.0000e-03  eta: 10:54:41  time: 0.8940  data_time: 0.0057  memory: 5124  loss: 1.5166  loss_rpn_cls: 0.2739  loss_rpn_bbox: 0.2136  loss_cls: 0.4899  acc: 79.1992  loss_bbox: 0.5392
# 02/24 00:16:02 - mmengine - INFO - Epoch(train)   [9][100/236]  lr: 2.0000e-03  eta: 10:53:56  time: 0.8662  data_time: 0.0055  memory: 4106  loss: 1.4508  loss_rpn_cls: 0.2441  loss_rpn_bbox: 0.1979  loss_cls: 0.4786  acc: 84.8633  loss_bbox: 0.5302
# 02/24 00:16:13 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:16:46 - mmengine - INFO - Epoch(train)   [9][150/236]  lr: 2.0000e-03  eta: 10:53:28  time: 0.8817  data_time: 0.0059  memory: 4099  loss: 1.3600  loss_rpn_cls: 0.1955  loss_rpn_bbox: 0.1808  loss_cls: 0.4520  acc: 80.0781  loss_bbox: 0.5316
# 02/24 00:17:28 - mmengine - INFO - Epoch(train)   [9][200/236]  lr: 2.0000e-03  eta: 10:52:08  time: 0.8346  data_time: 0.0050  memory: 5124  loss: 1.4314  loss_rpn_cls: 0.2204  loss_rpn_bbox: 0.1894  loss_cls: 0.4706  acc: 82.1289  loss_bbox: 0.5510
# 02/24 00:17:49 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 00:17:49 - mmengine - INFO - Saving checkpoint at 9 epochs
# 02/24 00:17:55 - mmengine - INFO - Epoch(val)   [9][ 50/135]    eta: 0:00:08  time: 0.1053  data_time: 0.0024  memory: 4867
# 02/24 00:18:04 - mmengine - INFO - Epoch(val)   [9][100/135]    eta: 0:00:04  time: 0.1719  data_time: 0.0021  memory: 552
# 02/24 00:18:10 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.50s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.024
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.356
# 02/24 05:46:11 - mmengine - INFO - bbox_mAP_copypaste: 0.082 0.171 0.067 0.023 0.143 0.233
# 02/24 05:46:11 - mmengine - INFO - Epoch(val) [157][135/135]    coco/bbox_mAP: 0.0820  coco/bbox_mAP_50: 0.1710  coco/bbox_mAP_75: 0.0670  coco/bbox_mAP_s: 0.0230  coco/bbox_mAP_m: 0.1430  coco/bbox_mAP_l: 0.2330  data_time: 0.0022  time: 0.0918
# 02/24 05:46:32 - mmengine - INFO - Epoch(train) [158][ 50/236]  lr: 2.0000e-04  eta: 1:17:06  time: 0.4150  data_time: 0.0052  memory: 4875  loss: 1.0038  loss_rpn_cls: 0.1126  loss_rpn_bbox: 0.1520  loss_cls: 0.3026  acc: 91.8945  loss_bbox: 0.4366
# 02/24 05:46:52 - mmengine - INFO - Epoch(train) [158][100/236]  lr: 2.0000e-04  eta: 1:16:43  time: 0.4144  data_time: 0.0041  memory: 4867  loss: 0.9616  loss_rpn_cls: 0.1031  loss_rpn_bbox: 0.1469  loss_cls: 0.2886  acc: 87.5000  loss_bbox: 0.4230
# 02/24 05:47:13 - mmengine - INFO - Epoch(train) [158][150/236]  lr: 2.0000e-04  eta: 1:16:19  time: 0.4106  data_time: 0.0041  memory: 4705  loss: 0.9428  loss_rpn_cls: 0.0928  loss_rpn_bbox: 0.1425  loss_cls: 0.2830  acc: 87.9883  loss_bbox: 0.4243
# 02/24 05:47:34 - mmengine - INFO - Epoch(train) [158][200/236]  lr: 2.0000e-04  eta: 1:15:56  time: 0.4217  data_time: 0.0041  memory: 5124  loss: 1.0022  loss_rpn_cls: 0.1221  loss_rpn_bbox: 0.1568  loss_cls: 0.3060  acc: 87.0117  loss_bbox: 0.4173
# 02/24 05:47:49 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:47:49 - mmengine - INFO - Saving checkpoint at 158 epochs
# 02/24 05:47:55 - mmengine - INFO - Epoch(val) [158][ 50/135]    eta: 0:00:07  time: 0.0928  data_time: 0.0024  memory: 5116
# 02/24 05:47:59 - mmengine - INFO - Epoch(val) [158][100/135]    eta: 0:00:03  time: 0.0917  data_time: 0.0018  memory: 552
# 02/24 05:48:03 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.95s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.350
# 02/24 05:48:18 - mmengine - INFO - bbox_mAP_copypaste: 0.081 0.168 0.068 0.023 0.142 0.229
# 02/24 05:48:18 - mmengine - INFO - Epoch(val) [158][135/135]    coco/bbox_mAP: 0.0810  coco/bbox_mAP_50: 0.1680  coco/bbox_mAP_75: 0.0680  coco/bbox_mAP_s: 0.0230  coco/bbox_mAP_m: 0.1420  coco/bbox_mAP_l: 0.2290  data_time: 0.0020  time: 0.0920
# 02/24 05:48:39 - mmengine - INFO - Epoch(train) [159][ 50/236]  lr: 2.0000e-04  eta: 1:15:16  time: 0.4124  data_time: 0.0053  memory: 4867  loss: 0.9843  loss_rpn_cls: 0.1009  loss_rpn_bbox: 0.1489  loss_cls: 0.2986  acc: 87.3047  loss_bbox: 0.4359
# 02/24 05:49:00 - mmengine - INFO - Epoch(train) [159][100/236]  lr: 2.0000e-04  eta: 1:14:52  time: 0.4170  data_time: 0.0041  memory: 5124  loss: 0.9841  loss_rpn_cls: 0.1166  loss_rpn_bbox: 0.1524  loss_cls: 0.2896  acc: 88.5742  loss_bbox: 0.4255
# 02/24 05:49:20 - mmengine - INFO - Epoch(train) [159][150/236]  lr: 2.0000e-04  eta: 1:14:29  time: 0.4162  data_time: 0.0041  memory: 4697  loss: 0.9900  loss_rpn_cls: 0.1120  loss_rpn_bbox: 0.1533  loss_cls: 0.2992  acc: 90.8203  loss_bbox: 0.4255
# 02/24 05:49:41 - mmengine - INFO - Epoch(train) [159][200/236]  lr: 2.0000e-04  eta: 1:14:05  time: 0.4160  data_time: 0.0041  memory: 4875  loss: 0.9400  loss_rpn_cls: 0.0978  loss_rpn_bbox: 0.1448  loss_cls: 0.2839  acc: 82.2266  loss_bbox: 0.4136
# 02/24 05:49:56 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:49:56 - mmengine - INFO - Saving checkpoint at 159 epochs
# 02/24 05:50:02 - mmengine - INFO - Epoch(val) [159][ 50/135]    eta: 0:00:07  time: 0.0929  data_time: 0.0023  memory: 4697
# 02/24 05:50:07 - mmengine - INFO - Epoch(val) [159][100/135]    eta: 0:00:03  time: 0.0918  data_time: 0.0019  memory: 552
# 02/24 05:50:10 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.73s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.143
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.118
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.348
# 02/24 05:50:25 - mmengine - INFO - bbox_mAP_copypaste: 0.082 0.170 0.068 0.023 0.143 0.232
# 02/24 05:50:25 - mmengine - INFO - Epoch(val) [159][135/135]    coco/bbox_mAP: 0.0820  coco/bbox_mAP_50: 0.1700  coco/bbox_mAP_75: 0.0680  coco/bbox_mAP_s: 0.0230  coco/bbox_mAP_m: 0.1430  coco/bbox_mAP_l: 0.2320  data_time: 0.0020  time: 0.0925
# 02/24 05:50:46 - mmengine - INFO - Epoch(train) [160][ 50/236]  lr: 2.0000e-04  eta: 1:13:25  time: 0.4160  data_time: 0.0056  memory: 4705  loss: 1.0115  loss_rpn_cls: 0.1122  loss_rpn_bbox: 0.1543  loss_cls: 0.3116  acc: 84.2773  loss_bbox: 0.4334
# 02/24 05:51:07 - mmengine - INFO - Epoch(train) [160][100/236]  lr: 2.0000e-04  eta: 1:13:02  time: 0.4167  data_time: 0.0042  memory: 5116  loss: 0.9878  loss_rpn_cls: 0.1140  loss_rpn_bbox: 0.1511  loss_cls: 0.2942  acc: 89.4531  loss_bbox: 0.4285
# 02/24 05:51:28 - mmengine - INFO - Epoch(train) [160][150/236]  lr: 2.0000e-04  eta: 1:12:38  time: 0.4170  data_time: 0.0040  memory: 5116  loss: 1.0213  loss_rpn_cls: 0.1169  loss_rpn_bbox: 0.1602  loss_cls: 0.3063  acc: 89.9414  loss_bbox: 0.4378
# 02/24 05:51:49 - mmengine - INFO - Epoch(train) [160][200/236]  lr: 2.0000e-04  eta: 1:12:15  time: 0.4164  data_time: 0.0043  memory: 4875  loss: 0.9168  loss_rpn_cls: 0.1001  loss_rpn_bbox: 0.1410  loss_cls: 0.2766  acc: 90.7227  loss_bbox: 0.3992
# 02/24 05:52:04 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:52:04 - mmengine - INFO - Saving checkpoint at 160 epochs
# 02/24 05:52:10 - mmengine - INFO - Epoch(val) [160][ 50/135]    eta: 0:00:07  time: 0.0927  data_time: 0.0027  memory: 4875
# 02/24 05:52:15 - mmengine - INFO - Epoch(val) [160][100/135]    eta: 0:00:03  time: 0.0921  data_time: 0.0019  memory: 552
# 02/24 05:52:18 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.77s).
# Accumulating evaluation results...
# DONE (t=0.26s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.234
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.349
# 02/24 05:52:33 - mmengine - INFO - bbox_mAP_copypaste: 0.084 0.175 0.069 0.024 0.146 0.234
# 02/24 05:52:33 - mmengine - INFO - Epoch(val) [160][135/135]    coco/bbox_mAP: 0.0840  coco/bbox_mAP_50: 0.1750  coco/bbox_mAP_75: 0.0690  coco/bbox_mAP_s: 0.0240  coco/bbox_mAP_m: 0.1460  coco/bbox_mAP_l: 0.2340  data_time: 0.0022  time: 0.0921
# 02/24 05:52:33 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_152.pth is removed
# 02/24 05:52:34 - mmengine - INFO - The best checkpoint with 0.1750 coco/bbox_mAP_50 at 160 epoch is saved to best_coco_bbox_mAP_50_epoch_160.pth.
# 02/24 05:52:56 - mmengine - INFO - Epoch(train) [161][ 50/236]  lr: 2.0000e-04  eta: 1:11:34  time: 0.4136  data_time: 0.0046  memory: 4875  loss: 0.9673  loss_rpn_cls: 0.1128  loss_rpn_bbox: 0.1495  loss_cls: 0.2895  acc: 83.4961  loss_bbox: 0.4156
# 02/24 05:53:17 - mmengine - INFO - Epoch(train) [161][100/236]  lr: 2.0000e-04  eta: 1:11:11  time: 0.4171  data_time: 0.0042  memory: 5124  loss: 1.0116  loss_rpn_cls: 0.1244  loss_rpn_bbox: 0.1593  loss_cls: 0.3011  acc: 91.3086  loss_bbox: 0.4269
# 02/24 05:53:38 - mmengine - INFO - Epoch(train) [161][150/236]  lr: 2.0000e-04  eta: 1:10:48  time: 0.4156  data_time: 0.0041  memory: 4867  loss: 0.9552  loss_rpn_cls: 0.0993  loss_rpn_bbox: 0.1477  loss_cls: 0.2883  acc: 84.2773  loss_bbox: 0.4198
# 02/24 05:53:59 - mmengine - INFO - Epoch(train) [161][200/236]  lr: 2.0000e-04  eta: 1:10:24  time: 0.4205  data_time: 0.0042  memory: 4867  loss: 0.9743  loss_rpn_cls: 0.1031  loss_rpn_bbox: 0.1493  loss_cls: 0.2951  acc: 86.5234  loss_bbox: 0.4268
# 02/24 05:54:14 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:54:14 - mmengine - INFO - Saving checkpoint at 161 epochs
# 02/24 05:54:20 - mmengine - INFO - Epoch(val) [161][ 50/135]    eta: 0:00:07  time: 0.0918  data_time: 0.0023  memory: 3629
# 02/24 05:54:24 - mmengine - INFO - Epoch(val) [161][100/135]    eta: 0:00:03  time: 0.0905  data_time: 0.0018  memory: 552
# 02/24 05:54:27 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.11s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.348
# 02/24 05:54:43 - mmengine - INFO - bbox_mAP_copypaste: 0.084 0.175 0.069 0.024 0.145 0.235
# 02/24 05:54:43 - mmengine - INFO - Epoch(val) [161][135/135]    coco/bbox_mAP: 0.0840  coco/bbox_mAP_50: 0.1750  coco/bbox_mAP_75: 0.0690  coco/bbox_mAP_s: 0.0240  coco/bbox_mAP_m: 0.1450  coco/bbox_mAP_l: 0.2350  data_time: 0.0020  time: 0.0907
# 02/24 05:54:45 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:55:04 - mmengine - INFO - Epoch(train) [162][ 50/236]  lr: 2.0000e-04  eta: 1:09:44  time: 0.4146  data_time: 0.0046  memory: 4867  loss: 0.9712  loss_rpn_cls: 0.1122  loss_rpn_bbox: 0.1505  loss_cls: 0.2887  acc: 93.1641  loss_bbox: 0.4197
# 02/24 05:55:24 - mmengine - INFO - Epoch(train) [162][100/236]  lr: 2.0000e-04  eta: 1:09:21  time: 0.4137  data_time: 0.0044  memory: 4099  loss: 0.9318  loss_rpn_cls: 0.0960  loss_rpn_bbox: 0.1412  loss_cls: 0.2807  acc: 90.2344  loss_bbox: 0.4139
# 02/24 05:55:45 - mmengine - INFO - Epoch(train) [162][150/236]  lr: 2.0000e-04  eta: 1:08:57  time: 0.4178  data_time: 0.0040  memory: 5116  loss: 1.0023  loss_rpn_cls: 0.1164  loss_rpn_bbox: 0.1568  loss_cls: 0.2985  acc: 87.4023  loss_bbox: 0.4306
# 02/24 05:56:06 - mmengine - INFO - Epoch(train) [162][200/236]  lr: 2.0000e-04  eta: 1:08:34  time: 0.4135  data_time: 0.0041  memory: 4106  loss: 0.9766  loss_rpn_cls: 0.1026  loss_rpn_bbox: 0.1501  loss_cls: 0.2917  acc: 90.7227  loss_bbox: 0.4323
# 02/24 05:56:21 - mmengine - INFO - Exp name: custom-dynamic-rcnn_r50_fpn_1x_coco_20240223_234146
# 02/24 05:56:21 - mmengine - INFO - Saving checkpoint at 162 epochs
# 02/24 05:56:27 - mmengine - INFO - Epoch(val) [162][ 50/135]    eta: 0:00:07  time: 0.0916  data_time: 0.0028  memory: 4875
# 02/24 05:56:31 - mmengine - INFO - Epoch(val) [162][100/135]    eta: 0:00:03  time: 0.0917  data_time: 0.0018  memory: 552
# 02/24 05:56:35 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.01s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.144
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.348
# 02/24 05:56:50 - mmengine - INFO - bbox_mAP_copypaste: 0.084 0.174 0.071 0.025 0.144 0.238
# 02/24 05:56:50 - mmengine - INFO - Epoch(val) [162][135/135]    coco/bbox_mAP: 0.0840  coco/bbox_mAP_50: 0.1740  coco/bbox_mAP_75: 0.0710  coco/bbox_mAP_s: 0.0250  coco/bbox_mAP_m: 0.1440  coco/bbox_mAP_l: 0.2380  data_time: 0.0022  time: 0.0912

# %%
CONFIDENCE_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

def callback(image: np.ndarray) -> sv.Detections:
    result = inference_detector(model, image)
    detections = sv.Detections.from_mmdetection(result)
    return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)


mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset = ds,
    callback = callback
)

print('mAP:', mean_average_precision.map50_95)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_44.pth
# mAP: 0.24204132435625836

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-dynamic-rcnn_r50_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_156.pth
# |   iter    |  target   | confid... | nms_io... |
# -------------------------------------------------
# | 1         | 0.2901    | 0.4371    | 0.9556    |
# | 2         | 0.3281    | 0.7588    | 0.6388    |
# | 3         | 0.2855    | 0.2404    | 0.2404    |
# | 4         | 0.2646    | 0.1523    | 0.8796    |
# | 5         | 0.3083    | 0.641     | 0.7373    |
# | 6         | 0.3012    | 0.9972    | 0.6058    |
# | 7         | 0.3222    | 0.713     | 0.4773    |
# | 8         | 0.3516    | 0.8623    | 0.1426    |
# | 9         | 0.347     | 0.8521    | 0.1611    |
# | 10        | 0.0       | 1.0       | 0.1       |
# | 11        | 0.2768    | 0.1292    | 0.2937    |
# | 12        | 0.2961    | 0.4976    | 0.8419    |
# | 13        | 0.3436    | 0.7896    | 0.1       |
# | 14        | 0.3097    | 0.6447    | 0.5877    |
# | 15        | 0.3435    | 0.8349    | 0.5346    |
# | 16        | 0.3177    | 0.6437    | 0.2365    |
# | 17        | 0.3425    | 0.842     | 0.4159    |
# | 18        | 0.3734    | 0.9517    | 0.4566    |
# | 19        | 0.3901    | 0.9683    | 0.3605    |
# | 20        | 0.3562    | 0.8861    | 0.3117    |
# | 21        | 0.3434    | 0.8523    | 0.8264    |
# | 22        | 0.355     | 0.8864    | 0.9758    |
# | 23        | 0.3431    | 0.8373    | 0.7127    |
# | 24        | 0.3008    | 0.5519    | 0.7047    |
# | 25        | 0.0       | 1.0       | 0.8924    |
# | 26        | 0.3302    | 0.7749    | 0.9549    |
# | 27        | 0.3268    | 0.7479    | 0.8191    |
# | 28        | 0.3041    | 0.5155    | 0.3919    |
# | 29        | 0.3244    | 0.6833    | 0.2055    |
# | 30        | 0.3127    | 0.5109    | 0.1       |
# | 31        | 0.2743    | 0.3076    | 0.5687    |
# | 32        | 0.3057    | 0.4266    | 0.1591    |
# | 33        | 0.3465    | 0.8361    | 0.2943    |
# | 34        | 0.3628    | 0.928     | 0.8193    |
# | 35        | 0.3635    | 0.9275    | 0.7451    |
# | 36        | 0.3659    | 0.9167    | 0.3959    |
# | 37        | 0.3263    | 0.7241    | 0.3452    |
# | 38        | 0.3812    | 0.9931    | 0.9738    |
# | 39        | 0.3919    | 0.9888    | 0.41      |
# | 40        | 0.2709    | 0.2347    | 0.5059    |
# | 41        | 0.3684    | 0.9494    | 0.9992    |
# | 42        | 0.3631    | 0.8968    | 0.235     |
# | 43        | 0.3176    | 0.6613    | 0.3765    |
# | 44        | 0.3913    | 0.9689    | 0.2873    |
# | 45        | 0.3493    | 0.8737    | 0.318     |
# | 46        | 0.3475    | 0.8243    | 0.1256    |
# | 47        | 0.3103    | 0.6455    | 1.0       |
# | 48        | 0.2901    | 0.4414    | 0.9469    |
# | 49        | 0.318     | 0.691     | 0.8816    |
# | 50        | 0.2818    | 0.1       | 0.1       |
# =================================================
# Best mAP: 0.3919255123191302
# Best Parameters: [0.9887553301985857, 0.40998158430303316]
