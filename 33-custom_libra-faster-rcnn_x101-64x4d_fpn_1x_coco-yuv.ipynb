# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Sun Feb 25 01:13:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:AF:00.0 Off |                    0 |
# | N/A   66C    P0              70W /  70W |   1943MiB / 15360MiB |     94%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     82002      C   /work/van-speech-nlp/jenv/bin/python        688MiB |
# |    0   N/A  N/A     83989      C   /work/van-speech-nlp/jenv/bin/python       1250MiB |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# 2024-02-25 01:13:48.566607: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-25 01:13:48.614943: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-25 01:13:48.614973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-25 01:13:48.616078: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-25 01:13:48.624116: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-25 01:13:51.872665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# set seed successfully

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="libra_rcnn"
dataset_location=f"/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv"
base_model_name="libra-faster-rcnn_x101-64x4d_fpn_1x_coco"
custom_model_name=f"custom-{base_model_name}-yuv"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
print(CUSTOM_CONFIG_PATH)


CUSTOM_CONFIG = f"""
_base_ = './{base_model_name}.py'

# ========================Frequently modified parameters======================
# -----data related-----
model = dict(
    roi_head=dict(
        bbox_head=dict(num_classes={num_classes}),
))

dataset_type = 'COCODataset'
classes =  {classes}

data_root = '{dataset_location}' # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = {classes} 
num_classes = {num_classes}  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = {BATCH_SIZE}  # Batch size per GPU during training
#train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = {MAX_EPOCHS}  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image


# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=15,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    #samples_per_gpu=1,
    #workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/_annotations.coco.json.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 8
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)
"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/configs/libra_rcnn/custom-libra-faster-rcnn_x101-64x4d_fpn_1x_coco-yuv.py

# %%
## !python tools/train.py configs/ssd/costom_ssd512.py --resume | tee ../OUT_ssd.txt
# !python tools/train.py configs/libra_rcnn/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco.py | tee ../OUT_libra.txt
# Out:
# 02/25 01:14:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1001674367
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1001674367
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/25 01:14:06 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=32,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     samples_per_gpu=8,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/annotation_coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'),
#     workers_per_gpu=2)
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv/'
# dataset_type = 'COCODataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_begin=100,
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 200
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=64,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_64x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=[
#         dict(
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#                 2048,
#             ],
#             num_outs=5,
#             out_channels=256,
#             type='FPN'),
#         dict(
#             in_channels=256,
#             num_levels=5,
#             refine_level=2,
#             refine_type='non_local',
#             type='BFP'),
#     ],
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(
#                 alpha=0.5,
#                 beta=1.0,
#                 gamma=1.5,
#                 loss_weight=1.0,
#                 type='BalancedL1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=80,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_sampler=dict(
#                     floor_fraction=0,
#                     floor_thr=-1,
#                     num_bins=3,
#                     type='IoUBalancedNegSampler'),
#                 num=512,
#                 pos_fraction=0.25,
#                 pos_sampler=dict(type='InstanceBalancedPosSampler'),
#                 type='CombinedSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=5,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# norm_cfg = dict(type='BN')
# num_classes = 4
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = False
# save_checkpoint_intervals = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_batch_size_per_gpu = 8
# train_cfg = dict(max_epochs=200, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_num_workers = 4
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_batch_size_per_gpu = 32
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# work_dir = './work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco'
#
# 02/25 01:14:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/25 01:14:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.51s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/25 01:14:14 - mmengine - INFO - load model from: open-mmlab://resnext101_64x4d
# 02/25 01:14:14 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_64x4d
# 02/25 01:14:16 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/25 01:14:16 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/25 01:14:16 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco.
# 02/25 01:17:00 - mmengine - INFO - Epoch(train)   [1][ 50/236]  lr: 1.9820e-03  eta: 1 day, 19:05:47  time: 3.2905  data_time: 0.0114  memory: 9411  loss: 2.4967  loss_rpn_cls: 0.6590  loss_rpn_bbox: 0.3346  loss_cls: 1.3374  acc: 78.7109  loss_bbox: 0.1656
# 02/25 01:19:17 - mmengine - INFO - Epoch(train)   [1][100/236]  lr: 3.9840e-03  eta: 1 day, 15:26:48  time: 2.7396  data_time: 0.0053  memory: 8034  loss: 1.6506  loss_rpn_cls: 0.6021  loss_rpn_bbox: 0.3120  loss_cls: 0.5063  acc: 87.1094  loss_bbox: 0.2303
# 02/25 01:21:41 - mmengine - INFO - Epoch(train)   [1][150/236]  lr: 5.9860e-03  eta: 1 day, 14:49:52  time: 2.8834  data_time: 0.0049  memory: 9050  loss: 1.8795  loss_rpn_cls: 0.6101  loss_rpn_bbox: 0.3146  loss_cls: 0.6940  acc: 78.7109  loss_bbox: 0.2608
# 02/25 01:22:47 - mmengine - INFO - Epoch(train)   [1][200/236]  lr: 7.9880e-03  eta: 1 day, 9:22:01  time: 1.3097  data_time: 0.0041  memory: 8801  loss: 2.0048  loss_rpn_cls: 0.5312  loss_rpn_bbox: 0.3009  loss_cls: 0.7016  acc: 76.9531  loss_bbox: 0.4711
# 02/25 01:23:35 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:23:46 - mmengine - INFO - Epoch(val)   [1][ 50/135]    eta: 0:00:17  time: 0.2018  data_time: 0.0082  memory: 11744
# 02/25 01:23:55 - mmengine - INFO - Epoch(val)   [1][100/135]    eta: 0:00:06  time: 0.1963  data_time: 0.0019  memory: 1018
# 02/25 01:24:02 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.12s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.031
# 02/25 01:24:20 - mmengine - INFO - bbox_mAP_copypaste: 0.002 0.011 0.000 0.002 0.003 0.004
# 02/25 01:24:20 - mmengine - INFO - Epoch(val) [1][135/135]    coco/bbox_mAP: 0.0020  coco/bbox_mAP_50: 0.0110  coco/bbox_mAP_75: 0.0000  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0030  coco/bbox_mAP_l: 0.0040  data_time: 0.0042  time: 0.1982
# 02/25 01:24:21 - mmengine - INFO - The best checkpoint with 0.0110 coco/bbox_mAP_50 at 1 epoch is saved to best_coco_bbox_mAP_50_epoch_1.pth.
# 02/25 01:25:20 - mmengine - INFO - Epoch(train)   [2][ 50/236]  lr: 1.1431e-02  eta: 1 day, 4:10:42  time: 1.1731  data_time: 0.0047  memory: 8629  loss: 1.8503  loss_rpn_cls: 0.4290  loss_rpn_bbox: 0.2752  loss_cls: 0.6112  acc: 76.3672  loss_bbox: 0.5350
# 02/25 01:26:19 - mmengine - INFO - Epoch(train)   [2][100/236]  lr: 1.3433e-02  eta: 1 day, 2:14:15  time: 1.1760  data_time: 0.0040  memory: 8806  loss: 1.8038  loss_rpn_cls: 0.3920  loss_rpn_bbox: 0.2738  loss_cls: 0.5859  acc: 77.2461  loss_bbox: 0.5521
# 02/25 01:27:18 - mmengine - INFO - Epoch(train)   [2][150/236]  lr: 1.5435e-02  eta: 1 day, 0:48:35  time: 1.1845  data_time: 0.0041  memory: 9047  loss: 1.8321  loss_rpn_cls: 0.4515  loss_rpn_bbox: 0.3000  loss_cls: 0.5836  acc: 76.6602  loss_bbox: 0.4969
# 02/25 01:28:17 - mmengine - INFO - Epoch(train)   [2][200/236]  lr: 1.7437e-02  eta: 23:42:09  time: 1.1824  data_time: 0.0040  memory: 9047  loss: 1.8465  loss_rpn_cls: 0.4189  loss_rpn_bbox: 0.2911  loss_cls: 0.5809  acc: 77.5391  loss_bbox: 0.5556
# 02/25 01:28:59 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:29:09 - mmengine - INFO - Epoch(val)   [2][ 50/135]    eta: 0:00:16  time: 0.1976  data_time: 0.0024  memory: 8806
# 02/25 01:29:19 - mmengine - INFO - Epoch(val)   [2][100/135]    eta: 0:00:06  time: 0.1972  data_time: 0.0019  memory: 1021
# 02/25 01:29:26 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.67s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.043
# 02/25 01:29:43 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.027 0.007 0.003 0.022 0.013
# 02/25 01:29:43 - mmengine - INFO - Epoch(val) [2][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0270  coco/bbox_mAP_75: 0.0070  coco/bbox_mAP_s: 0.0030  coco/bbox_mAP_m: 0.0220  coco/bbox_mAP_l: 0.0130  data_time: 0.0021  time: 0.1972
# 02/25 01:29:43 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_1.pth is removed
# 02/25 01:29:45 - mmengine - INFO - The best checkpoint with 0.0270 coco/bbox_mAP_50 at 2 epoch is saved to best_coco_bbox_mAP_50_epoch_2.pth.
# 02/25 01:30:43 - mmengine - INFO - Epoch(train)   [3][ 50/236]  lr: 2.0000e-02  eta: 22:15:28  time: 1.1704  data_time: 0.0048  memory: 8635  loss: 1.8166  loss_rpn_cls: 0.3909  loss_rpn_bbox: 0.2791  loss_cls: 0.5929  acc: 77.8320  loss_bbox: 0.5537
# 02/25 01:31:42 - mmengine - INFO - Epoch(train)   [3][100/236]  lr: 2.0000e-02  eta: 21:37:26  time: 1.1779  data_time: 0.0039  memory: 9047  loss: 1.7417  loss_rpn_cls: 0.3802  loss_rpn_bbox: 0.2663  loss_cls: 0.5560  acc: 78.3203  loss_bbox: 0.5392
# 02/25 01:32:41 - mmengine - INFO - Epoch(train)   [3][150/236]  lr: 2.0000e-02  eta: 21:05:31  time: 1.1803  data_time: 0.0040  memory: 8797  loss: 1.7159  loss_rpn_cls: 0.3590  loss_rpn_bbox: 0.2685  loss_cls: 0.5506  acc: 78.9062  loss_bbox: 0.5378
# 02/25 01:33:40 - mmengine - INFO - Epoch(train)   [3][200/236]  lr: 2.0000e-02  eta: 20:38:17  time: 1.1819  data_time: 0.0040  memory: 8410  loss: 1.6921  loss_rpn_cls: 0.3366  loss_rpn_bbox: 0.2540  loss_cls: 0.5686  acc: 78.0273  loss_bbox: 0.5328
# 02/25 01:34:23 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:34:32 - mmengine - INFO - Epoch(val)   [3][ 50/135]    eta: 0:00:16  time: 0.1965  data_time: 0.0028  memory: 9056
# 02/25 01:34:42 - mmengine - INFO - Epoch(val)   [3][100/135]    eta: 0:00:06  time: 0.1970  data_time: 0.0019  memory: 1021
# 02/25 01:34:49 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.72s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.109
# 02/25 01:35:05 - mmengine - INFO - bbox_mAP_copypaste: 0.017 0.047 0.009 0.005 0.037 0.026
# 02/25 01:35:05 - mmengine - INFO - Epoch(val) [3][135/135]    coco/bbox_mAP: 0.0170  coco/bbox_mAP_50: 0.0470  coco/bbox_mAP_75: 0.0090  coco/bbox_mAP_s: 0.0050  coco/bbox_mAP_m: 0.0370  coco/bbox_mAP_l: 0.0260  data_time: 0.0022  time: 0.1967
# 02/25 01:35:05 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_2.pth is removed
# 02/25 01:35:07 - mmengine - INFO - The best checkpoint with 0.0470 coco/bbox_mAP_50 at 3 epoch is saved to best_coco_bbox_mAP_50_epoch_3.pth.
# 02/25 01:36:06 - mmengine - INFO - Epoch(train)   [4][ 50/236]  lr: 2.0000e-02  eta: 19:58:38  time: 1.1729  data_time: 0.0056  memory: 9056  loss: 1.7120  loss_rpn_cls: 0.3215  loss_rpn_bbox: 0.2542  loss_cls: 0.5685  acc: 78.1250  loss_bbox: 0.5677
# 02/25 01:37:04 - mmengine - INFO - Epoch(train)   [4][100/236]  lr: 2.0000e-02  eta: 19:39:04  time: 1.1665  data_time: 0.0040  memory: 7996  loss: 1.6916  loss_rpn_cls: 0.3269  loss_rpn_bbox: 0.2473  loss_cls: 0.5578  acc: 82.5195  loss_bbox: 0.5596
# 02/25 01:38:03 - mmengine - INFO - Epoch(train)   [4][150/236]  lr: 2.0000e-02  eta: 19:22:09  time: 1.1775  data_time: 0.0040  memory: 8797  loss: 1.6651  loss_rpn_cls: 0.3333  loss_rpn_bbox: 0.2477  loss_cls: 0.5433  acc: 77.5391  loss_bbox: 0.5408
# 02/25 01:39:02 - mmengine - INFO - Epoch(train)   [4][200/236]  lr: 2.0000e-02  eta: 19:07:08  time: 1.1804  data_time: 0.0042  memory: 9047  loss: 1.6217  loss_rpn_cls: 0.3205  loss_rpn_bbox: 0.2408  loss_cls: 0.5517  acc: 79.1992  loss_bbox: 0.5087
# 02/25 01:39:44 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:39:54 - mmengine - INFO - Epoch(val)   [4][ 50/135]    eta: 0:00:16  time: 0.1975  data_time: 0.0024  memory: 8037
# 02/25 01:40:04 - mmengine - INFO - Epoch(val)   [4][100/135]    eta: 0:00:06  time: 0.1984  data_time: 0.0019  memory: 1021
# 02/25 01:40:11 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.03s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.080
# 02/25 01:40:27 - mmengine - INFO - bbox_mAP_copypaste: 0.013 0.033 0.008 0.006 0.042 0.009
# 02/25 01:40:27 - mmengine - INFO - Epoch(val) [4][135/135]    coco/bbox_mAP: 0.0130  coco/bbox_mAP_50: 0.0330  coco/bbox_mAP_75: 0.0080  coco/bbox_mAP_s: 0.0060  coco/bbox_mAP_m: 0.0420  coco/bbox_mAP_l: 0.0090  data_time: 0.0021  time: 0.1981
# 02/25 01:41:26 - mmengine - INFO - Epoch(train)   [5][ 50/236]  lr: 2.0000e-02  eta: 18:44:04  time: 1.1755  data_time: 0.0048  memory: 9047  loss: 1.6418  loss_rpn_cls: 0.3241  loss_rpn_bbox: 0.2450  loss_cls: 0.5448  acc: 80.0781  loss_bbox: 0.5280
# 02/25 01:41:33 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:42:25 - mmengine - INFO - Epoch(train)   [5][100/236]  lr: 2.0000e-02  eta: 18:32:27  time: 1.1772  data_time: 0.0039  memory: 8806  loss: 1.5970  loss_rpn_cls: 0.3197  loss_rpn_bbox: 0.2515  loss_cls: 0.5226  acc: 76.3672  loss_bbox: 0.5033
# 02/25 01:43:24 - mmengine - INFO - Epoch(train)   [5][150/236]  lr: 2.0000e-02  eta: 18:22:01  time: 1.1834  data_time: 0.0043  memory: 8806  loss: 1.6017  loss_rpn_cls: 0.3141  loss_rpn_bbox: 0.2426  loss_cls: 0.5258  acc: 80.7617  loss_bbox: 0.5192
# 02/25 01:44:23 - mmengine - INFO - Epoch(train)   [5][200/236]  lr: 2.0000e-02  eta: 18:12:13  time: 1.1776  data_time: 0.0041  memory: 9056  loss: 1.5812  loss_rpn_cls: 0.2940  loss_rpn_bbox: 0.2301  loss_cls: 0.5260  acc: 79.1992  loss_bbox: 0.5311
# 02/25 01:45:05 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:45:15 - mmengine - INFO - Epoch(val)   [5][ 50/135]    eta: 0:00:16  time: 0.1974  data_time: 0.0029  memory: 8627
# 02/25 01:45:25 - mmengine - INFO - Epoch(val)   [5][100/135]    eta: 0:00:06  time: 0.1976  data_time: 0.0019  memory: 1021
# 02/25 01:45:32 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.09s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.108
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.073
# 02/25 01:45:47 - mmengine - INFO - bbox_mAP_copypaste: 0.027 0.068 0.016 0.011 0.059 0.015
# 02/25 01:45:47 - mmengine - INFO - Epoch(val) [5][135/135]    coco/bbox_mAP: 0.0270  coco/bbox_mAP_50: 0.0680  coco/bbox_mAP_75: 0.0160  coco/bbox_mAP_s: 0.0110  coco/bbox_mAP_m: 0.0590  coco/bbox_mAP_l: 0.0150  data_time: 0.0023  time: 0.1973
# 02/25 01:45:47 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_3.pth is removed
# 02/25 01:45:49 - mmengine - INFO - The best checkpoint with 0.0680 coco/bbox_mAP_50 at 5 epoch is saved to best_coco_bbox_mAP_50_epoch_5.pth.
# 02/25 01:46:48 - mmengine - INFO - Epoch(train)   [6][ 50/236]  lr: 2.0000e-02  eta: 17:56:36  time: 1.1754  data_time: 0.0055  memory: 8806  loss: 1.5725  loss_rpn_cls: 0.2882  loss_rpn_bbox: 0.2359  loss_cls: 0.5122  acc: 81.1523  loss_bbox: 0.5361
# 02/25 01:47:46 - mmengine - INFO - Epoch(train)   [6][100/236]  lr: 2.0000e-02  eta: 17:48:35  time: 1.1762  data_time: 0.0042  memory: 8410  loss: 1.5474  loss_rpn_cls: 0.2875  loss_rpn_bbox: 0.2367  loss_cls: 0.5077  acc: 71.6797  loss_bbox: 0.5154
# 02/25 01:48:45 - mmengine - INFO - Epoch(train)   [6][150/236]  lr: 2.0000e-02  eta: 17:41:15  time: 1.1814  data_time: 0.0044  memory: 8029  loss: 1.5640  loss_rpn_cls: 0.2885  loss_rpn_bbox: 0.2328  loss_cls: 0.5210  acc: 81.0547  loss_bbox: 0.5217
# 02/25 01:49:45 - mmengine - INFO - Epoch(train)   [6][200/236]  lr: 2.0000e-02  eta: 17:34:21  time: 1.1806  data_time: 0.0042  memory: 9047  loss: 1.5576  loss_rpn_cls: 0.2822  loss_rpn_bbox: 0.2239  loss_cls: 0.5167  acc: 78.9062  loss_bbox: 0.5348
# 02/25 01:50:27 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:50:37 - mmengine - INFO - Epoch(val)   [6][ 50/135]    eta: 0:00:16  time: 0.1982  data_time: 0.0028  memory: 9056
# 02/25 01:50:46 - mmengine - INFO - Epoch(val)   [6][100/135]    eta: 0:00:06  time: 0.1969  data_time: 0.0018  memory: 1021
# 02/25 01:50:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.31s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.013
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.103
# 02/25 01:51:09 - mmengine - INFO - bbox_mAP_copypaste: 0.013 0.033 0.008 0.005 0.040 0.013
# 02/25 01:51:09 - mmengine - INFO - Epoch(val) [6][135/135]    coco/bbox_mAP: 0.0130  coco/bbox_mAP_50: 0.0330  coco/bbox_mAP_75: 0.0080  coco/bbox_mAP_s: 0.0050  coco/bbox_mAP_m: 0.0400  coco/bbox_mAP_l: 0.0130  data_time: 0.0022  time: 0.1971
# 02/25 01:52:08 - mmengine - INFO - Epoch(train)   [7][ 50/236]  lr: 2.0000e-02  eta: 17:23:13  time: 1.1804  data_time: 0.0047  memory: 9056  loss: 1.5470  loss_rpn_cls: 0.2951  loss_rpn_bbox: 0.2426  loss_cls: 0.5185  acc: 80.6641  loss_bbox: 0.4908
# 02/25 01:53:07 - mmengine - INFO - Epoch(train)   [7][100/236]  lr: 2.0000e-02  eta: 17:17:13  time: 1.1750  data_time: 0.0041  memory: 9047  loss: 1.5206  loss_rpn_cls: 0.2681  loss_rpn_bbox: 0.2189  loss_cls: 0.5175  acc: 84.7656  loss_bbox: 0.5162
# 02/25 01:54:05 - mmengine - INFO - Epoch(train)   [7][150/236]  lr: 2.0000e-02  eta: 17:11:29  time: 1.1731  data_time: 0.0042  memory: 8627  loss: 1.5265  loss_rpn_cls: 0.2598  loss_rpn_bbox: 0.2242  loss_cls: 0.4987  acc: 78.3203  loss_bbox: 0.5439
# 02/25 01:55:04 - mmengine - INFO - Epoch(train)   [7][200/236]  lr: 2.0000e-02  eta: 17:06:04  time: 1.1742  data_time: 0.0042  memory: 8806  loss: 1.5316  loss_rpn_cls: 0.2702  loss_rpn_bbox: 0.2230  loss_cls: 0.5043  acc: 77.4414  loss_bbox: 0.5341
# 02/25 01:55:46 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 01:55:56 - mmengine - INFO - Epoch(val)   [7][ 50/135]    eta: 0:00:16  time: 0.1981  data_time: 0.0029  memory: 8797
# 02/25 01:56:06 - mmengine - INFO - Epoch(val)   [7][100/135]    eta: 0:00:06  time: 0.1978  data_time: 0.0019  memory: 1021
# 02/25 01:56:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.31s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.134
# 02/25 01:56:29 - mmengine - INFO - bbox_mAP_copypaste: 0.040 0.097 0.028 0.013 0.079 0.054
# 02/25 01:56:29 - mmengine - INFO - Epoch(val) [7][135/135]    coco/bbox_mAP: 0.0400  coco/bbox_mAP_50: 0.0970  coco/bbox_mAP_75: 0.0280  coco/bbox_mAP_s: 0.0130  coco/bbox_mAP_m: 0.0790  coco/bbox_mAP_l: 0.0540  data_time: 0.0023  time: 0.1979
# 02/25 01:56:29 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco/best_coco_bbox_mAP_50_epoch_5.pth is removed
# 02/25 01:56:31 - mmengine - INFO - The best checkpoint with 0.0970 coco/bbox_mAP_50 at 7 epoch is saved to best_coco_bbox_mAP_50_epoch_7.pth.
# 02/25 01:57:29 - mmengine - INFO - Epoch(train)   [8][ 50/236]  lr: 2.0000e-02  eta: 16:57:13  time: 1.1715  data_time: 0.0057  memory: 7853  loss: 1.5124  loss_rpn_cls: 0.2498  loss_rpn_bbox: 0.2263  loss_cls: 0.4991  acc: 80.7617  loss_bbox: 0.5371
# 02/25 01:58:28 - mmengine - INFO - Epoch(train)   [8][100/236]  lr: 2.0000e-02  eta: 16:52:23  time: 1.1699  data_time: 0.0042  memory: 8402  loss: 1.4513  loss_rpn_cls: 0.2442  loss_rpn_bbox: 0.2081  loss_cls: 0.4826  acc: 81.2500  loss_bbox: 0.5164
# 02/25 01:59:27 - mmengine - INFO - Epoch(train)   [8][150/236]  lr: 2.0000e-02  eta: 16:47:55  time: 1.1765  data_time: 0.0040  memory: 8797  loss: 1.4970  loss_rpn_cls: 0.2575  loss_rpn_bbox: 0.2232  loss_cls: 0.5030  acc: 78.9062  loss_bbox: 0.5133
# 02/25 02:00:26 - mmengine - INFO - Epoch(train)   [8][200/236]  lr: 2.0000e-02  eta: 16:43:48  time: 1.1847  data_time: 0.0042  memory: 9047  loss: 1.4808  loss_rpn_cls: 0.2722  loss_rpn_bbox: 0.2213  loss_cls: 0.4893  acc: 83.3008  loss_bbox: 0.4980
# 02/25 02:01:08 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:01:18 - mmengine - INFO - Epoch(val)   [8][ 50/135]    eta: 0:00:16  time: 0.1977  data_time: 0.0029  memory: 9047
# 02/25 02:01:28 - mmengine - INFO - Epoch(val)   [8][100/135]    eta: 0:00:06  time: 0.1975  data_time: 0.0018  memory: 1021
# 02/25 02:01:35 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.54s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.139
# 02/25 02:01:49 - mmengine - INFO - bbox_mAP_copypaste: 0.019 0.041 0.015 0.009 0.060 0.020
# 02/25 02:01:49 - mmengine - INFO - Epoch(val) [8][135/135]    coco/bbox_mAP: 0.0190  coco/bbox_mAP_50: 0.0410  coco/bbox_mAP_75: 0.0150  coco/bbox_mAP_s: 0.0090  coco/bbox_mAP_m: 0.0600  coco/bbox_mAP_l: 0.0200  data_time: 0.0022  time: 0.1975
# 02/25 02:02:48 - mmengine - INFO - Epoch(train)   [9][ 50/236]  lr: 2.0000e-03  eta: 16:36:42  time: 1.1755  data_time: 0.0057  memory: 9056  loss: 1.3882  loss_rpn_cls: 0.2348  loss_rpn_bbox: 0.1990  loss_cls: 0.4621  acc: 80.5664  loss_bbox: 0.4924
# 02/25 02:03:47 - mmengine - INFO - Epoch(train)   [9][100/236]  lr: 2.0000e-03  eta: 16:32:55  time: 1.1796  data_time: 0.0040  memory: 8797  loss: 1.3680  loss_rpn_cls: 0.2250  loss_rpn_bbox: 0.2028  loss_cls: 0.4493  acc: 79.1992  loss_bbox: 0.4909
# 02/25 02:04:01 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:04:46 - mmengine - INFO - Epoch(train)   [9][150/236]  lr: 2.0000e-03  eta: 16:29:26  time: 1.1881  data_time: 0.0041  memory: 8797  loss: 1.3228  loss_rpn_cls: 0.2028  loss_rpn_bbox: 0.1929  loss_cls: 0.4411  acc: 87.4023  loss_bbox: 0.4861
# 02/25 02:05:45 - mmengine - INFO - Epoch(train)   [9][200/236]  lr: 2.0000e-03  eta: 16:26:01  time: 1.1857  data_time: 0.0040  memory: 8806  loss: 1.2919  loss_rpn_cls: 0.1994  loss_rpn_bbox: 0.1882  loss_cls: 0.4291  acc: 82.1289  loss_bbox: 0.4752
# 02/25 02:06:27 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:06:37 - mmengine - INFO - Epoch(val)   [9][ 50/135]    eta: 0:00:16  time: 0.1987  data_time: 0.0029  memory: 9047
# 02/25 02:06:47 - mmengine - INFO - Epoch(val)   [9][100/135]    eta: 0:00:06  time: 0.1986  data_time: 0.0019  memory: 1021
# 02/25 02:06:54 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.88s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.086
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.238
# 02/25 02:23:09 - mmengine - INFO - bbox_mAP_copypaste: 0.042 0.085 0.034 0.019 0.097 0.068
# 02/25 02:23:09 - mmengine - INFO - Epoch(val) [12][135/135]    coco/bbox_mAP: 0.0420  coco/bbox_mAP_50: 0.0850  coco/bbox_mAP_75: 0.0340  coco/bbox_mAP_s: 0.0190  coco/bbox_mAP_m: 0.0970  coco/bbox_mAP_l: 0.0680  data_time: 0.0022  time: 0.1984
# 02/25 02:24:07 - mmengine - INFO - Epoch(train)  [13][ 50/236]  lr: 2.0000e-04  eta: 15:41:48  time: 1.1720  data_time: 0.0048  memory: 8004  loss: 1.2552  loss_rpn_cls: 0.1813  loss_rpn_bbox: 0.1767  loss_cls: 0.4166  acc: 82.4219  loss_bbox: 0.4805
# 02/25 02:25:06 - mmengine - INFO - Epoch(train)  [13][100/236]  lr: 2.0000e-04  eta: 15:39:33  time: 1.1808  data_time: 0.0042  memory: 8635  loss: 1.2656  loss_rpn_cls: 0.1942  loss_rpn_bbox: 0.1856  loss_cls: 0.4259  acc: 90.1367  loss_bbox: 0.4599
# 02/25 02:26:05 - mmengine - INFO - Epoch(train)  [13][150/236]  lr: 2.0000e-04  eta: 15:37:22  time: 1.1824  data_time: 0.0044  memory: 8029  loss: 1.2522  loss_rpn_cls: 0.1784  loss_rpn_bbox: 0.1761  loss_cls: 0.4201  acc: 83.6914  loss_bbox: 0.4775
# 02/25 02:26:27 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:27:05 - mmengine - INFO - Epoch(train)  [13][200/236]  lr: 2.0000e-04  eta: 15:35:15  time: 1.1839  data_time: 0.0041  memory: 9056  loss: 1.1846  loss_rpn_cls: 0.1652  loss_rpn_bbox: 0.1733  loss_cls: 0.3987  acc: 85.0586  loss_bbox: 0.4474
# 02/25 02:27:47 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:27:57 - mmengine - INFO - Epoch(val)  [13][ 50/135]    eta: 0:00:17  time: 0.2004  data_time: 0.0027  memory: 9056
# 02/25 02:28:07 - mmengine - INFO - Epoch(val)  [13][100/135]    eta: 0:00:06  time: 0.1984  data_time: 0.0019  memory: 1021
# 02/25 02:28:14 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.94s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.242
# 02/25 02:28:29 - mmengine - INFO - bbox_mAP_copypaste: 0.042 0.086 0.035 0.019 0.099 0.068
# 02/25 02:28:29 - mmengine - INFO - Epoch(val) [13][135/135]    coco/bbox_mAP: 0.0420  coco/bbox_mAP_50: 0.0860  coco/bbox_mAP_75: 0.0350  coco/bbox_mAP_s: 0.0190  coco/bbox_mAP_m: 0.0990  coco/bbox_mAP_l: 0.0680  data_time: 0.0022  time: 0.1990
# 02/25 02:29:28 - mmengine - INFO - Epoch(train)  [14][ 50/236]  lr: 2.0000e-04  eta: 15:31:37  time: 1.1803  data_time: 0.0048  memory: 8797  loss: 1.2691  loss_rpn_cls: 0.1967  loss_rpn_bbox: 0.1845  loss_cls: 0.4235  acc: 83.7891  loss_bbox: 0.4643
# 02/25 02:30:27 - mmengine - INFO - Epoch(train)  [14][100/236]  lr: 2.0000e-04  eta: 15:29:31  time: 1.1787  data_time: 0.0038  memory: 9047  loss: 1.2846  loss_rpn_cls: 0.1832  loss_rpn_bbox: 0.1825  loss_cls: 0.4326  acc: 79.4922  loss_bbox: 0.4863
# 02/25 02:31:26 - mmengine - INFO - Epoch(train)  [14][150/236]  lr: 2.0000e-04  eta: 15:27:32  time: 1.1839  data_time: 0.0042  memory: 9056  loss: 1.1800  loss_rpn_cls: 0.1584  loss_rpn_bbox: 0.1701  loss_cls: 0.3935  acc: 89.0625  loss_bbox: 0.4581
# 02/25 02:32:25 - mmengine - INFO - Epoch(train)  [14][200/236]  lr: 2.0000e-04  eta: 15:25:38  time: 1.1903  data_time: 0.0042  memory: 8627  loss: 1.2389  loss_rpn_cls: 0.1816  loss_rpn_bbox: 0.1809  loss_cls: 0.4135  acc: 85.4492  loss_bbox: 0.4629
# 02/25 02:33:08 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:33:18 - mmengine - INFO - Epoch(val)  [14][ 50/135]    eta: 0:00:16  time: 0.1984  data_time: 0.0024  memory: 8797
# 02/25 02:33:27 - mmengine - INFO - Epoch(val)  [14][100/135]    eta: 0:00:06  time: 0.1980  data_time: 0.0019  memory: 1021
# 02/25 02:33:35 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.38s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.246
# 02/25 02:33:49 - mmengine - INFO - bbox_mAP_copypaste: 0.044 0.090 0.037 0.019 0.101 0.073
# 02/25 02:33:49 - mmengine - INFO - Epoch(val) [14][135/135]    coco/bbox_mAP: 0.0440  coco/bbox_mAP_50: 0.0900  coco/bbox_mAP_75: 0.0370  coco/bbox_mAP_s: 0.0190  coco/bbox_mAP_m: 0.1010  coco/bbox_mAP_l: 0.0730  data_time: 0.0021  time: 0.1979
# 02/25 02:34:48 - mmengine - INFO - Epoch(train)  [15][ 50/236]  lr: 2.0000e-04  eta: 15:22:11  time: 1.1805  data_time: 0.0046  memory: 8627  loss: 1.2100  loss_rpn_cls: 0.1814  loss_rpn_bbox: 0.1798  loss_cls: 0.4036  acc: 82.8125  loss_bbox: 0.4451
# 02/25 02:35:47 - mmengine - INFO - Epoch(train)  [15][100/236]  lr: 2.0000e-04  eta: 15:20:13  time: 1.1764  data_time: 0.0043  memory: 8635  loss: 1.2472  loss_rpn_cls: 0.1816  loss_rpn_bbox: 0.1772  loss_cls: 0.4176  acc: 81.7383  loss_bbox: 0.4708
# 02/25 02:36:46 - mmengine - INFO - Epoch(train)  [15][150/236]  lr: 2.0000e-04  eta: 15:18:23  time: 1.1857  data_time: 0.0041  memory: 8797  loss: 1.2348  loss_rpn_cls: 0.1861  loss_rpn_bbox: 0.1798  loss_cls: 0.4086  acc: 82.7148  loss_bbox: 0.4603
# 02/25 02:37:46 - mmengine - INFO - Epoch(train)  [15][200/236]  lr: 2.0000e-04  eta: 15:16:35  time: 1.1872  data_time: 0.0041  memory: 9056  loss: 1.2681  loss_rpn_cls: 0.1911  loss_rpn_bbox: 0.1875  loss_cls: 0.4260  acc: 87.4023  loss_bbox: 0.4635
# 02/25 02:38:28 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:38:38 - mmengine - INFO - Epoch(val)  [15][ 50/135]    eta: 0:00:16  time: 0.1976  data_time: 0.0028  memory: 9047
# 02/25 02:38:47 - mmengine - INFO - Epoch(val)  [15][100/135]    eta: 0:00:06  time: 0.1978  data_time: 0.0019  memory: 1021
# 02/25 02:38:54 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.33s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.141
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.254
# 02/25 02:39:09 - mmengine - INFO - bbox_mAP_copypaste: 0.045 0.092 0.037 0.020 0.101 0.079
# 02/25 02:39:09 - mmengine - INFO - Epoch(val) [15][135/135]    coco/bbox_mAP: 0.0450  coco/bbox_mAP_50: 0.0920  coco/bbox_mAP_75: 0.0370  coco/bbox_mAP_s: 0.0200  coco/bbox_mAP_m: 0.1010  coco/bbox_mAP_l: 0.0790  data_time: 0.0022  time: 0.1974
# 02/25 02:40:08 - mmengine - INFO - Epoch(train)  [16][ 50/236]  lr: 2.0000e-04  eta: 15:13:19  time: 1.1834  data_time: 0.0046  memory: 9047  loss: 1.2747  loss_rpn_cls: 0.1993  loss_rpn_bbox: 0.1884  loss_cls: 0.4188  acc: 82.5195  loss_bbox: 0.4681
# 02/25 02:41:07 - mmengine - INFO - Epoch(train)  [16][100/236]  lr: 2.0000e-04  eta: 15:11:32  time: 1.1823  data_time: 0.0042  memory: 9047  loss: 1.2069  loss_rpn_cls: 0.1699  loss_rpn_bbox: 0.1720  loss_cls: 0.4015  acc: 81.0547  loss_bbox: 0.4635
# 02/25 02:42:07 - mmengine - INFO - Epoch(train)  [16][150/236]  lr: 2.0000e-04  eta: 15:09:47  time: 1.1841  data_time: 0.0041  memory: 8029  loss: 1.2174  loss_rpn_cls: 0.1671  loss_rpn_bbox: 0.1746  loss_cls: 0.4153  acc: 90.1367  loss_bbox: 0.4604
# 02/25 02:43:06 - mmengine - INFO - Epoch(train)  [16][200/236]  lr: 2.0000e-04  eta: 15:08:05  time: 1.1868  data_time: 0.0041  memory: 8402  loss: 1.2460  loss_rpn_cls: 0.1794  loss_rpn_bbox: 0.1798  loss_cls: 0.4147  acc: 81.0547  loss_bbox: 0.4721
# 02/25 02:43:48 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:43:58 - mmengine - INFO - Epoch(val)  [16][ 50/135]    eta: 0:00:16  time: 0.1978  data_time: 0.0027  memory: 8806
# 02/25 02:44:08 - mmengine - INFO - Epoch(val)  [16][100/135]    eta: 0:00:06  time: 0.1992  data_time: 0.0019  memory: 1021
# 02/25 02:44:15 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.33s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.141
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.246
# 02/25 02:44:30 - mmengine - INFO - bbox_mAP_copypaste: 0.044 0.090 0.036 0.020 0.101 0.073
# 02/25 02:44:30 - mmengine - INFO - Epoch(val) [16][135/135]    coco/bbox_mAP: 0.0440  coco/bbox_mAP_50: 0.0900  coco/bbox_mAP_75: 0.0360  coco/bbox_mAP_s: 0.0200  coco/bbox_mAP_m: 0.1010  coco/bbox_mAP_l: 0.0730  data_time: 0.0022  time: 0.1982
# 02/25 02:45:29 - mmengine - INFO - Epoch(train)  [17][ 50/236]  lr: 2.0000e-04  eta: 15:05:00  time: 1.1784  data_time: 0.0054  memory: 9047  loss: 1.2384  loss_rpn_cls: 0.1893  loss_rpn_bbox: 0.1820  loss_cls: 0.4101  acc: 88.8672  loss_bbox: 0.4571
# 02/25 02:46:28 - mmengine - INFO - Epoch(train)  [17][100/236]  lr: 2.0000e-04  eta: 15:03:18  time: 1.1812  data_time: 0.0040  memory: 8635  loss: 1.1880  loss_rpn_cls: 0.1739  loss_rpn_bbox: 0.1756  loss_cls: 0.3939  acc: 89.4531  loss_bbox: 0.4446
# 02/25 02:47:27 - mmengine - INFO - Epoch(train)  [17][150/236]  lr: 2.0000e-04  eta: 15:01:41  time: 1.1877  data_time: 0.0041  memory: 8806  loss: 1.2467  loss_rpn_cls: 0.1795  loss_rpn_bbox: 0.1775  loss_cls: 0.4191  acc: 86.2305  loss_bbox: 0.4707
# 02/25 02:48:27 - mmengine - INFO - Epoch(train)  [17][200/236]  lr: 2.0000e-04  eta: 15:00:03  time: 1.1857  data_time: 0.0040  memory: 9056  loss: 1.2584  loss_rpn_cls: 0.1814  loss_rpn_bbox: 0.1786  loss_cls: 0.4233  acc: 86.6211  loss_bbox: 0.4752
# 02/25 02:48:55 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:49:09 - mmengine - INFO - Exp name: custom_libra-faster-rcnn_x101-64x4d_fpn_1x_coco_20240225_011403
# 02/25 02:49:19 - mmengine - INFO - Epoch(val)  [17][ 50/135]    eta: 0:00:16  time: 0.1990  data_time: 0.0025  memory: 8029
# 02/25 02:49:29 - mmengine - INFO - Epoch(val)  [17][100/135]    eta: 0:00:06  time: 0.1983  data_time: 0.0019  memory: 1021
# 02/25 02:49:36 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.38s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.241
# 02/25 02:49:51 - mmengine - INFO - bbox_mAP_copypaste: 0.045 0.093 0.037 0.020 0.101 0.074
# 02/25 02:49:51 - mmengine - INFO - Epoch(val) [17][135/135]    coco/bbox_mAP: 0.0450  coco/bbox_mAP_50: 0.0930  coco/bbox_mAP_75: 0.0370  coco/bbox_mAP_s: 0.0200  coco/bbox_mAP_m: 0.1010  coco/bbox_mAP_l: 0.0740  data_time: 0.0021  time: 0.1986
# 02/25 02:49:51 - mmengine - INFO - the monitored metric did not improve in the last 10 records. best score: 0.097.

# %%
CONFIDENCE_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

def callback(image: np.ndarray) -> sv.Detections:
    result = inference_detector(model, image)
    detections = sv.Detections.from_mmdetection(result)
    return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)


mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset = ds,
    callback = callback
)

print('mAP:', mean_average_precision.map50_95)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       4 ds = sv.DetectionDataset.from_coco(
#       5     images_directory_path=f"{dataset_location}/test",
#       6     annotations_path=f"{dataset_location}/test/_annotations.coco.json",
#       7 )
#       9 images = list(ds.images.values())
# ---> 10 CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
#      11 model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)
#      13 def callback(image: np.ndarray) -> sv.Detections:
#
# NameError: name 'model_name' is not defined

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)
