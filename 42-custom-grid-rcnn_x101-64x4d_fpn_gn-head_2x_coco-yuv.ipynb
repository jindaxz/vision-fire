# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Mon Feb 26 23:33:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       On  | 00000000:AF:00.0 Off |                    0 |
# | N/A   31C    P8               9W /  70W |      2MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3
# 2024-02-26 23:33:57.337770: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 23:33:57.398405: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 23:33:57.398448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 23:33:57.399899: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 23:33:57.409665: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 23:34:03.239192: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# set seed successfully

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="grid_rcnn"
base_model_name="grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco"
custom_model_name=f"custom-{base_model_name}-yuv"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
dataset_location=f"/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv"

CUSTOM_CONFIG = f"""
# The new config inherits a base config to highlight the necessary modification
_base_ = 'grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco.py'

# ========================Frequently modified parameters======================

dataset_type = 'COCODataset'
max_epochs = 200
classes =  ('Alive Tree', 'Beetle-Fire Tree', 'Dead Tree', 'Debris') 

data_root = '{dataset_location}'

data = dict(
    samples_per_gpu=8,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/annotation_coco.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=10,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 32
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----model related-----
# The scaling factor that controls the depth of the network structure
deepen_factor = 0.67
# The scaling factor that controls the width of the network structure
widen_factor = 0.75
# Strides of multi-scale prior box
strides = [8, 16, 32]

norm_cfg = dict(type='BN')  # Normalization config

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)


train_dataloader = dict(
    batch_size=4,
)

val_dataloader = dict(
    batch_size=4,
)

test_dataloader = dict(
    batch_size=4,
)

"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)

# %%
# !python tools/train.py configs/{model_folder}/{custom_model_name}.py --resume\
    | tee "../log/OUT_{custom_model_name}_$(date +"%Y%m%d_%H%M%S").txt"
# Out:
# 02/26 23:34:31 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1730897177
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1730897177
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/26 23:34:31 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# batch_shapes_cfg = dict(
#     batch_size=32,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     samples_per_gpu=8,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/annotation_coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'),
#     workers_per_gpu=2)
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv'
# dataset_type = 'COCODataset'
# deepen_factor = 0.67
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 200
# max_keep_ckpts = 3
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=64,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_64x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             num_classes=80,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead',
#             with_reg=False),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         grid_head=dict(
#             grid_points=9,
#             in_channels=256,
#             loss_grid=dict(
#                 loss_weight=15, type='CrossEntropyLoss', use_sigmoid=True),
#             norm_cfg=dict(num_groups=36, type='GN'),
#             num_convs=8,
#             point_feat_channels=64,
#             type='GridHead'),
#         grid_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='GridRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.3, type='nms'),
#             score_thr=0.03),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             max_num_grid=192,
#             pos_radius=1,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='GridRCNN')
# mosaic_max_cached_images = 40
# norm_cfg = dict(type='BN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=3665,
#         start_factor=0.0125,
#         type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=25,
#         gamma=0.1,
#         milestones=[
#             17,
#             23,
#         ],
#         type='MultiStepLR'),
# ]
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = True
# save_checkpoint_intervals = 10
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=200, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=4,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_batch_size_per_gpu = 32
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# widen_factor = 0.75
# work_dir = './work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv'
#
# 02/26 23:34:37 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/26 23:34:37 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/26 23:34:39 - mmengine - INFO - load model from: open-mmlab://resnext101_64x4d
# 02/26 23:34:39 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_64x4d
# 02/26 23:34:40 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv/epoch_41.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv/epoch_41.pth
# 02/26 23:34:41 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv/epoch_41.pth
# 02/26 23:34:41 - mmengine - INFO - resumed epoch: 41, iter: 4838
# 02/26 23:34:41 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/26 23:34:41 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/26 23:34:41 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv.
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/26 23:37:37 - mmengine - INFO - Epoch(train)  [42][ 50/118]  lr: 2.0000e-04  eta: 18:13:37  time: 3.5067  data_time: 0.0145  memory: 14472  loss: 1.1796  loss_rpn_cls: 0.0987  loss_rpn_bbox: 0.0873  loss_cls: 0.2735  acc: 85.8398  loss_grid: 0.7202
# 02/26 23:40:13 - mmengine - INFO - Epoch(train)  [42][100/118]  lr: 2.0000e-04  eta: 17:12:59  time: 3.1356  data_time: 0.0079  memory: 13429  loss: 1.1940  loss_rpn_cls: 0.1003  loss_rpn_bbox: 0.0875  loss_cls: 0.2798  acc: 86.7676  loss_grid: 0.7263
# 02/26 23:41:23 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/26 23:41:23 - mmengine - INFO - Saving checkpoint at 42 epochs
# 02/26 23:42:33 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.37s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.11s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.235
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.408
# 02/26 23:42:51 - mmengine - INFO - bbox_mAP_copypaste: 0.108 0.235 0.087 0.028 0.165 0.343
# 02/26 23:42:51 - mmengine - INFO - Epoch(val) [42][34/34]    coco/bbox_mAP: 0.1080  coco/bbox_mAP_50: 0.2350  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1650  coco/bbox_mAP_l: 0.3430  data_time: 0.0186  time: 1.8871
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/26 23:45:09 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/26 23:45:28 - mmengine - INFO - Epoch(train)  [43][ 50/118]  lr: 2.0000e-04  eta: 17:12:21  time: 3.1558  data_time: 0.0104  memory: 13204  loss: 1.1964  loss_rpn_cls: 0.1011  loss_rpn_bbox: 0.0880  loss_cls: 0.2825  acc: 89.9902  loss_grid: 0.7247
# 02/26 23:48:07 - mmengine - INFO - Epoch(train)  [43][100/118]  lr: 2.0000e-04  eta: 16:57:51  time: 3.1659  data_time: 0.0080  memory: 13416  loss: 1.1738  loss_rpn_cls: 0.0970  loss_rpn_bbox: 0.0865  loss_cls: 0.2724  acc: 87.3535  loss_grid: 0.7178
# 02/26 23:49:03 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/26 23:49:03 - mmengine - INFO - Saving checkpoint at 43 epochs
# 02/26 23:50:01 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.21s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.234
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.405
# 02/26 23:50:19 - mmengine - INFO - bbox_mAP_copypaste: 0.108 0.234 0.086 0.029 0.165 0.341
# 02/26 23:50:19 - mmengine - INFO - Epoch(val) [43][34/34]    coco/bbox_mAP: 0.1080  coco/bbox_mAP_50: 0.2340  coco/bbox_mAP_75: 0.0860  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1650  coco/bbox_mAP_l: 0.3410  data_time: 0.0097  time: 1.6209
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/26 23:52:57 - mmengine - INFO - Epoch(train)  [44][ 50/118]  lr: 2.0000e-04  eta: 16:43:15  time: 3.1511  data_time: 0.0089  memory: 13421  loss: 1.1782  loss_rpn_cls: 0.0942  loss_rpn_bbox: 0.0865  loss_cls: 0.2744  acc: 86.2305  loss_grid: 0.7232
# 02/26 23:55:35 - mmengine - INFO - Epoch(train)  [44][100/118]  lr: 2.0000e-04  eta: 16:36:10  time: 3.1623  data_time: 0.0083  memory: 13208  loss: 1.2001  loss_rpn_cls: 0.1032  loss_rpn_bbox: 0.0882  loss_cls: 0.2822  acc: 87.5000  loss_grid: 0.7266
# 02/26 23:56:31 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/26 23:56:31 - mmengine - INFO - Saving checkpoint at 44 epochs
# 02/26 23:57:18 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.48s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.164
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.353
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.418
# 02/26 23:57:36 - mmengine - INFO - bbox_mAP_copypaste: 0.109 0.236 0.088 0.029 0.164 0.353
# 02/26 23:57:36 - mmengine - INFO - Epoch(val) [44][34/34]    coco/bbox_mAP: 0.1090  coco/bbox_mAP_50: 0.2360  coco/bbox_mAP_75: 0.0880  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1640  coco/bbox_mAP_l: 0.3530  data_time: 0.0101  time: 1.2372
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:00:13 - mmengine - INFO - Epoch(train)  [45][ 50/118]  lr: 2.0000e-04  eta: 16:26:51  time: 3.1390  data_time: 0.0101  memory: 13187  loss: 1.1646  loss_rpn_cls: 0.0940  loss_rpn_bbox: 0.0841  loss_cls: 0.2700  acc: 89.5996  loss_grid: 0.7165
# 02/27 00:02:51 - mmengine - INFO - Epoch(train)  [45][100/118]  lr: 2.0000e-04  eta: 16:22:08  time: 3.1651  data_time: 0.0077  memory: 13420  loss: 1.1791  loss_rpn_cls: 0.0972  loss_rpn_bbox: 0.0852  loss_cls: 0.2773  acc: 86.1328  loss_grid: 0.7193
# 02/27 00:03:48 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:03:48 - mmengine - INFO - Saving checkpoint at 45 epochs
# 02/27 00:04:34 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.45s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.142
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.405
# 02/27 00:04:52 - mmengine - INFO - bbox_mAP_copypaste: 0.108 0.236 0.087 0.029 0.165 0.343
# 02/27 00:04:52 - mmengine - INFO - Epoch(val) [45][34/34]    coco/bbox_mAP: 0.1080  coco/bbox_mAP_50: 0.2360  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1650  coco/bbox_mAP_l: 0.3430  data_time: 0.0085  time: 1.2260
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:07:31 - mmengine - INFO - Epoch(train)  [46][ 50/118]  lr: 2.0000e-04  eta: 16:16:11  time: 3.1723  data_time: 0.0106  memory: 13201  loss: 1.1673  loss_rpn_cls: 0.0945  loss_rpn_bbox: 0.0846  loss_cls: 0.2685  acc: 85.8887  loss_grid: 0.7197
# 02/27 00:10:09 - mmengine - INFO - Epoch(train)  [46][100/118]  lr: 2.0000e-04  eta: 16:12:34  time: 3.1760  data_time: 0.0088  memory: 13420  loss: 1.1836  loss_rpn_cls: 0.0981  loss_rpn_bbox: 0.0875  loss_cls: 0.2759  acc: 87.4023  loss_grid: 0.7221
# 02/27 00:11:06 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:11:06 - mmengine - INFO - Saving checkpoint at 46 epochs
# 02/27 00:11:48 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.52s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.351
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.415
# 02/27 00:12:06 - mmengine - INFO - bbox_mAP_copypaste: 0.110 0.238 0.088 0.029 0.167 0.351
# 02/27 00:12:06 - mmengine - INFO - Epoch(val) [46][34/34]    coco/bbox_mAP: 0.1100  coco/bbox_mAP_50: 0.2380  coco/bbox_mAP_75: 0.0880  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1670  coco/bbox_mAP_l: 0.3510  data_time: 0.0098  time: 1.1145
# 02/27 00:12:06 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv/best_coco_bbox_mAP_50_epoch_31.pth is removed
# 02/27 00:12:09 - mmengine - INFO - The best checkpoint with 0.2380 coco/bbox_mAP_50 at 46 epoch is saved to best_coco_bbox_mAP_50_epoch_46.pth.
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:14:51 - mmengine - INFO - Epoch(train)  [47][ 50/118]  lr: 2.0000e-04  eta: 16:07:10  time: 3.1603  data_time: 0.0104  memory: 13420  loss: 1.1583  loss_rpn_cls: 0.0940  loss_rpn_bbox: 0.0837  loss_cls: 0.2689  acc: 89.0625  loss_grid: 0.7118
# 02/27 00:17:30 - mmengine - INFO - Epoch(train)  [47][100/118]  lr: 2.0000e-04  eta: 16:04:10  time: 3.1864  data_time: 0.0082  memory: 13407  loss: 1.1786  loss_rpn_cls: 0.0965  loss_rpn_bbox: 0.0869  loss_cls: 0.2699  acc: 86.6211  loss_grid: 0.7253
# 02/27 00:18:27 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:18:27 - mmengine - INFO - Saving checkpoint at 47 epochs
# 02/27 00:19:15 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.29s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.220
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.417
# 02/27 00:19:32 - mmengine - INFO - bbox_mAP_copypaste: 0.109 0.238 0.089 0.029 0.165 0.350
# 02/27 00:19:32 - mmengine - INFO - Epoch(val) [47][34/34]    coco/bbox_mAP: 0.1090  coco/bbox_mAP_50: 0.2380  coco/bbox_mAP_75: 0.0890  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1650  coco/bbox_mAP_l: 0.3500  data_time: 0.0084  time: 1.2415
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:22:11 - mmengine - INFO - Epoch(train)  [48][ 50/118]  lr: 2.0000e-04  eta: 15:59:32  time: 3.1687  data_time: 0.0100  memory: 13413  loss: 1.1478  loss_rpn_cls: 0.0902  loss_rpn_bbox: 0.0839  loss_cls: 0.2645  acc: 89.8926  loss_grid: 0.7091
# 02/27 00:24:50 - mmengine - INFO - Epoch(train)  [48][100/118]  lr: 2.0000e-04  eta: 15:56:39  time: 3.1857  data_time: 0.0073  memory: 13427  loss: 1.1817  loss_rpn_cls: 0.0963  loss_rpn_bbox: 0.0874  loss_cls: 0.2763  acc: 93.3594  loss_grid: 0.7217
# 02/27 00:25:47 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:25:47 - mmengine - INFO - Saving checkpoint at 48 epochs
# 02/27 00:26:36 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.15s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.413
# 02/27 00:26:54 - mmengine - INFO - bbox_mAP_copypaste: 0.109 0.238 0.089 0.028 0.166 0.349
# 02/27 00:26:54 - mmengine - INFO - Epoch(val) [48][34/34]    coco/bbox_mAP: 0.1090  coco/bbox_mAP_50: 0.2380  coco/bbox_mAP_75: 0.0890  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1660  coco/bbox_mAP_l: 0.3490  data_time: 0.0094  time: 1.3110
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:29:33 - mmengine - INFO - Epoch(train)  [49][ 50/118]  lr: 2.0000e-04  eta: 15:52:20  time: 3.1769  data_time: 0.0099  memory: 13421  loss: 1.1816  loss_rpn_cls: 0.0971  loss_rpn_bbox: 0.0877  loss_cls: 0.2726  acc: 85.4980  loss_grid: 0.7242
# 02/27 00:32:11 - mmengine - INFO - Epoch(train)  [49][100/118]  lr: 2.0000e-04  eta: 15:49:19  time: 3.1721  data_time: 0.0085  memory: 12857  loss: 1.1485  loss_rpn_cls: 0.0872  loss_rpn_bbox: 0.0824  loss_cls: 0.2651  acc: 87.3535  loss_grid: 0.7137
# 02/27 00:33:08 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:33:08 - mmengine - INFO - Saving checkpoint at 49 epochs
# 02/27 00:33:46 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.40s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.241
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.425
# 02/27 00:34:04 - mmengine - INFO - bbox_mAP_copypaste: 0.110 0.241 0.089 0.028 0.167 0.357
# 02/27 00:34:04 - mmengine - INFO - Epoch(val) [49][34/34]    coco/bbox_mAP: 0.1100  coco/bbox_mAP_50: 0.2410  coco/bbox_mAP_75: 0.0890  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1670  coco/bbox_mAP_l: 0.3570  data_time: 0.0096  time: 0.9790
# 02/27 00:34:04 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv/best_coco_bbox_mAP_50_epoch_46.pth is removed
# 02/27 00:34:06 - mmengine - INFO - The best checkpoint with 0.2410 coco/bbox_mAP_50 at 49 epoch is saved to best_coco_bbox_mAP_50_epoch_49.pth.
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:36:48 - mmengine - INFO - Epoch(train)  [50][ 50/118]  lr: 2.0000e-04  eta: 15:44:43  time: 3.1505  data_time: 0.0103  memory: 13421  loss: 1.1345  loss_rpn_cls: 0.0844  loss_rpn_bbox: 0.0813  loss_cls: 0.2550  acc: 89.0137  loss_grid: 0.7138
# 02/27 00:39:27 - mmengine - INFO - Epoch(train)  [50][100/118]  lr: 2.0000e-04  eta: 15:42:02  time: 3.1883  data_time: 0.0082  memory: 13406  loss: 1.1911  loss_rpn_cls: 0.1032  loss_rpn_bbox: 0.0878  loss_cls: 0.2806  acc: 87.9883  loss_grid: 0.7194
# 02/27 00:40:24 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:40:24 - mmengine - INFO - Saving checkpoint at 50 epochs
# 02/27 00:41:07 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.14s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.424
# 02/27 00:41:25 - mmengine - INFO - bbox_mAP_copypaste: 0.110 0.239 0.089 0.028 0.167 0.357
# 02/27 00:41:25 - mmengine - INFO - Epoch(val) [50][34/34]    coco/bbox_mAP: 0.1100  coco/bbox_mAP_50: 0.2390  coco/bbox_mAP_75: 0.0890  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1670  coco/bbox_mAP_l: 0.3570  data_time: 0.0085  time: 1.1205
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:44:04 - mmengine - INFO - Epoch(train)  [51][ 50/118]  lr: 2.0000e-04  eta: 15:37:54  time: 3.1705  data_time: 0.0096  memory: 13406  loss: 1.1794  loss_rpn_cls: 0.0961  loss_rpn_bbox: 0.0861  loss_cls: 0.2740  acc: 86.0840  loss_grid: 0.7231
# 02/27 00:46:43 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:46:43 - mmengine - INFO - Epoch(train)  [51][100/118]  lr: 2.0000e-04  eta: 15:35:13  time: 3.1861  data_time: 0.0082  memory: 13406  loss: 1.1524  loss_rpn_cls: 0.0939  loss_rpn_bbox: 0.0840  loss_cls: 0.2637  acc: 89.9902  loss_grid: 0.7108
# 02/27 00:47:39 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:47:39 - mmengine - INFO - Saving checkpoint at 51 epochs
# 02/27 00:48:21 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.24s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.417
# 02/27 00:48:39 - mmengine - INFO - bbox_mAP_copypaste: 0.110 0.238 0.089 0.028 0.167 0.349
# 02/27 00:48:39 - mmengine - INFO - Epoch(val) [51][34/34]    coco/bbox_mAP: 0.1100  coco/bbox_mAP_50: 0.2380  coco/bbox_mAP_75: 0.0890  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1670  coco/bbox_mAP_l: 0.3490  data_time: 0.0105  time: 1.0568
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 00:51:17 - mmengine - INFO - Epoch(train)  [52][ 50/118]  lr: 2.0000e-04  eta: 15:31:05  time: 3.1657  data_time: 0.0091  memory: 13424  loss: 1.1769  loss_rpn_cls: 0.0935  loss_rpn_bbox: 0.0873  loss_cls: 0.2735  acc: 86.5234  loss_grid: 0.7227
# 02/27 00:53:56 - mmengine - INFO - Epoch(train)  [52][100/118]  lr: 2.0000e-04  eta: 15:28:18  time: 3.1749  data_time: 0.0074  memory: 13189  loss: 1.1447  loss_rpn_cls: 0.0891  loss_rpn_bbox: 0.0808  loss_cls: 0.2618  acc: 87.5000  loss_grid: 0.7130
# 02/27 00:54:52 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 00:54:52 - mmengine - INFO - Saving checkpoint at 52 epochs
# 02/27 00:55:37 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.17s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.444
# 02/27 03:05:45 - mmengine - INFO - bbox_mAP_copypaste: 0.115 0.245 0.095 0.029 0.175 0.377
# 02/27 03:05:45 - mmengine - INFO - Epoch(val) [70][34/34]    coco/bbox_mAP: 0.1150  coco/bbox_mAP_50: 0.2450  coco/bbox_mAP_75: 0.0950  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1750  coco/bbox_mAP_l: 0.3770  data_time: 0.0097  time: 1.1091
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:08:23 - mmengine - INFO - Epoch(train)  [71][ 50/118]  lr: 2.0000e-04  eta: 13:29:26  time: 3.1624  data_time: 0.0104  memory: 13429  loss: 1.0692  loss_rpn_cls: 0.0736  loss_rpn_bbox: 0.0766  loss_cls: 0.2332  acc: 93.6035  loss_grid: 0.6858
# 02/27 03:11:03 - mmengine - INFO - Epoch(train)  [71][100/118]  lr: 2.0000e-04  eta: 13:26:51  time: 3.1953  data_time: 0.0080  memory: 13427  loss: 1.1112  loss_rpn_cls: 0.0869  loss_rpn_bbox: 0.0815  loss_cls: 0.2405  acc: 86.6699  loss_grid: 0.7024
# 02/27 03:12:00 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:12:00 - mmengine - INFO - Saving checkpoint at 71 epochs
# 02/27 03:12:38 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.93s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.231
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.438
# 02/27 03:12:55 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.245 0.093 0.029 0.176 0.371
# 02/27 03:12:55 - mmengine - INFO - Epoch(val) [71][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2450  coco/bbox_mAP_75: 0.0930  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1760  coco/bbox_mAP_l: 0.3710  data_time: 0.0101  time: 0.9786
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:15:33 - mmengine - INFO - Epoch(train)  [72][ 50/118]  lr: 2.0000e-04  eta: 13:23:11  time: 3.1702  data_time: 0.0136  memory: 13205  loss: 1.0901  loss_rpn_cls: 0.0791  loss_rpn_bbox: 0.0792  loss_cls: 0.2397  acc: 90.9668  loss_grid: 0.6922
# 02/27 03:18:13 - mmengine - INFO - Epoch(train)  [72][100/118]  lr: 2.0000e-04  eta: 13:20:35  time: 3.1893  data_time: 0.0080  memory: 13410  loss: 1.1081  loss_rpn_cls: 0.0823  loss_rpn_bbox: 0.0803  loss_cls: 0.2448  acc: 88.3789  loss_grid: 0.7007
# 02/27 03:19:09 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:19:09 - mmengine - INFO - Saving checkpoint at 72 epochs
# 02/27 03:19:45 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.05s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.230
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.444
# 02/27 03:20:03 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.245 0.094 0.028 0.174 0.378
# 02/27 03:20:03 - mmengine - INFO - Epoch(val) [72][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2450  coco/bbox_mAP_75: 0.0940  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1740  coco/bbox_mAP_l: 0.3780  data_time: 0.0101  time: 0.9142
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:22:41 - mmengine - INFO - Epoch(train)  [73][ 50/118]  lr: 2.0000e-04  eta: 13:16:55  time: 3.1762  data_time: 0.0095  memory: 13410  loss: 1.0789  loss_rpn_cls: 0.0746  loss_rpn_bbox: 0.0766  loss_cls: 0.2325  acc: 90.3809  loss_grid: 0.6953
# 02/27 03:25:21 - mmengine - INFO - Epoch(train)  [73][100/118]  lr: 2.0000e-04  eta: 13:14:19  time: 3.1857  data_time: 0.0080  memory: 13425  loss: 1.0964  loss_rpn_cls: 0.0778  loss_rpn_bbox: 0.0806  loss_cls: 0.2433  acc: 88.9648  loss_grid: 0.6947
# 02/27 03:26:17 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:26:17 - mmengine - INFO - Saving checkpoint at 73 epochs
# 02/27 03:26:59 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.92s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.176
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.446
# 02/27 03:27:16 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.246 0.096 0.028 0.176 0.378
# 02/27 03:27:16 - mmengine - INFO - Epoch(val) [73][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2460  coco/bbox_mAP_75: 0.0960  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1760  coco/bbox_mAP_l: 0.3780  data_time: 0.0099  time: 1.0476
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:29:55 - mmengine - INFO - Epoch(train)  [74][ 50/118]  lr: 2.0000e-04  eta: 13:10:41  time: 3.1769  data_time: 0.0091  memory: 13420  loss: 1.0839  loss_rpn_cls: 0.0794  loss_rpn_bbox: 0.0794  loss_cls: 0.2365  acc: 89.5020  loss_grid: 0.6886
# 02/27 03:32:34 - mmengine - INFO - Epoch(train)  [74][100/118]  lr: 2.0000e-04  eta: 13:08:02  time: 3.1790  data_time: 0.0087  memory: 13048  loss: 1.0663  loss_rpn_cls: 0.0727  loss_rpn_bbox: 0.0747  loss_cls: 0.2307  acc: 89.8438  loss_grid: 0.6881
# 02/27 03:33:31 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:33:31 - mmengine - INFO - Saving checkpoint at 74 epochs
# 02/27 03:34:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.01s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.245
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.149
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.445
# 02/27 03:34:30 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.245 0.095 0.028 0.175 0.380
# 02/27 03:34:30 - mmengine - INFO - Epoch(val) [74][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2450  coco/bbox_mAP_75: 0.0950  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1750  coco/bbox_mAP_l: 0.3800  data_time: 0.0095  time: 0.9797
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:37:08 - mmengine - INFO - Epoch(train)  [75][ 50/118]  lr: 2.0000e-04  eta: 13:04:22  time: 3.1647  data_time: 0.0091  memory: 13421  loss: 1.0856  loss_rpn_cls: 0.0826  loss_rpn_bbox: 0.0794  loss_cls: 0.2351  acc: 88.0859  loss_grid: 0.6885
# 02/27 03:39:47 - mmengine - INFO - Epoch(train)  [75][100/118]  lr: 2.0000e-04  eta: 13:01:41  time: 3.1635  data_time: 0.0076  memory: 12857  loss: 1.0632  loss_rpn_cls: 0.0724  loss_rpn_bbox: 0.0763  loss_cls: 0.2303  acc: 94.4336  loss_grid: 0.6842
# 02/27 03:40:43 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:40:43 - mmengine - INFO - Saving checkpoint at 75 epochs
# 02/27 03:41:21 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.11s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.440
# 02/27 03:41:39 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.247 0.094 0.028 0.177 0.375
# 02/27 03:41:39 - mmengine - INFO - Epoch(val) [75][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2470  coco/bbox_mAP_75: 0.0940  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1770  coco/bbox_mAP_l: 0.3750  data_time: 0.0083  time: 0.9712
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/mmdet/models/task_modules/samplers/sampling_result.py:132: UserWarning: DeprecationWarning: pos_bboxes is deprecated, please use "pos_priors" instead
#   warnings.warn('DeprecationWarning: pos_bboxes is deprecated, '
# 02/27 03:44:17 - mmengine - INFO - Epoch(train)  [76][ 50/118]  lr: 2.0000e-04  eta: 12:58:00  time: 3.1605  data_time: 0.0100  memory: 13202  loss: 1.0900  loss_rpn_cls: 0.0815  loss_rpn_bbox: 0.0790  loss_cls: 0.2353  acc: 92.4805  loss_grid: 0.6942
# 02/27 03:46:55 - mmengine - INFO - Epoch(train)  [76][100/118]  lr: 2.0000e-04  eta: 12:55:19  time: 3.1646  data_time: 0.0082  memory: 13202  loss: 1.0636  loss_rpn_cls: 0.0737  loss_rpn_bbox: 0.0767  loss_cls: 0.2300  acc: 91.3086  loss_grid: 0.6831
# 02/27 03:47:51 - mmengine - INFO - Exp name: custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-yuv_20240226_233426
# 02/27 03:47:51 - mmengine - INFO - Saving checkpoint at 76 epochs
# 02/27 03:48:28 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.86s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.116
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.374
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.442
# 02/27 03:48:45 - mmengine - INFO - bbox_mAP_copypaste: 0.116 0.244 0.094 0.030 0.175 0.374
# 02/27 03:48:45 - mmengine - INFO - Epoch(val) [76][34/34]    coco/bbox_mAP: 0.1160  coco/bbox_mAP_50: 0.2440  coco/bbox_mAP_75: 0.0940  coco/bbox_mAP_s: 0.0300  coco/bbox_mAP_m: 0.1750  coco/bbox_mAP_l: 0.3740  data_time: 0.0104  time: 0.9083
# 02/27 03:48:45 - mmengine - INFO - the monitored metric did not improve in the last 10 records. best score: 0.247.

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       1 ds = sv.DetectionDataset.from_coco(
#       2     images_directory_path=f"{dataset_location}/test",
#       3     annotations_path=f"{dataset_location}/test/_annotations.coco.json",
#       4 )
#       6 images = list(ds.images.values())
# ----> 7 CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
#       8 model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)
#      10 best_map, best_params = optimize_params(ds, model, param_space)
#
# NameError: name 'model_name' is not defined
