# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# /bin/bash: nvcc: command not found
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# /bin/bash: nvidia-smi: command not found
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 False
# 3.3.0
# 11.7
# GCC 9.3

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="grid_rcnn"
base_model_name="grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco"
custom_model_name=f"custom-{base_model_name}-hsv"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
dataset_location=f"/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-hsv"
print(CUSTOM_CONFIG_PATH)


CUSTOM_CONFIG = f"""
_base_ = './{base_model_name}.py'

# ========================Frequently modified parameters======================
# -----data related-----
model = dict(
    roi_head=dict(
        bbox_head=dict(num_classes={num_classes}),
))

dataset_type = 'COCODataset'
classes =  {classes}

data_root = '{dataset_location}' # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = {classes} 
num_classes = {num_classes}  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = {BATCH_SIZE}  # Batch size per GPU during training
#train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = {MAX_EPOCHS}  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image


# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=15,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    samples_per_gpu=8,
    #workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/_annotations.coco.json.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 8
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)




test_dataloader = dict(
    dataset=dict(
        data_root='{dataset_location}',
    ),)
test_evaluator = dict(
    ann_file='{dataset_location}/valid/_annotations.coco.json',)



train_dataloader = dict(

    dataset=dict(
        data_root='{dataset_location}',
    ),)

val_dataloader = dict(

    dataset=dict(

        data_root='{dataset_location}',
    ),)
    
    
val_evaluator = dict(
    ann_file=
    '{dataset_location}/valid/_annotations.coco.json',
)

"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/configs/grid_rcnn/custom-grid-rcnn_x101-64x4d_fpn_gn-head_2x_coco-hsv.py

# %%
# !python tools/train.py configs/{model_folder}/{custom_model_name}.py --resume\
    | tee "../log/OUT_{custom_model_name}_$(date +"%Y%m%d_%H%M%S").txt"
# Out:
# 03/01 22:14:28 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 121423069
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 121423069
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/01 22:14:29 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=8,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     samples_per_gpu=8,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/_annotations.coco.json.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'))
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv'
# dataset_type = 'COCODataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=15,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 300
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=4,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = True
# save_checkpoint_intervals = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(max_epochs=300, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 8
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-yuv/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# work_dir = './work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv'
#
# 03/01 22:14:34 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/01 22:14:34 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.50s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 03/01 22:14:36 - mmengine - INFO - load model from: torchvision://resnet50
# 03/01 22:14:36 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 03/01 22:14:37 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 03/01 22:14:37 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/epoch_286.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/epoch_286.pth
# 03/01 22:14:37 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/epoch_286.pth
# 03/01 22:14:37 - mmengine - INFO - resumed epoch: 286, iter: 67496
# 03/01 22:14:37 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/01 22:14:37 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 03/01 22:14:37 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv.
# 03/01 22:15:43 - mmengine - INFO - Epoch(train) [287][ 50/236]  lr: 2.0000e-04  eta: 1:11:25  time: 1.3169  data_time: 0.0165  memory: 10411  loss: 0.7068  loss_rpn_cls: 0.0544  loss_rpn_bbox: 0.1234  loss_cls: 0.1821  acc: 96.2891  loss_bbox: 0.3468
# 03/01 22:16:30 - mmengine - INFO - Epoch(train) [287][100/236]  lr: 2.0000e-04  eta: 0:59:55  time: 0.9278  data_time: 0.0060  memory: 4874  loss: 0.7212  loss_rpn_cls: 0.0587  loss_rpn_bbox: 0.1270  loss_cls: 0.1826  acc: 94.9219  loss_bbox: 0.3530
# 03/01 22:17:51 - mmengine - INFO - Epoch(train) [287][150/236]  lr: 2.0000e-04  eta: 1:07:47  time: 1.6244  data_time: 0.0061  memory: 4704  loss: 0.7093  loss_rpn_cls: 0.0554  loss_rpn_bbox: 0.1257  loss_cls: 0.1812  acc: 91.4062  loss_bbox: 0.3470
# 03/01 22:19:14 - mmengine - INFO - Epoch(train) [287][200/236]  lr: 2.0000e-04  eta: 1:11:32  time: 1.6628  data_time: 0.0049  memory: 5124  loss: 0.7039  loss_rpn_cls: 0.0562  loss_rpn_bbox: 0.1242  loss_cls: 0.1808  acc: 93.2617  loss_bbox: 0.3427
# 03/01 22:20:34 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:20:34 - mmengine - INFO - Saving checkpoint at 287 epochs
# 03/01 22:20:48 - mmengine - INFO - Epoch(val) [287][ 50/135]    eta: 0:00:20  time: 0.2419  data_time: 0.0086  memory: 9791
# 03/01 22:20:57 - mmengine - INFO - Epoch(val) [287][100/135]    eta: 0:00:07  time: 0.1921  data_time: 0.0018  memory: 551
# 03/01 22:21:06 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.94s).
# Accumulating evaluation results...
# DONE (t=0.33s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.406
# 03/01 22:21:23 - mmengine - INFO - bbox_mAP_copypaste: 0.100 0.206 0.085 0.029 0.154 0.305
# 03/01 22:21:23 - mmengine - INFO - Epoch(val) [287][135/135]    coco/bbox_mAP: 0.1000  coco/bbox_mAP_50: 0.2060  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1540  coco/bbox_mAP_l: 0.3050  data_time: 0.0044  time: 0.2235
# 03/01 22:21:23 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/best_coco_bbox_mAP_50_epoch_276.pth is removed
# 03/01 22:21:25 - mmengine - INFO - The best checkpoint with 0.2060 coco/bbox_mAP_50 at 287 epoch is saved to best_coco_bbox_mAP_50_epoch_287.pth.
# 03/01 22:23:06 - mmengine - INFO - Epoch(train) [288][ 50/236]  lr: 2.0000e-04  eta: 1:20:05  time: 1.9862  data_time: 0.0059  memory: 5122  loss: 0.7307  loss_rpn_cls: 0.0632  loss_rpn_bbox: 0.1301  loss_cls: 0.1834  acc: 92.5781  loss_bbox: 0.3540
# 03/01 22:24:23 - mmengine - INFO - Epoch(train) [288][100/236]  lr: 2.0000e-04  eta: 1:18:21  time: 1.5361  data_time: 0.0048  memory: 4710  loss: 0.6971  loss_rpn_cls: 0.0518  loss_rpn_bbox: 0.1238  loss_cls: 0.1732  acc: 94.6289  loss_bbox: 0.3484
# 03/01 22:25:48 - mmengine - INFO - Epoch(train) [288][150/236]  lr: 2.0000e-04  eta: 1:17:46  time: 1.7019  data_time: 0.0053  memory: 5122  loss: 0.7182  loss_rpn_cls: 0.0597  loss_rpn_bbox: 0.1240  loss_cls: 0.1887  acc: 88.6719  loss_bbox: 0.3458
# 03/01 22:27:10 - mmengine - INFO - Epoch(train) [288][200/236]  lr: 2.0000e-04  eta: 1:16:43  time: 1.6489  data_time: 0.0048  memory: 4709  loss: 0.7202  loss_rpn_cls: 0.0569  loss_rpn_bbox: 0.1258  loss_cls: 0.1860  acc: 92.7734  loss_bbox: 0.3515
# 03/01 22:28:02 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:28:02 - mmengine - INFO - Saving checkpoint at 288 epochs
# 03/01 22:28:17 - mmengine - INFO - Epoch(val) [288][ 50/135]    eta: 0:00:22  time: 0.2612  data_time: 0.0039  memory: 4872
# 03/01 22:28:31 - mmengine - INFO - Epoch(val) [288][100/135]    eta: 0:00:09  time: 0.2743  data_time: 0.0022  memory: 555
# 03/01 22:28:40 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.30s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.05s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.398
# 03/01 22:28:58 - mmengine - INFO - bbox_mAP_copypaste: 0.102 0.207 0.087 0.030 0.158 0.300
# 03/01 22:28:58 - mmengine - INFO - Epoch(val) [288][135/135]    coco/bbox_mAP: 0.1020  coco/bbox_mAP_50: 0.2070  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0300  coco/bbox_mAP_m: 0.1580  coco/bbox_mAP_l: 0.3000  data_time: 0.0029  time: 0.2704
# 03/01 22:28:58 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/best_coco_bbox_mAP_50_epoch_287.pth is removed
# 03/01 22:28:59 - mmengine - INFO - The best checkpoint with 0.2070 coco/bbox_mAP_50 at 288 epoch is saved to best_coco_bbox_mAP_50_epoch_288.pth.
# 03/01 22:29:31 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:29:48 - mmengine - INFO - Epoch(train) [289][ 50/236]  lr: 2.0000e-04  eta: 1:10:54  time: 0.9369  data_time: 0.0059  memory: 4872  loss: 0.6922  loss_rpn_cls: 0.0515  loss_rpn_bbox: 0.1215  loss_cls: 0.1752  acc: 93.2617  loss_bbox: 0.3441
# 03/01 22:30:59 - mmengine - INFO - Epoch(train) [289][100/236]  lr: 2.0000e-04  eta: 1:09:14  time: 1.4326  data_time: 0.0052  memory: 4879  loss: 0.7110  loss_rpn_cls: 0.0564  loss_rpn_bbox: 0.1251  loss_cls: 0.1834  acc: 96.0938  loss_bbox: 0.3461
# 03/01 22:32:19 - mmengine - INFO - Epoch(train) [289][150/236]  lr: 2.0000e-04  eta: 1:08:16  time: 1.6029  data_time: 0.0048  memory: 4104  loss: 0.7075  loss_rpn_cls: 0.0555  loss_rpn_bbox: 0.1208  loss_cls: 0.1836  acc: 93.5547  loss_bbox: 0.3476
# 03/01 22:33:42 - mmengine - INFO - Epoch(train) [289][200/236]  lr: 2.0000e-04  eta: 1:07:25  time: 1.6598  data_time: 0.0053  memory: 5122  loss: 0.7183  loss_rpn_cls: 0.0569  loss_rpn_bbox: 0.1264  loss_cls: 0.1853  acc: 95.4102  loss_bbox: 0.3498
# 03/01 22:34:31 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:34:31 - mmengine - INFO - Saving checkpoint at 289 epochs
# 03/01 22:34:46 - mmengine - INFO - Epoch(val) [289][ 50/135]    eta: 0:00:23  time: 0.2716  data_time: 0.0034  memory: 5129
# 03/01 22:35:00 - mmengine - INFO - Epoch(val) [289][100/135]    eta: 0:00:09  time: 0.2714  data_time: 0.0024  memory: 555
# 03/01 22:35:10 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=17.35s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.400
# 03/01 22:35:28 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.205 0.085 0.029 0.156 0.292
# 03/01 22:35:28 - mmengine - INFO - Epoch(val) [289][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2050  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1560  coco/bbox_mAP_l: 0.2920  data_time: 0.0027  time: 0.2721
# 03/01 22:36:53 - mmengine - INFO - Epoch(train) [290][ 50/236]  lr: 2.0000e-04  eta: 1:05:18  time: 1.7070  data_time: 0.0066  memory: 5122  loss: 0.7332  loss_rpn_cls: 0.0627  loss_rpn_bbox: 0.1317  loss_cls: 0.1840  acc: 93.1507  loss_bbox: 0.3549
# 03/01 22:38:17 - mmengine - INFO - Epoch(train) [290][100/236]  lr: 2.0000e-04  eta: 1:04:24  time: 1.6847  data_time: 0.0048  memory: 5122  loss: 0.7162  loss_rpn_cls: 0.0617  loss_rpn_bbox: 0.1281  loss_cls: 0.1841  acc: 92.0898  loss_bbox: 0.3423
# 03/01 22:39:39 - mmengine - INFO - Epoch(train) [290][150/236]  lr: 2.0000e-04  eta: 1:03:19  time: 1.6350  data_time: 0.0061  memory: 4879  loss: 0.6779  loss_rpn_cls: 0.0500  loss_rpn_bbox: 0.1160  loss_cls: 0.1710  acc: 94.5312  loss_bbox: 0.3409
# 03/01 22:41:00 - mmengine - INFO - Epoch(train) [290][200/236]  lr: 2.0000e-04  eta: 1:02:10  time: 1.6182  data_time: 0.0046  memory: 4702  loss: 0.7156  loss_rpn_cls: 0.0520  loss_rpn_bbox: 0.1266  loss_cls: 0.1815  acc: 94.3359  loss_bbox: 0.3556
# 03/01 22:41:52 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:41:52 - mmengine - INFO - Saving checkpoint at 290 epochs
# 03/01 22:42:07 - mmengine - INFO - Epoch(val) [290][ 50/135]    eta: 0:00:23  time: 0.2729  data_time: 0.0028  memory: 4104
# 03/01 22:42:21 - mmengine - INFO - Epoch(val) [290][100/135]    eta: 0:00:09  time: 0.2724  data_time: 0.0021  memory: 555
# 03/01 22:42:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.35s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.389
# 03/01 22:42:47 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.206 0.085 0.029 0.157 0.297
# 03/01 22:42:47 - mmengine - INFO - Epoch(val) [290][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2060  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1570  coco/bbox_mAP_l: 0.2970  data_time: 0.0024  time: 0.2717
# 03/01 22:44:13 - mmengine - INFO - Epoch(train) [291][ 50/236]  lr: 2.0000e-04  eta: 1:00:04  time: 1.7102  data_time: 0.0063  memory: 4078  loss: 0.6892  loss_rpn_cls: 0.0510  loss_rpn_bbox: 0.1234  loss_cls: 0.1689  acc: 90.6250  loss_bbox: 0.3460
# 03/01 22:45:13 - mmengine - INFO - Epoch(train) [291][100/236]  lr: 2.0000e-04  eta: 0:58:06  time: 1.1914  data_time: 0.0057  memory: 4872  loss: 0.7129  loss_rpn_cls: 0.0537  loss_rpn_bbox: 0.1254  loss_cls: 0.1806  acc: 94.7266  loss_bbox: 0.3532
# 03/01 22:45:59 - mmengine - INFO - Epoch(train) [291][150/236]  lr: 2.0000e-04  eta: 0:55:46  time: 0.9243  data_time: 0.0056  memory: 5122  loss: 0.7261  loss_rpn_cls: 0.0621  loss_rpn_bbox: 0.1292  loss_cls: 0.1879  acc: 95.2148  loss_bbox: 0.3470
# 03/01 22:46:42 - mmengine - INFO - Epoch(train) [291][200/236]  lr: 2.0000e-04  eta: 0:53:29  time: 0.8604  data_time: 0.0062  memory: 5122  loss: 0.7232  loss_rpn_cls: 0.0577  loss_rpn_bbox: 0.1282  loss_cls: 0.1847  acc: 94.0430  loss_bbox: 0.3525
# 03/01 22:47:02 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:47:02 - mmengine - INFO - Saving checkpoint at 291 epochs
# 03/01 22:47:13 - mmengine - INFO - Epoch(val) [291][ 50/135]    eta: 0:00:15  time: 0.1821  data_time: 0.0029  memory: 4879
# 03/01 22:47:22 - mmengine - INFO - Epoch(val) [291][100/135]    eta: 0:00:06  time: 0.1842  data_time: 0.0024  memory: 555
# 03/01 22:47:28 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.00s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.406
# 03/01 22:47:45 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.206 0.084 0.029 0.157 0.300
# 03/01 22:47:45 - mmengine - INFO - Epoch(val) [291][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2060  coco/bbox_mAP_75: 0.0840  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1570  coco/bbox_mAP_l: 0.3000  data_time: 0.0026  time: 0.1821
# 03/01 22:48:31 - mmengine - INFO - Epoch(train) [292][ 50/236]  lr: 2.0000e-04  eta: 0:49:38  time: 0.9334  data_time: 0.0058  memory: 4709  loss: 0.6761  loss_rpn_cls: 0.0491  loss_rpn_bbox: 0.1207  loss_cls: 0.1712  acc: 87.9883  loss_bbox: 0.3351
# 03/01 22:49:17 - mmengine - INFO - Epoch(train) [292][100/236]  lr: 2.0000e-04  eta: 0:47:45  time: 0.9170  data_time: 0.0053  memory: 4484  loss: 0.7059  loss_rpn_cls: 0.0565  loss_rpn_bbox: 0.1244  loss_cls: 0.1812  acc: 92.1875  loss_bbox: 0.3439
# 03/01 22:50:05 - mmengine - INFO - Epoch(train) [292][150/236]  lr: 2.0000e-04  eta: 0:45:59  time: 0.9440  data_time: 0.0055  memory: 5122  loss: 0.7175  loss_rpn_cls: 0.0549  loss_rpn_bbox: 0.1285  loss_cls: 0.1838  acc: 93.2617  loss_bbox: 0.3504
# 03/01 22:50:45 - mmengine - INFO - Epoch(train) [292][200/236]  lr: 2.0000e-04  eta: 0:44:08  time: 0.8018  data_time: 0.0066  memory: 5122  loss: 0.7213  loss_rpn_cls: 0.0603  loss_rpn_bbox: 0.1269  loss_cls: 0.1830  acc: 92.3828  loss_bbox: 0.3511
# 03/01 22:51:01 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:51:01 - mmengine - INFO - Saving checkpoint at 292 epochs
# 03/01 22:51:07 - mmengine - INFO - Epoch(val) [292][ 50/135]    eta: 0:00:07  time: 0.0937  data_time: 0.0030  memory: 3994
# 03/01 22:51:12 - mmengine - INFO - Epoch(val) [292][100/135]    eta: 0:00:03  time: 0.0926  data_time: 0.0020  memory: 555
# 03/01 22:51:15 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.78s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.411
# 03/01 22:51:31 - mmengine - INFO - bbox_mAP_copypaste: 0.102 0.208 0.084 0.028 0.160 0.305
# 03/01 22:51:31 - mmengine - INFO - Epoch(val) [292][135/135]    coco/bbox_mAP: 0.1020  coco/bbox_mAP_50: 0.2080  coco/bbox_mAP_75: 0.0840  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1600  coco/bbox_mAP_l: 0.3050  data_time: 0.0024  time: 0.0936
# 03/01 22:51:31 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/best_coco_bbox_mAP_50_epoch_288.pth is removed
# 03/01 22:51:33 - mmengine - INFO - The best checkpoint with 0.2080 coco/bbox_mAP_50 at 292 epoch is saved to best_coco_bbox_mAP_50_epoch_292.pth.
# 03/01 22:51:56 - mmengine - INFO - Epoch(train) [293][ 50/236]  lr: 2.0000e-04  eta: 0:40:30  time: 0.4463  data_time: 0.0052  memory: 4872  loss: 0.7270  loss_rpn_cls: 0.0621  loss_rpn_bbox: 0.1281  loss_cls: 0.1850  acc: 92.4925  loss_bbox: 0.3518
# 03/01 22:52:13 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:52:19 - mmengine - INFO - Epoch(train) [293][100/236]  lr: 2.0000e-04  eta: 0:38:32  time: 0.4466  data_time: 0.0049  memory: 4879  loss: 0.6908  loss_rpn_cls: 0.0540  loss_rpn_bbox: 0.1220  loss_cls: 0.1723  acc: 93.3594  loss_bbox: 0.3425
# 03/01 22:52:41 - mmengine - INFO - Epoch(train) [293][150/236]  lr: 2.0000e-04  eta: 0:36:40  time: 0.4453  data_time: 0.0049  memory: 4702  loss: 0.6877  loss_rpn_cls: 0.0505  loss_rpn_bbox: 0.1232  loss_cls: 0.1717  acc: 93.1641  loss_bbox: 0.3423
# 03/01 22:53:03 - mmengine - INFO - Epoch(train) [293][200/236]  lr: 2.0000e-04  eta: 0:34:54  time: 0.4439  data_time: 0.0048  memory: 4872  loss: 0.6527  loss_rpn_cls: 0.0452  loss_rpn_bbox: 0.1149  loss_cls: 0.1645  acc: 95.4102  loss_bbox: 0.3282
# 03/01 22:53:19 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:53:19 - mmengine - INFO - Saving checkpoint at 293 epochs
# 03/01 22:53:25 - mmengine - INFO - Epoch(val) [293][ 50/135]    eta: 0:00:07  time: 0.0937  data_time: 0.0029  memory: 5129
# 03/01 22:53:30 - mmengine - INFO - Epoch(val) [293][100/135]    eta: 0:00:03  time: 0.0930  data_time: 0.0020  memory: 555
# 03/01 22:53:33 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.77s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.382
# 03/01 22:53:50 - mmengine - INFO - bbox_mAP_copypaste: 0.098 0.202 0.085 0.027 0.156 0.282
# 03/01 22:53:50 - mmengine - INFO - Epoch(val) [293][135/135]    coco/bbox_mAP: 0.0980  coco/bbox_mAP_50: 0.2020  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1560  coco/bbox_mAP_l: 0.2820  data_time: 0.0023  time: 0.0931
# 03/01 22:54:12 - mmengine - INFO - Epoch(train) [294][ 50/236]  lr: 2.0000e-04  eta: 0:32:03  time: 0.4459  data_time: 0.0054  memory: 4111  loss: 0.7086  loss_rpn_cls: 0.0585  loss_rpn_bbox: 0.1265  loss_cls: 0.1821  acc: 95.8984  loss_bbox: 0.3415
# 03/01 22:54:34 - mmengine - INFO - Epoch(train) [294][100/236]  lr: 2.0000e-04  eta: 0:30:29  time: 0.4491  data_time: 0.0048  memory: 5129  loss: 0.7148  loss_rpn_cls: 0.0612  loss_rpn_bbox: 0.1292  loss_cls: 0.1829  acc: 90.9180  loss_bbox: 0.3415
# 03/01 22:54:57 - mmengine - INFO - Epoch(train) [294][150/236]  lr: 2.0000e-04  eta: 0:29:00  time: 0.4468  data_time: 0.0047  memory: 4879  loss: 0.7133  loss_rpn_cls: 0.0560  loss_rpn_bbox: 0.1257  loss_cls: 0.1788  acc: 93.1641  loss_bbox: 0.3528
# 03/01 22:55:19 - mmengine - INFO - Epoch(train) [294][200/236]  lr: 2.0000e-04  eta: 0:27:34  time: 0.4438  data_time: 0.0046  memory: 4477  loss: 0.6950  loss_rpn_cls: 0.0470  loss_rpn_bbox: 0.1216  loss_cls: 0.1789  acc: 91.5039  loss_bbox: 0.3475
# 03/01 22:55:35 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:55:35 - mmengine - INFO - Saving checkpoint at 294 epochs
# 03/01 22:55:41 - mmengine - INFO - Epoch(val) [294][ 50/135]    eta: 0:00:07  time: 0.0926  data_time: 0.0025  memory: 5129
# 03/01 22:55:45 - mmengine - INFO - Epoch(val) [294][100/135]    eta: 0:00:03  time: 0.0916  data_time: 0.0021  memory: 555
# 03/01 22:55:49 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.69s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.407
# 03/01 22:56:05 - mmengine - INFO - bbox_mAP_copypaste: 0.102 0.208 0.087 0.030 0.159 0.303
# 03/01 22:56:05 - mmengine - INFO - Epoch(val) [294][135/135]    coco/bbox_mAP: 0.1020  coco/bbox_mAP_50: 0.2080  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0300  coco/bbox_mAP_m: 0.1590  coco/bbox_mAP_l: 0.3030  data_time: 0.0022  time: 0.0923
# 03/01 22:56:27 - mmengine - INFO - Epoch(train) [295][ 50/236]  lr: 2.0000e-04  eta: 0:25:14  time: 0.4443  data_time: 0.0061  memory: 5122  loss: 0.6874  loss_rpn_cls: 0.0523  loss_rpn_bbox: 0.1186  loss_cls: 0.1761  acc: 92.7734  loss_bbox: 0.3404
# 03/01 22:56:50 - mmengine - INFO - Epoch(train) [295][100/236]  lr: 2.0000e-04  eta: 0:23:56  time: 0.4459  data_time: 0.0047  memory: 4111  loss: 0.7244  loss_rpn_cls: 0.0602  loss_rpn_bbox: 0.1291  loss_cls: 0.1811  acc: 95.9961  loss_bbox: 0.3540
# 03/01 22:57:12 - mmengine - INFO - Epoch(train) [295][150/236]  lr: 2.0000e-04  eta: 0:22:42  time: 0.4443  data_time: 0.0045  memory: 5129  loss: 0.6841  loss_rpn_cls: 0.0528  loss_rpn_bbox: 0.1210  loss_cls: 0.1734  acc: 92.2852  loss_bbox: 0.3369
# 03/01 22:57:34 - mmengine - INFO - Epoch(train) [295][200/236]  lr: 2.0000e-04  eta: 0:21:30  time: 0.4480  data_time: 0.0047  memory: 4872  loss: 0.7074  loss_rpn_cls: 0.0555  loss_rpn_bbox: 0.1243  loss_cls: 0.1843  acc: 93.7500  loss_bbox: 0.3434
# 03/01 22:57:50 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 22:57:50 - mmengine - INFO - Saving checkpoint at 295 epochs
# 03/01 22:57:57 - mmengine - INFO - Epoch(val) [295][ 50/135]    eta: 0:00:08  time: 0.0965  data_time: 0.0031  memory: 4872
# 03/01 22:58:02 - mmengine - INFO - Epoch(val) [295][100/135]    eta: 0:00:03  time: 0.0933  data_time: 0.0021  memory: 555
# 03/01 22:58:05 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.39s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.406
# 03/01 22:58:21 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.207 0.087 0.029 0.157 0.303
# 03/01 22:58:21 - mmengine - INFO - Epoch(val) [295][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2070  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1570  coco/bbox_mAP_l: 0.3030  data_time: 0.0024  time: 0.0940
# 03/01 22:58:43 - mmengine - INFO - Epoch(train) [296][ 50/236]  lr: 2.0000e-04  eta: 0:19:31  time: 0.4479  data_time: 0.0061  memory: 5122  loss: 0.6984  loss_rpn_cls: 0.0583  loss_rpn_bbox: 0.1259  loss_cls: 0.1750  acc: 91.5039  loss_bbox: 0.3392
# 03/01 22:59:05 - mmengine - INFO - Epoch(train) [296][100/236]  lr: 2.0000e-04  eta: 0:18:25  time: 0.4442  data_time: 0.0046  memory: 4484  loss: 0.7003  loss_rpn_cls: 0.0527  loss_rpn_bbox: 0.1208  loss_cls: 0.1804  acc: 91.6992  loss_bbox: 0.3465
# 03/01 22:59:28 - mmengine - INFO - Epoch(train) [296][150/236]  lr: 2.0000e-04  eta: 0:17:20  time: 0.4470  data_time: 0.0056  memory: 4879  loss: 0.6923  loss_rpn_cls: 0.0527  loss_rpn_bbox: 0.1228  loss_cls: 0.1758  acc: 90.8203  loss_bbox: 0.3410
# 03/01 22:59:50 - mmengine - INFO - Epoch(train) [296][200/236]  lr: 2.0000e-04  eta: 0:16:18  time: 0.4467  data_time: 0.0045  memory: 4879  loss: 0.6878  loss_rpn_cls: 0.0468  loss_rpn_bbox: 0.1206  loss_cls: 0.1781  acc: 92.8711  loss_bbox: 0.3423
# 03/01 23:00:06 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:00:06 - mmengine - INFO - Saving checkpoint at 296 epochs
# 03/01 23:00:13 - mmengine - INFO - Epoch(val) [296][ 50/135]    eta: 0:00:08  time: 0.0963  data_time: 0.0031  memory: 5122
# 03/01 23:00:17 - mmengine - INFO - Epoch(val) [296][100/135]    eta: 0:00:03  time: 0.0927  data_time: 0.0020  memory: 555
# 03/01 23:00:21 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.78s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.412
# 03/01 23:00:37 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.207 0.086 0.029 0.159 0.302
# 03/01 23:00:37 - mmengine - INFO - Epoch(val) [296][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2070  coco/bbox_mAP_75: 0.0860  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1590  coco/bbox_mAP_l: 0.3020  data_time: 0.0024  time: 0.0937
# 03/01 23:00:59 - mmengine - INFO - Epoch(train) [297][ 50/236]  lr: 2.0000e-04  eta: 0:14:34  time: 0.4479  data_time: 0.0061  memory: 4702  loss: 0.7163  loss_rpn_cls: 0.0600  loss_rpn_bbox: 0.1267  loss_cls: 0.1836  acc: 95.9961  loss_bbox: 0.3460
# 03/01 23:01:22 - mmengine - INFO - Epoch(train) [297][100/236]  lr: 2.0000e-04  eta: 0:13:36  time: 0.4486  data_time: 0.0045  memory: 5122  loss: 0.6960  loss_rpn_cls: 0.0595  loss_rpn_bbox: 0.1245  loss_cls: 0.1766  acc: 95.9961  loss_bbox: 0.3354
# 03/01 23:01:41 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:01:44 - mmengine - INFO - Epoch(train) [297][150/236]  lr: 2.0000e-04  eta: 0:12:40  time: 0.4466  data_time: 0.0046  memory: 4879  loss: 0.6666  loss_rpn_cls: 0.0458  loss_rpn_bbox: 0.1214  loss_cls: 0.1655  acc: 97.0703  loss_bbox: 0.3339
# 03/01 23:02:06 - mmengine - INFO - Epoch(train) [297][200/236]  lr: 2.0000e-04  eta: 0:11:45  time: 0.4476  data_time: 0.0045  memory: 5122  loss: 0.6658  loss_rpn_cls: 0.0512  loss_rpn_bbox: 0.1167  loss_cls: 0.1690  acc: 92.2852  loss_bbox: 0.3289
# 03/01 23:02:22 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:02:22 - mmengine - INFO - Saving checkpoint at 297 epochs
# 03/01 23:02:28 - mmengine - INFO - Epoch(val) [297][ 50/135]    eta: 0:00:08  time: 0.0953  data_time: 0.0029  memory: 4879
# 03/01 23:02:33 - mmengine - INFO - Epoch(val) [297][100/135]    eta: 0:00:03  time: 0.0938  data_time: 0.0019  memory: 555
# 03/01 23:02:37 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.84s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.406
# 03/01 23:02:53 - mmengine - INFO - bbox_mAP_copypaste: 0.102 0.207 0.087 0.029 0.158 0.308
# 03/01 23:02:53 - mmengine - INFO - Epoch(val) [297][135/135]    coco/bbox_mAP: 0.1020  coco/bbox_mAP_50: 0.2070  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1580  coco/bbox_mAP_l: 0.3080  data_time: 0.0024  time: 0.0944
# 03/01 23:03:15 - mmengine - INFO - Epoch(train) [298][ 50/236]  lr: 2.0000e-04  eta: 0:10:12  time: 0.4443  data_time: 0.0052  memory: 4702  loss: 0.6728  loss_rpn_cls: 0.0447  loss_rpn_bbox: 0.1191  loss_cls: 0.1688  acc: 95.3125  loss_bbox: 0.3402
# 03/01 23:03:37 - mmengine - INFO - Epoch(train) [298][100/236]  lr: 2.0000e-04  eta: 0:09:20  time: 0.4443  data_time: 0.0049  memory: 4709  loss: 0.6297  loss_rpn_cls: 0.0460  loss_rpn_bbox: 0.1099  loss_cls: 0.1544  acc: 88.8672  loss_bbox: 0.3193
# 03/01 23:04:00 - mmengine - INFO - Epoch(train) [298][150/236]  lr: 2.0000e-04  eta: 0:08:29  time: 0.4495  data_time: 0.0048  memory: 4879  loss: 0.7209  loss_rpn_cls: 0.0597  loss_rpn_bbox: 0.1265  loss_cls: 0.1852  acc: 94.1406  loss_bbox: 0.3495
# 03/01 23:04:22 - mmengine - INFO - Epoch(train) [298][200/236]  lr: 2.0000e-04  eta: 0:07:39  time: 0.4507  data_time: 0.0048  memory: 5129  loss: 0.7261  loss_rpn_cls: 0.0616  loss_rpn_bbox: 0.1313  loss_cls: 0.1857  acc: 87.9883  loss_bbox: 0.3475
# 03/01 23:04:38 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:04:38 - mmengine - INFO - Saving checkpoint at 298 epochs
# 03/01 23:04:45 - mmengine - INFO - Epoch(val) [298][ 50/135]    eta: 0:00:07  time: 0.0934  data_time: 0.0029  memory: 5122
# 03/01 23:04:49 - mmengine - INFO - Epoch(val) [298][100/135]    eta: 0:00:03  time: 0.0941  data_time: 0.0020  memory: 555
# 03/01 23:04:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.83s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.400
# 03/01 23:05:09 - mmengine - INFO - bbox_mAP_copypaste: 0.099 0.206 0.085 0.028 0.155 0.296
# 03/01 23:05:09 - mmengine - INFO - Epoch(val) [298][135/135]    coco/bbox_mAP: 0.0990  coco/bbox_mAP_50: 0.2060  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1550  coco/bbox_mAP_l: 0.2960  data_time: 0.0023  time: 0.0935
# 03/01 23:05:32 - mmengine - INFO - Epoch(train) [299][ 50/236]  lr: 2.0000e-04  eta: 0:06:16  time: 0.4485  data_time: 0.0060  memory: 5122  loss: 0.7101  loss_rpn_cls: 0.0594  loss_rpn_bbox: 0.1270  loss_cls: 0.1841  acc: 93.9453  loss_bbox: 0.3397
# 03/01 23:05:54 - mmengine - INFO - Epoch(train) [299][100/236]  lr: 2.0000e-04  eta: 0:05:28  time: 0.4461  data_time: 0.0046  memory: 4702  loss: 0.7090  loss_rpn_cls: 0.0519  loss_rpn_bbox: 0.1251  loss_cls: 0.1814  acc: 94.9219  loss_bbox: 0.3506
# 03/01 23:06:16 - mmengine - INFO - Epoch(train) [299][150/236]  lr: 2.0000e-04  eta: 0:04:42  time: 0.4507  data_time: 0.0047  memory: 4879  loss: 0.7151  loss_rpn_cls: 0.0573  loss_rpn_bbox: 0.1274  loss_cls: 0.1841  acc: 89.2578  loss_bbox: 0.3463
# 03/01 23:06:39 - mmengine - INFO - Epoch(train) [299][200/236]  lr: 2.0000e-04  eta: 0:03:56  time: 0.4482  data_time: 0.0046  memory: 5122  loss: 0.6848  loss_rpn_cls: 0.0536  loss_rpn_bbox: 0.1227  loss_cls: 0.1701  acc: 92.6758  loss_bbox: 0.3385
# 03/01 23:06:55 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:06:55 - mmengine - INFO - Saving checkpoint at 299 epochs
# 03/01 23:07:01 - mmengine - INFO - Epoch(val) [299][ 50/135]    eta: 0:00:08  time: 0.0949  data_time: 0.0030  memory: 4702
# 03/01 23:07:06 - mmengine - INFO - Epoch(val) [299][100/135]    eta: 0:00:03  time: 0.0938  data_time: 0.0020  memory: 555
# 03/01 23:07:09 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=16.03s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.160
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.134
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.400
# 03/01 23:07:26 - mmengine - INFO - bbox_mAP_copypaste: 0.101 0.204 0.088 0.028 0.160 0.301
# 03/01 23:07:26 - mmengine - INFO - Epoch(val) [299][135/135]    coco/bbox_mAP: 0.1010  coco/bbox_mAP_50: 0.2040  coco/bbox_mAP_75: 0.0880  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1600  coco/bbox_mAP_l: 0.3010  data_time: 0.0024  time: 0.0945
# 03/01 23:07:48 - mmengine - INFO - Epoch(train) [300][ 50/236]  lr: 2.0000e-04  eta: 0:02:39  time: 0.4432  data_time: 0.0053  memory: 4104  loss: 0.6652  loss_rpn_cls: 0.0445  loss_rpn_bbox: 0.1170  loss_cls: 0.1678  acc: 92.8711  loss_bbox: 0.3359
# 03/01 23:08:10 - mmengine - INFO - Epoch(train) [300][100/236]  lr: 2.0000e-04  eta: 0:01:55  time: 0.4430  data_time: 0.0061  memory: 4071  loss: 0.6470  loss_rpn_cls: 0.0478  loss_rpn_bbox: 0.1149  loss_cls: 0.1615  acc: 95.2475  loss_bbox: 0.3227
# 03/01 23:08:32 - mmengine - INFO - Epoch(train) [300][150/236]  lr: 2.0000e-04  eta: 0:01:12  time: 0.4484  data_time: 0.0045  memory: 4879  loss: 0.7127  loss_rpn_cls: 0.0571  loss_rpn_bbox: 0.1273  loss_cls: 0.1772  acc: 95.1172  loss_bbox: 0.3511
# 03/01 23:08:55 - mmengine - INFO - Epoch(train) [300][200/236]  lr: 2.0000e-04  eta: 0:00:30  time: 0.4516  data_time: 0.0047  memory: 5122  loss: 0.6991  loss_rpn_cls: 0.0541  loss_rpn_bbox: 0.1259  loss_cls: 0.1780  acc: 94.0430  loss_bbox: 0.3412
# 03/01 23:09:11 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-yuv_20240301_221424
# 03/01 23:09:11 - mmengine - INFO - Saving checkpoint at 300 epochs
# 03/01 23:09:17 - mmengine - INFO - Epoch(val) [300][ 50/135]    eta: 0:00:07  time: 0.0932  data_time: 0.0025  memory: 4709
# 03/01 23:09:22 - mmengine - INFO - Epoch(val) [300][100/135]    eta: 0:00:03  time: 0.0941  data_time: 0.0020  memory: 555
# 03/01 23:09:26 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.61s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.403
# 03/01 23:09:42 - mmengine - INFO - bbox_mAP_copypaste: 0.100 0.204 0.087 0.028 0.157 0.300
# 03/01 23:09:42 - mmengine - INFO - Epoch(val) [300][135/135]    coco/bbox_mAP: 0.1000  coco/bbox_mAP_50: 0.2040  coco/bbox_mAP_75: 0.0870  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1570  coco/bbox_mAP_l: 0.3000  data_time: 0.0022  time: 0.0941

# %%
CONFIDENCE_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{custom_model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

def callback(image: np.ndarray) -> sv.Detections:
    result = inference_detector(model, image)
    detections = sv.Detections.from_mmdetection(result)
    return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)


mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset = ds,
    callback = callback
)

print('mAP:', mean_average_precision.map50_95)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/best_coco_bbox_mAP_50_epoch_292.pth
# mAP: 0.34466125930426084

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{custom_model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-yuv/best_coco_bbox_mAP_50_epoch_292.pth
# |   iter    |  target   | confid... | nms_io... |
# -------------------------------------------------
# | 1         | 0.3383    | 0.4371    | 0.9556    |
# | 2         | 0.3741    | 0.7588    | 0.6388    |
# | 3         | 0.341     | 0.2404    | 0.2404    |
# | 4         | 0.3185    | 0.1523    | 0.8796    |
# | 5         | 0.3582    | 0.641     | 0.7373    |
# | 6         | 0.0       | 1.0       | 0.4306    |
# | 7         | 0.3454    | 0.5362    | 0.5189    |
# | 8         | 0.3858    | 0.8475    | 0.9144    |
# | 9         | 0.3828    | 0.8208    | 0.8899    |
# | 10        | 0.315     | 0.1       | 0.5253    |
# | 11        | 0.3566    | 0.5287    | 0.1       |
# | 12        | 0.3443    | 0.4976    | 0.8419    |
# | 13        | 0.3338    | 0.1       | 0.1       |
# | 14        | 0.3637    | 0.6861    | 1.0       |
# | 15        | 0.0       | 1.0       | 1.0       |
# | 16        | 0.3691    | 0.6437    | 0.2365    |
# | 17        | 0.3541    | 0.475     | 0.289     |
# | 18        | 0.3777    | 0.7416    | 0.1       |
# | 19        | 0.3325    | 0.367     | 0.659     |
# | 20        | 0.3776    | 0.7486    | 0.1011    |
# | 21        | 0.3346    | 0.3263    | 0.4385    |
# | 22        | 0.3461    | 0.3462    | 0.1017    |
# | 23        | 0.3851    | 0.8373    | 0.7127    |
# | 24        | 0.3742    | 0.7598    | 0.639     |
# | 25        | 0.0       | 1.0       | 0.1       |
# | 26        | 0.33      | 0.1067    | 0.3314    |
# | 27        | 0.3246    | 0.2576    | 0.9987    |
# | 28        | 0.3666    | 0.676     | 0.4117    |
# | 29        | 0.315     | 0.1       | 0.7089    |
# | 30        | 0.315     | 0.1       | 1.0       |
# =================================================
# Best mAP: 0.38576235506725765
# Best Parameters: [0.8474831810221157, 0.9144467385288542]

# %%
print()
