# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Mon Mar 11 23:38:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       On  | 00000000:5E:00.0 Off |                    0 |
# | N/A   34C    P8              12W /  70W |      2MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="faster_rcnn"
base_model_name="faster-rcnn_r50_fpn_1x_coco"
custom_model_name=f"custom-{base_model_name}-log"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
dataset_location=f"/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-log"
print(CUSTOM_CONFIG_PATH)


CUSTOM_CONFIG = f"""
_base_ = './{base_model_name}.py'

# ========================Frequently modified parameters======================
# -----data related-----
model = dict(
    roi_head=dict(
        bbox_head=dict(num_classes={num_classes}),
))

dataset_type = 'COCODataset'
classes =  {classes}

data_root = '{dataset_location}' # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = {classes} 
num_classes = {num_classes}  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = {BATCH_SIZE}  # Batch size per GPU during training
#train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
base_lr = 0.004  # Base learning rate for optimization
max_epochs = {MAX_EPOCHS}  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image


# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=20,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    samples_per_gpu=8,
    #workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/_annotations.coco.json.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 8
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)



test_dataloader = dict(
    dataset=dict(
        data_root='{dataset_location}',
    ),)
test_evaluator = dict(
    ann_file='{dataset_location}/valid/_annotations.coco.json',)



train_dataloader = dict(

    dataset=dict(
        data_root='{dataset_location}',
    ),)

val_dataloader = dict(

    dataset=dict(

        data_root='{dataset_location}',
    ),)
    
    
val_evaluator = dict(
    ann_file=
    '{dataset_location}/valid/_annotations.coco.json',
)

"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/configs/faster_rcnn/custom-faster-rcnn_r50_fpn_1x_coco-log.py

# %%
# !python tools/train.py configs/{model_folder}/{custom_model_name}.py \
    --resume --cfg-options randomness.seed=42 \
    | tee "../log/OUT_{custom_model_name}_$(date +"%Y%m%d_%H%M%S").txt"
# Out:
# 02/28 18:12:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 42
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 42
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/28 18:12:58 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.004
# batch_shapes_cfg = dict(
#     batch_size=8,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     samples_per_gpu=8,
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/_annotations.coco.json.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'))
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab'
# dataset_type = 'COCODataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=20,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 200
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=4,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# randomness = dict(seed=42)
# resume = True
# save_checkpoint_intervals = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(max_epochs=200, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 8
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1-lab/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# work_dir = './work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-lab'
#
# 02/28 18:13:02 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/28 18:13:02 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.52s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 02/28 18:13:05 - mmengine - INFO - load model from: torchvision://resnet50
# 02/28 18:13:05 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 02/28 18:13:05 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 02/28 18:13:05 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-lab/epoch_32.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-lab/epoch_32.pth
# 02/28 18:13:06 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-lab/epoch_32.pth
# 02/28 18:13:06 - mmengine - WARNING - The value of random seed in the checkpoint "484897047" is different from the value in `randomness` config "42"
# 02/28 18:13:06 - mmengine - INFO - resumed epoch: 32, iter: 7552
# 02/28 18:13:06 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/28 18:13:06 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/28 18:13:06 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-lab.
# 02/28 18:14:07 - mmengine - INFO - Epoch(train)  [33][ 50/236]  lr: 2.0000e-04  eta: 13:23:36  time: 1.2177  data_time: 0.0126  memory: 9094  loss: 1.4263  loss_rpn_cls: 0.2359  loss_rpn_bbox: 0.1971  loss_cls: 0.4676  acc: 81.3477  loss_bbox: 0.5257
# 02/28 18:14:51 - mmengine - INFO - Epoch(train)  [33][100/236]  lr: 2.0000e-04  eta: 11:33:56  time: 0.8880  data_time: 0.0065  memory: 5118  loss: 1.3882  loss_rpn_cls: 0.2242  loss_rpn_bbox: 0.1873  loss_cls: 0.4561  acc: 79.8828  loss_bbox: 0.5205
# 02/28 18:15:20 - mmengine - INFO - Epoch(train)  [33][150/236]  lr: 2.0000e-04  eta: 9:48:50  time: 0.5778  data_time: 0.0046  memory: 4875  loss: 1.3945  loss_rpn_cls: 0.2160  loss_rpn_bbox: 0.1895  loss_cls: 0.4619  acc: 80.2734  loss_bbox: 0.5271
# 02/28 18:16:05 - mmengine - INFO - Epoch(train)  [33][200/236]  lr: 2.0000e-04  eta: 9:48:56  time: 0.8996  data_time: 0.0045  memory: 4699  loss: 1.3864  loss_rpn_cls: 0.2190  loss_rpn_bbox: 0.1852  loss_cls: 0.4600  acc: 82.4219  loss_bbox: 0.5222
# 02/28 18:16:48 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:16:48 - mmengine - INFO - Saving checkpoint at 33 epochs
# 02/28 18:16:58 - mmengine - INFO - Epoch(val)  [33][ 50/135]    eta: 0:00:15  time: 0.1801  data_time: 0.0068  memory: 9213
# 02/28 18:17:07 - mmengine - INFO - Epoch(val)  [33][100/135]    eta: 0:00:06  time: 0.1785  data_time: 0.0026  memory: 551
# 02/28 18:17:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.83s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.039
# 02/28 18:17:28 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.010 0.002 0.017 0.021
# 02/28 18:17:28 - mmengine - INFO - Epoch(val) [33][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0040  time: 0.1775
# 02/28 18:18:13 - mmengine - INFO - Epoch(train)  [34][ 50/236]  lr: 2.0000e-04  eta: 10:13:17  time: 0.9113  data_time: 0.0065  memory: 4701  loss: 1.3779  loss_rpn_cls: 0.2132  loss_rpn_bbox: 0.1868  loss_cls: 0.4534  acc: 80.9570  loss_bbox: 0.5245
# 02/28 18:18:58 - mmengine - INFO - Epoch(train)  [34][100/236]  lr: 2.0000e-04  eta: 10:08:34  time: 0.8945  data_time: 0.0049  memory: 5120  loss: 1.3824  loss_rpn_cls: 0.2228  loss_rpn_bbox: 0.1888  loss_cls: 0.4545  acc: 84.5703  loss_bbox: 0.5163
# 02/28 18:19:27 - mmengine - INFO - Epoch(train)  [34][150/236]  lr: 2.0000e-04  eta: 9:37:53  time: 0.5759  data_time: 0.0045  memory: 4878  loss: 1.4291  loss_rpn_cls: 0.2446  loss_rpn_bbox: 0.1978  loss_cls: 0.4688  acc: 82.1289  loss_bbox: 0.5180
# 02/28 18:20:12 - mmengine - INFO - Epoch(train)  [34][200/236]  lr: 2.0000e-04  eta: 9:39:25  time: 0.9134  data_time: 0.0055  memory: 5120  loss: 1.3913  loss_rpn_cls: 0.2138  loss_rpn_bbox: 0.1878  loss_cls: 0.4639  acc: 79.0039  loss_bbox: 0.5258
# 02/28 18:20:23 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:20:44 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:20:44 - mmengine - INFO - Saving checkpoint at 34 epochs
# 02/28 18:20:55 - mmengine - INFO - Epoch(val)  [34][ 50/135]    eta: 0:00:14  time: 0.1753  data_time: 0.0030  memory: 4103
# 02/28 18:21:04 - mmengine - INFO - Epoch(val)  [34][100/135]    eta: 0:00:06  time: 0.1809  data_time: 0.0023  memory: 555
# 02/28 18:21:10 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.02s).
# Accumulating evaluation results...
# DONE (t=0.30s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.040
# 02/28 18:21:25 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.024 0.010 0.002 0.017 0.021
# 02/28 18:21:25 - mmengine - INFO - Epoch(val) [34][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0025  time: 0.1792
# 02/28 18:22:11 - mmengine - INFO - Epoch(train)  [35][ 50/236]  lr: 2.0000e-04  eta: 9:40:32  time: 0.9332  data_time: 0.0054  memory: 5120  loss: 1.3869  loss_rpn_cls: 0.2225  loss_rpn_bbox: 0.1896  loss_cls: 0.4576  acc: 79.9805  loss_bbox: 0.5172
# 02/28 18:22:54 - mmengine - INFO - Epoch(train)  [35][100/236]  lr: 2.0000e-04  eta: 9:38:17  time: 0.8637  data_time: 0.0042  memory: 4878  loss: 1.3949  loss_rpn_cls: 0.2386  loss_rpn_bbox: 0.1922  loss_cls: 0.4566  acc: 80.1758  loss_bbox: 0.5076
# 02/28 18:23:23 - mmengine - INFO - Epoch(train)  [35][150/236]  lr: 2.0000e-04  eta: 9:20:37  time: 0.5643  data_time: 0.0054  memory: 4708  loss: 1.3987  loss_rpn_cls: 0.2218  loss_rpn_bbox: 0.1905  loss_cls: 0.4597  acc: 83.8867  loss_bbox: 0.5266
# 02/28 18:24:08 - mmengine - INFO - Epoch(train)  [35][200/236]  lr: 2.0000e-04  eta: 9:22:07  time: 0.9078  data_time: 0.0048  memory: 4476  loss: 1.4128  loss_rpn_cls: 0.2168  loss_rpn_bbox: 0.1901  loss_cls: 0.4709  acc: 82.1289  loss_bbox: 0.5350
# 02/28 18:24:40 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:24:40 - mmengine - INFO - Saving checkpoint at 35 epochs
# 02/28 18:24:50 - mmengine - INFO - Epoch(val)  [35][ 50/135]    eta: 0:00:15  time: 0.1801  data_time: 0.0023  memory: 4872
# 02/28 18:24:59 - mmengine - INFO - Epoch(val)  [35][100/135]    eta: 0:00:06  time: 0.1743  data_time: 0.0020  memory: 555
# 02/28 18:25:06 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.66s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.038
# 02/28 18:25:20 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.010 0.002 0.017 0.021
# 02/28 18:25:20 - mmengine - INFO - Epoch(val) [35][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0021  time: 0.1787
# 02/28 18:26:04 - mmengine - INFO - Epoch(train)  [36][ 50/236]  lr: 2.0000e-04  eta: 9:22:28  time: 0.8908  data_time: 0.0048  memory: 5120  loss: 1.4122  loss_rpn_cls: 0.2321  loss_rpn_bbox: 0.1940  loss_cls: 0.4629  acc: 80.8594  loss_bbox: 0.5233
# 02/28 18:26:49 - mmengine - INFO - Epoch(train)  [36][100/236]  lr: 2.0000e-04  eta: 9:23:12  time: 0.9042  data_time: 0.0047  memory: 5127  loss: 1.4158  loss_rpn_cls: 0.2332  loss_rpn_bbox: 0.1963  loss_cls: 0.4589  acc: 82.1289  loss_bbox: 0.5274
# 02/28 18:27:23 - mmengine - INFO - Epoch(train)  [36][150/236]  lr: 2.0000e-04  eta: 9:14:43  time: 0.6640  data_time: 0.0046  memory: 4708  loss: 1.3104  loss_rpn_cls: 0.1879  loss_rpn_bbox: 0.1760  loss_cls: 0.4361  acc: 88.1836  loss_bbox: 0.5105
# 02/28 18:28:04 - mmengine - INFO - Epoch(train)  [36][200/236]  lr: 2.0000e-04  eta: 9:13:07  time: 0.8333  data_time: 0.0049  memory: 4872  loss: 1.4084  loss_rpn_cls: 0.2296  loss_rpn_bbox: 0.1929  loss_cls: 0.4624  acc: 79.6875  loss_bbox: 0.5234
# 02/28 18:28:36 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:28:36 - mmengine - INFO - Saving checkpoint at 36 epochs
# 02/28 18:28:47 - mmengine - INFO - Epoch(val)  [36][ 50/135]    eta: 0:00:15  time: 0.1830  data_time: 0.0028  memory: 3934
# 02/28 18:28:56 - mmengine - INFO - Epoch(val)  [36][100/135]    eta: 0:00:06  time: 0.1695  data_time: 0.0026  memory: 555
# 02/28 18:29:02 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.50s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.042
# 02/28 18:29:16 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.024 0.010 0.002 0.017 0.021
# 02/28 18:29:16 - mmengine - INFO - Epoch(val) [36][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0026  time: 0.1793
# 02/28 18:30:01 - mmengine - INFO - Epoch(train)  [37][ 50/236]  lr: 2.0000e-04  eta: 9:13:59  time: 0.8937  data_time: 0.0056  memory: 4878  loss: 1.3774  loss_rpn_cls: 0.2057  loss_rpn_bbox: 0.1845  loss_cls: 0.4593  acc: 82.1289  loss_bbox: 0.5279
# 02/28 18:30:48 - mmengine - INFO - Epoch(train)  [37][100/236]  lr: 2.0000e-04  eta: 9:15:23  time: 0.9290  data_time: 0.0044  memory: 4872  loss: 1.3431  loss_rpn_cls: 0.2165  loss_rpn_bbox: 0.1859  loss_cls: 0.4376  acc: 82.4219  loss_bbox: 0.5030
# 02/28 18:31:23 - mmengine - INFO - Epoch(train)  [37][150/236]  lr: 2.0000e-04  eta: 9:10:16  time: 0.7131  data_time: 0.0054  memory: 4878  loss: 1.4169  loss_rpn_cls: 0.2259  loss_rpn_bbox: 0.1948  loss_cls: 0.4634  acc: 83.1055  loss_bbox: 0.5329
# 02/28 18:31:58 - mmengine - INFO - Epoch(train)  [37][200/236]  lr: 2.0000e-04  eta: 9:04:48  time: 0.6872  data_time: 0.0042  memory: 5120  loss: 1.4081  loss_rpn_cls: 0.2296  loss_rpn_bbox: 0.1910  loss_cls: 0.4643  acc: 90.9180  loss_bbox: 0.5233
# 02/28 18:32:29 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:32:29 - mmengine - INFO - Saving checkpoint at 37 epochs
# 02/28 18:32:40 - mmengine - INFO - Epoch(val)  [37][ 50/135]    eta: 0:00:15  time: 0.1781  data_time: 0.0023  memory: 5127
# 02/28 18:32:48 - mmengine - INFO - Epoch(val)  [37][100/135]    eta: 0:00:06  time: 0.1769  data_time: 0.0021  memory: 555
# 02/28 18:32:55 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.52s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.040
# 02/28 18:33:09 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.024 0.010 0.001 0.017 0.022
# 02/28 18:33:09 - mmengine - INFO - Epoch(val) [37][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0220  data_time: 0.0021  time: 0.1794
# 02/28 18:33:55 - mmengine - INFO - Epoch(train)  [38][ 50/236]  lr: 2.0000e-04  eta: 9:05:45  time: 0.9109  data_time: 0.0060  memory: 4483  loss: 1.3859  loss_rpn_cls: 0.2181  loss_rpn_bbox: 0.1919  loss_cls: 0.4485  acc: 85.9375  loss_bbox: 0.5274
# 02/28 18:34:40 - mmengine - INFO - Epoch(train)  [38][100/236]  lr: 2.0000e-04  eta: 9:06:27  time: 0.9089  data_time: 0.0050  memory: 5127  loss: 1.3598  loss_rpn_cls: 0.2194  loss_rpn_bbox: 0.1844  loss_cls: 0.4447  acc: 78.2227  loss_bbox: 0.5113
# 02/28 18:35:23 - mmengine - INFO - Epoch(train)  [38][150/236]  lr: 2.0000e-04  eta: 9:06:00  time: 0.8658  data_time: 0.0047  memory: 4000  loss: 1.4111  loss_rpn_cls: 0.2271  loss_rpn_bbox: 0.1902  loss_cls: 0.4667  acc: 78.3203  loss_bbox: 0.5271
# 02/28 18:35:50 - mmengine - INFO - Epoch(train)  [38][200/236]  lr: 2.0000e-04  eta: 8:57:39  time: 0.5244  data_time: 0.0040  memory: 5127  loss: 1.3801  loss_rpn_cls: 0.2205  loss_rpn_bbox: 0.1865  loss_cls: 0.4490  acc: 78.2227  loss_bbox: 0.5241
# 02/28 18:36:22 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:36:22 - mmengine - INFO - Saving checkpoint at 38 epochs
# 02/28 18:36:33 - mmengine - INFO - Epoch(val)  [38][ 50/135]    eta: 0:00:15  time: 0.1765  data_time: 0.0026  memory: 4871
# 02/28 18:36:41 - mmengine - INFO - Epoch(val)  [38][100/135]    eta: 0:00:06  time: 0.1762  data_time: 0.0020  memory: 555
# 02/28 18:36:48 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.38s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
# 02/28 18:37:02 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.010 0.002 0.017 0.021
# 02/28 18:37:02 - mmengine - INFO - Epoch(val) [38][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0024  time: 0.1763
# 02/28 18:37:31 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:37:47 - mmengine - INFO - Epoch(train)  [39][ 50/236]  lr: 2.0000e-04  eta: 8:58:59  time: 0.9133  data_time: 0.0055  memory: 4701  loss: 1.3590  loss_rpn_cls: 0.2199  loss_rpn_bbox: 0.1872  loss_cls: 0.4451  acc: 81.1523  loss_bbox: 0.5068
# 02/28 18:38:34 - mmengine - INFO - Epoch(train)  [39][100/236]  lr: 2.0000e-04  eta: 9:00:05  time: 0.9332  data_time: 0.0047  memory: 5127  loss: 1.4059  loss_rpn_cls: 0.2270  loss_rpn_bbox: 0.1901  loss_cls: 0.4616  acc: 81.2500  loss_bbox: 0.5272
# 02/28 18:39:18 - mmengine - INFO - Epoch(train)  [39][150/236]  lr: 2.0000e-04  eta: 8:59:49  time: 0.8721  data_time: 0.0044  memory: 5120  loss: 1.4167  loss_rpn_cls: 0.2314  loss_rpn_bbox: 0.1960  loss_cls: 0.4633  acc: 80.6641  loss_bbox: 0.5261
# 02/28 18:39:46 - mmengine - INFO - Epoch(train)  [39][200/236]  lr: 2.0000e-04  eta: 8:53:46  time: 0.5776  data_time: 0.0043  memory: 4103  loss: 1.3879  loss_rpn_cls: 0.2081  loss_rpn_bbox: 0.1850  loss_cls: 0.4624  acc: 80.1758  loss_bbox: 0.5323
# 02/28 18:40:17 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:40:17 - mmengine - INFO - Saving checkpoint at 39 epochs
# 02/28 18:40:28 - mmengine - INFO - Epoch(val)  [39][ 50/135]    eta: 0:00:15  time: 0.1796  data_time: 0.0030  memory: 4872
# 02/28 18:40:37 - mmengine - INFO - Epoch(val)  [39][100/135]    eta: 0:00:06  time: 0.1786  data_time: 0.0021  memory: 555
# 02/28 18:40:44 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.35s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.043
# 02/28 18:40:58 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.010 0.002 0.017 0.021
# 02/28 18:40:58 - mmengine - INFO - Epoch(val) [39][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0026  time: 0.1799
# 02/28 18:41:44 - mmengine - INFO - Epoch(train)  [40][ 50/236]  lr: 2.0000e-04  eta: 8:54:17  time: 0.9249  data_time: 0.0057  memory: 5120  loss: 1.3623  loss_rpn_cls: 0.2215  loss_rpn_bbox: 0.1870  loss_cls: 0.4427  acc: 82.0312  loss_bbox: 0.5111
# 02/28 18:42:28 - mmengine - INFO - Epoch(train)  [40][100/236]  lr: 2.0000e-04  eta: 8:54:25  time: 0.8908  data_time: 0.0050  memory: 4701  loss: 1.3772  loss_rpn_cls: 0.2132  loss_rpn_bbox: 0.1847  loss_cls: 0.4516  acc: 81.3477  loss_bbox: 0.5278
# 02/28 18:43:13 - mmengine - INFO - Epoch(train)  [40][150/236]  lr: 2.0000e-04  eta: 8:54:30  time: 0.8919  data_time: 0.0055  memory: 4708  loss: 1.3928  loss_rpn_cls: 0.2269  loss_rpn_bbox: 0.1922  loss_cls: 0.4612  acc: 81.3477  loss_bbox: 0.5125
# 02/28 18:43:47 - mmengine - INFO - Epoch(train)  [40][200/236]  lr: 2.0000e-04  eta: 8:51:00  time: 0.6829  data_time: 0.0092  memory: 5120  loss: 1.4171  loss_rpn_cls: 0.2255  loss_rpn_bbox: 0.1904  loss_cls: 0.4713  acc: 79.7852  loss_bbox: 0.5299
# 02/28 18:44:14 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:44:14 - mmengine - INFO - Saving checkpoint at 40 epochs
# 02/28 18:44:24 - mmengine - INFO - Epoch(val)  [40][ 50/135]    eta: 0:00:15  time: 0.1818  data_time: 0.0026  memory: 4872
# 02/28 18:44:33 - mmengine - INFO - Epoch(val)  [40][100/135]    eta: 0:00:06  time: 0.1790  data_time: 0.0023  memory: 555
# 02/28 18:44:40 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.54s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.043
# 02/28 18:44:54 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.024 0.010 0.002 0.017 0.021
# 02/28 18:44:54 - mmengine - INFO - Epoch(val) [40][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0024  time: 0.1807
# 02/28 18:45:39 - mmengine - INFO - Epoch(train)  [41][ 50/236]  lr: 2.0000e-04  eta: 8:49:29  time: 0.9028  data_time: 0.0074  memory: 4000  loss: 1.3972  loss_rpn_cls: 0.2204  loss_rpn_bbox: 0.1892  loss_cls: 0.4568  acc: 79.7852  loss_bbox: 0.5308
# 02/28 18:46:24 - mmengine - INFO - Epoch(train)  [41][100/236]  lr: 2.0000e-04  eta: 8:49:55  time: 0.9136  data_time: 0.0047  memory: 4878  loss: 1.3525  loss_rpn_cls: 0.2143  loss_rpn_bbox: 0.1810  loss_cls: 0.4438  acc: 82.0312  loss_bbox: 0.5134
# 02/28 18:47:10 - mmengine - INFO - Epoch(train)  [41][150/236]  lr: 2.0000e-04  eta: 8:50:11  time: 0.9077  data_time: 0.0048  memory: 4708  loss: 1.3765  loss_rpn_cls: 0.2099  loss_rpn_bbox: 0.1839  loss_cls: 0.4465  acc: 79.3945  loss_bbox: 0.5362
# 02/28 18:47:47 - mmengine - INFO - Epoch(train)  [41][200/236]  lr: 2.0000e-04  eta: 8:47:59  time: 0.7463  data_time: 0.0054  memory: 5127  loss: 1.3735  loss_rpn_cls: 0.2276  loss_rpn_bbox: 0.1892  loss_cls: 0.4578  acc: 80.0781  loss_bbox: 0.4988
# 02/28 18:48:06 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 18:48:06 - mmengine - INFO - Saving checkpoint at 41 epochs
# 02/28 18:48:16 - mmengine - INFO - Epoch(val)  [41][ 50/135]    eta: 0:00:13  time: 0.1646  data_time: 0.0023  memory: 4103
# 02/28 18:48:24 - mmengine - INFO - Epoch(val)  [41][100/135]    eta: 0:00:05  time: 0.1749  data_time: 0.0019  memory: 555
# 02/28 18:48:31 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.47s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.039
# 02/28 18:48:45 - mmengine - INFO - bbox_mAP_copypaste: 0.011 0.024 0.009 0.002 0.017 0.021
# 02/28 18:48:45 - mmengine - INFO - Epoch(val) [41][135/135]    coco/bbox_mAP: 0.0110  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0090  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0210  data_time: 0.0020  time: 0.1722
# 02/28 18:49:30 - mmengine - INFO - Epoch(train)  [42][ 50/236]  lr: 2.0000e-04  eta: 8:44:13  time: 0.8981  data_time: 0.0058  memory: 4878  loss: 1.3836  loss_rpn_cls: 0.2242  loss_rpn_bbox: 0.1876  loss_cls: 0.4521  acc: 89.0625  loss_bbox: 0.5196
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
# 02/28 20:11:47 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.025 0.010 0.002 0.016 0.022
# 02/28 20:11:47 - mmengine - INFO - Epoch(val) [62][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0250  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0160  coco/bbox_mAP_l: 0.0220  data_time: 0.0026  time: 0.1749
# 02/28 20:12:33 - mmengine - INFO - Epoch(train)  [63][ 50/236]  lr: 2.0000e-04  eta: 7:38:27  time: 0.9178  data_time: 0.0054  memory: 4878  loss: 1.3128  loss_rpn_cls: 0.1977  loss_rpn_bbox: 0.1836  loss_cls: 0.4277  acc: 82.1289  loss_bbox: 0.5038
# 02/28 20:13:18 - mmengine - INFO - Epoch(train)  [63][100/236]  lr: 2.0000e-04  eta: 7:37:58  time: 0.9053  data_time: 0.0063  memory: 4878  loss: 1.3712  loss_rpn_cls: 0.2170  loss_rpn_bbox: 0.1879  loss_cls: 0.4501  acc: 74.8047  loss_bbox: 0.5161
# 02/28 20:14:04 - mmengine - INFO - Epoch(train)  [63][150/236]  lr: 2.0000e-04  eta: 7:37:30  time: 0.9120  data_time: 0.0052  memory: 4878  loss: 1.3375  loss_rpn_cls: 0.2041  loss_rpn_bbox: 0.1806  loss_cls: 0.4417  acc: 88.0859  loss_bbox: 0.5111
# 02/28 20:14:38 - mmengine - INFO - Epoch(train)  [63][200/236]  lr: 2.0000e-04  eta: 7:36:13  time: 0.6876  data_time: 0.0051  memory: 5120  loss: 1.3662  loss_rpn_cls: 0.2208  loss_rpn_bbox: 0.1890  loss_cls: 0.4468  acc: 80.7617  loss_bbox: 0.5096
# 02/28 20:15:02 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:15:02 - mmengine - INFO - Saving checkpoint at 63 epochs
# 02/28 20:15:12 - mmengine - INFO - Epoch(val)  [63][ 50/135]    eta: 0:00:15  time: 0.1769  data_time: 0.0029  memory: 5120
# 02/28 20:15:22 - mmengine - INFO - Epoch(val)  [63][100/135]    eta: 0:00:06  time: 0.1850  data_time: 0.0023  memory: 555
# 02/28 20:15:28 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.29s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
# 02/28 20:15:42 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.010 0.001 0.016 0.022
# 02/28 20:15:42 - mmengine - INFO - Epoch(val) [63][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0160  coco/bbox_mAP_l: 0.0220  data_time: 0.0025  time: 0.1809
# 02/28 20:16:28 - mmengine - INFO - Epoch(train)  [64][ 50/236]  lr: 2.0000e-04  eta: 7:34:46  time: 0.9088  data_time: 0.0052  memory: 4701  loss: 1.3408  loss_rpn_cls: 0.2219  loss_rpn_bbox: 0.1844  loss_cls: 0.4342  acc: 82.6172  loss_bbox: 0.5003
# 02/28 20:17:12 - mmengine - INFO - Epoch(train)  [64][100/236]  lr: 2.0000e-04  eta: 7:34:14  time: 0.8953  data_time: 0.0058  memory: 5120  loss: 1.3252  loss_rpn_cls: 0.1905  loss_rpn_bbox: 0.1790  loss_cls: 0.4341  acc: 84.7656  loss_bbox: 0.5215
# 02/28 20:17:41 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:17:58 - mmengine - INFO - Epoch(train)  [64][150/236]  lr: 2.0000e-04  eta: 7:33:45  time: 0.9071  data_time: 0.0047  memory: 4872  loss: 1.3623  loss_rpn_cls: 0.2076  loss_rpn_bbox: 0.1886  loss_cls: 0.4511  acc: 80.6641  loss_bbox: 0.5149
# 02/28 20:18:38 - mmengine - INFO - Epoch(train)  [64][200/236]  lr: 2.0000e-04  eta: 7:32:55  time: 0.8085  data_time: 0.0058  memory: 4872  loss: 1.3616  loss_rpn_cls: 0.2168  loss_rpn_bbox: 0.1890  loss_cls: 0.4453  acc: 81.5430  loss_bbox: 0.5106
# 02/28 20:18:57 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:18:57 - mmengine - INFO - Saving checkpoint at 64 epochs
# 02/28 20:19:08 - mmengine - INFO - Epoch(val)  [64][ 50/135]    eta: 0:00:15  time: 0.1826  data_time: 0.0025  memory: 5127
# 02/28 20:19:17 - mmengine - INFO - Epoch(val)  [64][100/135]    eta: 0:00:06  time: 0.1765  data_time: 0.0021  memory: 555
# 02/28 20:19:23 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.75s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.039
# 02/28 20:19:36 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.009 0.001 0.016 0.021
# 02/28 20:19:36 - mmengine - INFO - Epoch(val) [64][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0090  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0160  coco/bbox_mAP_l: 0.0210  data_time: 0.0022  time: 0.1799
# 02/28 20:20:23 - mmengine - INFO - Epoch(train)  [65][ 50/236]  lr: 2.0000e-04  eta: 7:31:12  time: 0.9342  data_time: 0.0065  memory: 5120  loss: 1.3430  loss_rpn_cls: 0.2121  loss_rpn_bbox: 0.1881  loss_cls: 0.4393  acc: 80.4688  loss_bbox: 0.5036
# 02/28 20:21:09 - mmengine - INFO - Epoch(train)  [65][100/236]  lr: 2.0000e-04  eta: 7:30:46  time: 0.9200  data_time: 0.0057  memory: 4878  loss: 1.3879  loss_rpn_cls: 0.2171  loss_rpn_bbox: 0.1913  loss_cls: 0.4533  acc: 81.5430  loss_bbox: 0.5262
# 02/28 20:21:54 - mmengine - INFO - Epoch(train)  [65][150/236]  lr: 2.0000e-04  eta: 7:30:14  time: 0.8948  data_time: 0.0046  memory: 5127  loss: 1.3193  loss_rpn_cls: 0.2035  loss_rpn_bbox: 0.1803  loss_cls: 0.4304  acc: 81.6406  loss_bbox: 0.5050
# 02/28 20:22:37 - mmengine - INFO - Epoch(train)  [65][200/236]  lr: 2.0000e-04  eta: 7:29:38  time: 0.8777  data_time: 0.0079  memory: 4878  loss: 1.3273  loss_rpn_cls: 0.2039  loss_rpn_bbox: 0.1851  loss_cls: 0.4253  acc: 79.9805  loss_bbox: 0.5130
# 02/28 20:22:54 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:22:54 - mmengine - INFO - Saving checkpoint at 65 epochs
# 02/28 20:23:04 - mmengine - INFO - Epoch(val)  [65][ 50/135]    eta: 0:00:15  time: 0.1800  data_time: 0.0027  memory: 3413
# 02/28 20:23:13 - mmengine - INFO - Epoch(val)  [65][100/135]    eta: 0:00:06  time: 0.1762  data_time: 0.0019  memory: 555
# 02/28 20:23:19 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.81s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
# 02/28 20:23:33 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.024 0.009 0.001 0.016 0.022
# 02/28 20:23:33 - mmengine - INFO - Epoch(val) [65][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0240  coco/bbox_mAP_75: 0.0090  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0160  coco/bbox_mAP_l: 0.0220  data_time: 0.0022  time: 0.1780
# 02/28 20:24:18 - mmengine - INFO - Epoch(train)  [66][ 50/236]  lr: 2.0000e-04  eta: 7:27:39  time: 0.9032  data_time: 0.0053  memory: 4878  loss: 1.3743  loss_rpn_cls: 0.2247  loss_rpn_bbox: 0.1954  loss_cls: 0.4464  acc: 81.5430  loss_bbox: 0.5078
# 02/28 20:25:02 - mmengine - INFO - Epoch(train)  [66][100/236]  lr: 2.0000e-04  eta: 7:27:06  time: 0.8887  data_time: 0.0048  memory: 5120  loss: 1.3377  loss_rpn_cls: 0.1981  loss_rpn_bbox: 0.1799  loss_cls: 0.4384  acc: 84.0820  loss_bbox: 0.5213
# 02/28 20:25:48 - mmengine - INFO - Epoch(train)  [66][150/236]  lr: 2.0000e-04  eta: 7:26:40  time: 0.9259  data_time: 0.0047  memory: 5120  loss: 1.3242  loss_rpn_cls: 0.2069  loss_rpn_bbox: 0.1812  loss_cls: 0.4317  acc: 79.4922  loss_bbox: 0.5045
# 02/28 20:26:32 - mmengine - INFO - Epoch(train)  [66][200/236]  lr: 2.0000e-04  eta: 7:26:02  time: 0.8667  data_time: 0.0048  memory: 4110  loss: 1.3074  loss_rpn_cls: 0.1933  loss_rpn_bbox: 0.1753  loss_cls: 0.4295  acc: 85.3516  loss_bbox: 0.5094
# 02/28 20:26:55 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:26:55 - mmengine - INFO - Saving checkpoint at 66 epochs
# 02/28 20:27:02 - mmengine - INFO - Epoch(val)  [66][ 50/135]    eta: 0:00:08  time: 0.0998  data_time: 0.0024  memory: 4871
# 02/28 20:27:09 - mmengine - INFO - Epoch(val)  [66][100/135]    eta: 0:00:04  time: 0.1542  data_time: 0.0020  memory: 555
# 02/28 20:27:16 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.69s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.042
# 02/28 20:27:29 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.025 0.010 0.001 0.017 0.022
# 02/28 20:27:29 - mmengine - INFO - Epoch(val) [66][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0250  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0010  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0220  data_time: 0.0022  time: 0.1410
# 02/28 20:28:16 - mmengine - INFO - Epoch(train)  [67][ 50/236]  lr: 2.0000e-04  eta: 7:24:38  time: 0.9305  data_time: 0.0061  memory: 4878  loss: 1.2920  loss_rpn_cls: 0.1933  loss_rpn_bbox: 0.1773  loss_cls: 0.4239  acc: 89.6484  loss_bbox: 0.4975
# 02/28 20:29:01 - mmengine - INFO - Epoch(train)  [67][100/236]  lr: 2.0000e-04  eta: 7:24:07  time: 0.9038  data_time: 0.0046  memory: 5128  loss: 1.3564  loss_rpn_cls: 0.2041  loss_rpn_bbox: 0.1880  loss_cls: 0.4467  acc: 82.4219  loss_bbox: 0.5176
# 02/28 20:29:46 - mmengine - INFO - Epoch(train)  [67][150/236]  lr: 2.0000e-04  eta: 7:23:35  time: 0.8999  data_time: 0.0052  memory: 5127  loss: 1.3690  loss_rpn_cls: 0.2133  loss_rpn_bbox: 0.1888  loss_cls: 0.4457  acc: 82.2266  loss_bbox: 0.5212
# 02/28 20:30:29 - mmengine - INFO - Epoch(train)  [67][200/236]  lr: 2.0000e-04  eta: 7:22:56  time: 0.8648  data_time: 0.0043  memory: 4871  loss: 1.3067  loss_rpn_cls: 0.2038  loss_rpn_bbox: 0.1805  loss_cls: 0.4254  acc: 87.5000  loss_bbox: 0.4970
# 02/28 20:30:56 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-lab_20240228_181254
# 02/28 20:30:56 - mmengine - INFO - Saving checkpoint at 67 epochs
# 02/28 20:31:03 - mmengine - INFO - Epoch(val)  [67][ 50/135]    eta: 0:00:08  time: 0.0994  data_time: 0.0023  memory: 4872
# 02/28 20:31:08 - mmengine - INFO - Epoch(val)  [67][100/135]    eta: 0:00:03  time: 0.0974  data_time: 0.0017  memory: 555
# 02/28 20:31:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=12.84s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.044
# 02/28 20:31:26 - mmengine - INFO - bbox_mAP_copypaste: 0.012 0.025 0.010 0.002 0.017 0.022
# 02/28 20:31:26 - mmengine - INFO - Epoch(val) [67][135/135]    coco/bbox_mAP: 0.0120  coco/bbox_mAP_50: 0.0250  coco/bbox_mAP_75: 0.0100  coco/bbox_mAP_s: 0.0020  coco/bbox_mAP_m: 0.0170  coco/bbox_mAP_l: 0.0220  data_time: 0.0020  time: 0.1059
# 02/28 20:31:26 - mmengine - INFO - the monitored metric did not improve in the last 20 records. best score: 0.025.

# %%
CONFIDENCE_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_folder}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

def callback(image: np.ndarray) -> sv.Detections:
    result = inference_detector(model, image)
    detections = sv.Detections.from_mmdetection(result)
    return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)


mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset = ds,
    callback = callback
)

print('mAP:', mean_average_precision.map50_95)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 CONFIDENCE_THRESHOLD = 0.5
#       2 NMS_IOU_THRESHOLD = 0.5
# ----> 4 ds = sv.DetectionDataset.from_coco(
#       5     images_directory_path=f"{dataset_location}/test",
#       6     annotations_path=f"{dataset_location}/test/_annotations.coco.json",
#       7 )
#       9 images = list(ds.images.values())
#      10 CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_folder}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
#
# NameError: name 'sv' is not defined

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{model_folder}/best_coco_bbox_mAP_50_epoch_*.pth")[-1]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)

# %%
print()
