# %%
# %run 1-0mmyolo-common.ipynb
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:08:53_PST_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0
# gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Sun Mar  3 18:33:05 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:3B:00.0 Off |                    0 |
# | N/A   42C    P0              27W /  70W |      2MiB / 15360MiB |      7%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# /work/van-speech-nlp/jindaznb/j-vis
# System Prefix: /work/van-speech-nlp/jenv
# HOME: /work/van-speech-nlp/jindaznb/j-vis
# 2.0.0+cu117 True
# 3.3.0
# 11.7
# GCC 9.3

# %% [markdown]
# # Write custom Config file

# %%
# %cd {HOME}/mmyolo
# %cd {HOME}/mmdetection
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection

# %%
model_folder="faster_rcnn"
base_model_name="faster-rcnn_r50_fpn_1x_coco"
custom_model_name=f"custom-{base_model_name}-cbam"
CUSTOM_CONFIG_PATH = f"{HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py"
print(CUSTOM_CONFIG_PATH)
MAX_EPOCHS=300


CUSTOM_CONFIG = f"""
_base_ = './{base_model_name}.py'

# model settings
model = dict(
    backbone=dict(
        type='ResNet_CBAM',
        depth=50,
        num_stages=4,
        out_indices=(0, 1, 2, 3),
        frozen_stages=1,
        norm_cfg=dict(type='BN', requires_grad=True),
        norm_eval=True,
        style='pytorch',
        init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50'),
        use_cbam=True),
    neck=dict(
        type='FPN',
        in_channels=[256, 512, 1024, 2048],
        out_channels=256,
        num_outs=5),
    )
    
dataset_type = 'COCODataset'
classes =  {classes}

data_root = '{dataset_location}' # Root directory of the dataset

train_ann_file = 'train/_annotations.coco.json'  # Annotation file for training set
train_data_prefix = 'train/'  # Prefix for training data directory

val_ann_file = 'valid/_annotations.coco.json'  # Annotation file for validation set
val_data_prefix = 'valid/'  # Prefix for validation data directory

class_name = {classes} 
num_classes = {num_classes}  # Number of classes in the dataset
metainfo = dict(classes=class_name, palette=[(20, 220, 60)])  # Metadata information for visualization

train_batch_size_per_gpu = {BATCH_SIZE}  # Batch size per GPU during training
#train_num_workers = 4  # Number of worker processes for data loading during training
persistent_workers = True  # Whether to use persistent workers during training

# -----train val related-----
# base_lr = 0.004  # Base learning rate for optimization
base_lr = 0.04
max_epochs = {MAX_EPOCHS}  # Maximum training epochs
num_epochs_stage2 = 20  # Number of epochs for stage 2 training

model_test_cfg = dict(
    multi_label=True,  # Multi-label configuration for multi-class prediction
    nms_pre=30000,  # Number of boxes before NMS
    score_thr=0.001,  # Score threshold to filter out boxes
    nms=dict(type='nms', iou_threshold=0.65),  # NMS type and threshold
    max_per_img=300)  # Maximum number of detections per image


# ========================Possible modified parameters========================
default_hooks = dict(
    checkpoint=dict(
        type="CheckpointHook",
        save_best="coco/bbox_mAP_50",
        rule="greater",
        max_keep_ckpts=10,
    ),
    early_stopping=dict(
        type="EarlyStoppingHook",
        monitor="coco/bbox_mAP_50",
        patience=15,
        min_delta=0.001
    ),
)

train_cfg=dict(
    max_epochs=max_epochs
)

data = dict(
    #samples_per_gpu=1,
    #workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        img_prefix='train/',
        classes=classes,
        ann_file='train/_annotations.coco.json.json'),
    val=dict(
        type=dataset_type,
        img_prefix='valid/',
        classes=classes,
        ann_file='valid/_annotations.coco.json'),
    test=dict(
        type=dataset_type,
        img_prefix='test/',
        classes=classes,
        ann_file='test/_annotations.coco.json'))

# -----data related-----
img_scale = (1024, 1024)  # width, height
# ratio range for random resize
random_resize_ratio_range = (0.1, 2.0)
# Cached images number in mosaic
mosaic_max_cached_images = 40
# Number of cached images in mixupep
mixup_max_cached_images = 20
# Batch size of a single GPU during validation
val_batch_size_per_gpu = 8
# Worker to pre-fetch data for each single GPU during validation
val_num_workers = 3

# Config of batch shapes. Only on val.
batch_shapes_cfg = dict(
    type='BatchShapePolicy',
    batch_size=val_batch_size_per_gpu,
    img_size=img_scale[0],
    size_divisor=32,
    extra_pad_ratio=0.5)

# -----train val related-----
lr_start_factor = 1.0e-5
dsl_topk = 13  # Number of bbox selected in each level
loss_cls_weight = 1.0
loss_bbox_weight = 2.0
qfl_beta = 2.0  # beta of QualityFocalLoss
weight_decay = 0.05

# Save model checkpoint and validation intervals
save_checkpoint_intervals = 10
# validation intervals in stage 2
val_interval_stage2 = 1
# The maximum checkpoints to keep.
max_keep_ckpts = 3
# single-scale training is recommended to
# be turned on, which can speed up training.
env_cfg = dict(cudnn_benchmark=True)
"""
with open(CUSTOM_CONFIG_PATH, 'w') as file:
    file.write(CUSTOM_CONFIG)
# Out:
# /work/van-speech-nlp/jindaznb/j-vis/mmdetection/configs/faster_rcnn/custom-faster-rcnn_r50_fpn_1x_coco-cbam.py

# %%
# !python tools/train.py {HOME}/mmdetection/configs/{model_folder}/{custom_model_name}.py --resume\
    | tee "../log/OUT_{base_model_name}_$(date +"%Y%m%d_%H%M%S").txt"
# Out:
# 03/03 18:33:38 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 313018247
#     GPU 0: Tesla T4
#     CUDA_HOME: /shared/centos7/cuda/11.2
#     NVCC: Cuda compilation tools, release 11.2, V11.2.67
#     GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.8.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 313018247
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/03 18:33:39 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.04
# batch_shapes_cfg = dict(
#     batch_size=8,
#     extra_pad_ratio=0.5,
#     img_size=1024,
#     size_divisor=32,
#     type='BatchShapePolicy')
# class_name = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# classes = (
#     'Alive Tree',
#     'Beetle-Fire Tree',
#     'Dead Tree',
#     'Debris',
# )
# data = dict(
#     test=dict(
#         ann_file='test/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='test/',
#         type='COCODataset'),
#     train=dict(
#         ann_file='train/_annotations.coco.json.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='train/',
#         type='COCODataset'),
#     val=dict(
#         ann_file='valid/_annotations.coco.json',
#         classes=(
#             'Alive Tree',
#             'Beetle-Fire Tree',
#             'Dead Tree',
#             'Debris',
#         ),
#         img_prefix='valid/',
#         type='COCODataset'))
# data_root = '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1'
# dataset_type = 'COCODataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=10,
#         rule='greater',
#         save_best='coco/bbox_mAP_50',
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.001,
#         monitor='coco/bbox_mAP_50',
#         patience=15,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dsl_topk = 13
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1, metric='bbox', save_best='bbox_mAP')
# img_scale = (
#     1024,
#     1024,
# )
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 2.0
# loss_cls_weight = 1.0
# lr_start_factor = 1e-05
# max_epochs = 300
# max_keep_ckpts = 3
# metainfo = dict(
#     classes=(
#         'Alive Tree',
#         'Beetle-Fire Tree',
#         'Dead Tree',
#         'Debris',
#     ),
#     palette=[
#         (
#             20,
#             220,
#             60,
#         ),
#     ])
# mixup_max_cached_images = 20
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet_CBAM',
#         use_cbam=True),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=80,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# mosaic_max_cached_images = 40
# num_classes = 4
# num_epochs_stage2 = 20
# optim_wrapper = dict(
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# persistent_workers = True
# qfl_beta = 2.0
# random_resize_ratio_range = (
#     0.1,
#     2.0,
# )
# resume = True
# save_checkpoint_intervals = 10
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_ann_file = 'train/_annotations.coco.json'
# train_batch_size_per_gpu = 8
# train_cfg = dict(max_epochs=300, type='EpochBasedTrainLoop', val_interval=1)
# train_data_prefix = 'train/'
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_ann_file = 'valid/_annotations.coco.json'
# val_batch_size_per_gpu = 8
# val_cfg = dict(type='ValLoop')
# val_data_prefix = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         backend_args=None,
#         data_prefix=dict(img='valid/'),
#         data_root='/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/',
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     '/work/van-speech-nlp/jindaznb/j-vis/Forestfire2024-1/valid/_annotations.coco.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# val_interval_stage2 = 1
# val_num_workers = 3
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# weight_decay = 0.05
# work_dir = './work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam'
#
# 03/03 18:33:43 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/03 18:33:43 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.47s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 03/03 18:33:45 - mmengine - INFO - load model from: torchvision://resnet50
# 03/03 18:33:45 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/zhang.jinda1/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 310MB/s]
# 03/03 18:33:46 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# missing keys in source state_dict: layer1.0.cbam.channel_attention.shared_mlp.1.weight, layer1.0.cbam.channel_attention.shared_mlp.1.bias, layer1.0.cbam.channel_attention.shared_mlp.3.weight, layer1.0.cbam.channel_attention.shared_mlp.3.bias, layer1.0.cbam.spatial_attention.spatial_attention.0.weight, layer1.0.cbam.spatial_attention.spatial_attention.1.weight, layer1.0.cbam.spatial_attention.spatial_attention.1.bias, layer1.0.cbam.spatial_attention.spatial_attention.1.running_mean, layer1.0.cbam.spatial_attention.spatial_attention.1.running_var, layer1.1.cbam.channel_attention.shared_mlp.1.weight, layer1.1.cbam.channel_attention.shared_mlp.1.bias, layer1.1.cbam.channel_attention.shared_mlp.3.weight, layer1.1.cbam.channel_attention.shared_mlp.3.bias, layer1.1.cbam.spatial_attention.spatial_attention.0.weight, layer1.1.cbam.spatial_attention.spatial_attention.1.weight, layer1.1.cbam.spatial_attention.spatial_attention.1.bias, layer1.1.cbam.spatial_attention.spatial_attention.1.running_mean, layer1.1.cbam.spatial_attention.spatial_attention.1.running_var, layer1.2.cbam.channel_attention.shared_mlp.1.weight, layer1.2.cbam.channel_attention.shared_mlp.1.bias, layer1.2.cbam.channel_attention.shared_mlp.3.weight, layer1.2.cbam.channel_attention.shared_mlp.3.bias, layer1.2.cbam.spatial_attention.spatial_attention.0.weight, layer1.2.cbam.spatial_attention.spatial_attention.1.weight, layer1.2.cbam.spatial_attention.spatial_attention.1.bias, layer1.2.cbam.spatial_attention.spatial_attention.1.running_mean, layer1.2.cbam.spatial_attention.spatial_attention.1.running_var, layer2.0.cbam.channel_attention.shared_mlp.1.weight, layer2.0.cbam.channel_attention.shared_mlp.1.bias, layer2.0.cbam.channel_attention.shared_mlp.3.weight, layer2.0.cbam.channel_attention.shared_mlp.3.bias, layer2.0.cbam.spatial_attention.spatial_attention.0.weight, layer2.0.cbam.spatial_attention.spatial_attention.1.weight, layer2.0.cbam.spatial_attention.spatial_attention.1.bias, layer2.0.cbam.spatial_attention.spatial_attention.1.running_mean, layer2.0.cbam.spatial_attention.spatial_attention.1.running_var, layer2.1.cbam.channel_attention.shared_mlp.1.weight, layer2.1.cbam.channel_attention.shared_mlp.1.bias, layer2.1.cbam.channel_attention.shared_mlp.3.weight, layer2.1.cbam.channel_attention.shared_mlp.3.bias, layer2.1.cbam.spatial_attention.spatial_attention.0.weight, layer2.1.cbam.spatial_attention.spatial_attention.1.weight, layer2.1.cbam.spatial_attention.spatial_attention.1.bias, layer2.1.cbam.spatial_attention.spatial_attention.1.running_mean, layer2.1.cbam.spatial_attention.spatial_attention.1.running_var, layer2.2.cbam.channel_attention.shared_mlp.1.weight, layer2.2.cbam.channel_attention.shared_mlp.1.bias, layer2.2.cbam.channel_attention.shared_mlp.3.weight, layer2.2.cbam.channel_attention.shared_mlp.3.bias, layer2.2.cbam.spatial_attention.spatial_attention.0.weight, layer2.2.cbam.spatial_attention.spatial_attention.1.weight, layer2.2.cbam.spatial_attention.spatial_attention.1.bias, layer2.2.cbam.spatial_attention.spatial_attention.1.running_mean, layer2.2.cbam.spatial_attention.spatial_attention.1.running_var, layer2.3.cbam.channel_attention.shared_mlp.1.weight, layer2.3.cbam.channel_attention.shared_mlp.1.bias, layer2.3.cbam.channel_attention.shared_mlp.3.weight, layer2.3.cbam.channel_attention.shared_mlp.3.bias, layer2.3.cbam.spatial_attention.spatial_attention.0.weight, layer2.3.cbam.spatial_attention.spatial_attention.1.weight, layer2.3.cbam.spatial_attention.spatial_attention.1.bias, layer2.3.cbam.spatial_attention.spatial_attention.1.running_mean, layer2.3.cbam.spatial_attention.spatial_attention.1.running_var, layer3.0.cbam.channel_attention.shared_mlp.1.weight, layer3.0.cbam.channel_attention.shared_mlp.1.bias, layer3.0.cbam.channel_attention.shared_mlp.3.weight, layer3.0.cbam.channel_attention.shared_mlp.3.bias, layer3.0.cbam.spatial_attention.spatial_attention.0.weight, layer3.0.cbam.spatial_attention.spatial_attention.1.weight, layer3.0.cbam.spat ...
#
# 03/03 18:33:46 - mmengine - INFO - Auto resumed from the latest checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/epoch_262.pth.
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/epoch_262.pth
# 03/03 18:33:46 - mmengine - INFO - Load checkpoint from /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/epoch_262.pth
# 03/03 18:33:47 - mmengine - INFO - resumed epoch: 262, iter: 61832
# 03/03 18:33:47 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/03 18:33:47 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 03/03 18:33:47 - mmengine - INFO - Checkpoints will be saved to /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam.
# 03/03 18:34:29 - mmengine - INFO - Epoch(train) [263][ 50/236]  lr: 2.0000e-04  eta: 2:06:34  time: 0.8516  data_time: 0.0115  memory: 11047  loss: 0.9298  loss_rpn_cls: 0.0996  loss_rpn_bbox: 0.1498  loss_cls: 0.2534  acc: 91.7969  loss_bbox: 0.4270
# 03/03 18:34:59 - mmengine - INFO - Epoch(train) [263][100/236]  lr: 2.0000e-04  eta: 1:46:47  time: 0.5934  data_time: 0.0046  memory: 4734  loss: 0.9138  loss_rpn_cls: 0.0857  loss_rpn_bbox: 0.1481  loss_cls: 0.2472  acc: 87.8906  loss_bbox: 0.4328
# 03/03 18:35:29 - mmengine - INFO - Epoch(train) [263][150/236]  lr: 2.0000e-04  eta: 1:40:13  time: 0.6010  data_time: 0.0042  memory: 5502  loss: 0.9428  loss_rpn_cls: 0.0971  loss_rpn_bbox: 0.1547  loss_cls: 0.2567  acc: 93.0664  loss_bbox: 0.4342
# 03/03 18:35:40 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:35:59 - mmengine - INFO - Epoch(train) [263][200/236]  lr: 2.0000e-04  eta: 1:36:42  time: 0.6010  data_time: 0.0043  memory: 5759  loss: 0.8872  loss_rpn_cls: 0.0924  loss_rpn_bbox: 0.1475  loss_cls: 0.2344  acc: 88.0859  loss_bbox: 0.4128
# 03/03 18:36:30 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:36:30 - mmengine - INFO - Saving checkpoint at 263 epochs
# 03/03 18:36:41 - mmengine - INFO - Epoch(val) [263][ 50/135]    eta: 0:00:15  time: 0.1877  data_time: 0.0054  memory: 10097
# 03/03 18:36:50 - mmengine - INFO - Epoch(val) [263][100/135]    eta: 0:00:06  time: 0.1820  data_time: 0.0018  memory: 573
# 03/03 18:36:57 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.32s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.083
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.145
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.368
# 03/03 18:37:12 - mmengine - INFO - bbox_mAP_copypaste: 0.083 0.170 0.072 0.026 0.145 0.210
# 03/03 18:37:12 - mmengine - INFO - Epoch(val) [263][135/135]    coco/bbox_mAP: 0.0830  coco/bbox_mAP_50: 0.1700  coco/bbox_mAP_75: 0.0720  coco/bbox_mAP_s: 0.0260  coco/bbox_mAP_m: 0.1450  coco/bbox_mAP_l: 0.2100  data_time: 0.0031  time: 0.1842
# 03/03 18:37:42 - mmengine - INFO - Epoch(train) [264][ 50/236]  lr: 2.0000e-04  eta: 1:38:02  time: 0.6062  data_time: 0.0050  memory: 5752  loss: 0.9299  loss_rpn_cls: 0.0986  loss_rpn_bbox: 0.1538  loss_cls: 0.2465  acc: 93.8477  loss_bbox: 0.4310
# 03/03 18:38:12 - mmengine - INFO - Epoch(train) [264][100/236]  lr: 2.0000e-04  eta: 1:35:56  time: 0.6063  data_time: 0.0047  memory: 5340  loss: 0.8530  loss_rpn_cls: 0.0822  loss_rpn_bbox: 0.1417  loss_cls: 0.2318  acc: 90.7227  loss_bbox: 0.3973
# 03/03 18:38:42 - mmengine - INFO - Epoch(train) [264][150/236]  lr: 2.0000e-04  eta: 1:34:15  time: 0.6059  data_time: 0.0048  memory: 5503  loss: 0.8591  loss_rpn_cls: 0.0899  loss_rpn_bbox: 0.1416  loss_cls: 0.2275  acc: 94.6289  loss_bbox: 0.4000
# 03/03 18:39:13 - mmengine - INFO - Epoch(train) [264][200/236]  lr: 2.0000e-04  eta: 1:32:51  time: 0.6068  data_time: 0.0046  memory: 5753  loss: 0.8884  loss_rpn_cls: 0.0902  loss_rpn_bbox: 0.1437  loss_cls: 0.2405  acc: 90.1367  loss_bbox: 0.4139
# 03/03 18:39:34 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:39:34 - mmengine - INFO - Saving checkpoint at 264 epochs
# 03/03 18:39:45 - mmengine - INFO - Epoch(val) [264][ 50/135]    eta: 0:00:15  time: 0.1854  data_time: 0.0028  memory: 4043
# 03/03 18:39:55 - mmengine - INFO - Epoch(val) [264][100/135]    eta: 0:00:06  time: 0.1834  data_time: 0.0019  memory: 576
# 03/03 18:40:01 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.99s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.365
# 03/03 18:40:16 - mmengine - INFO - bbox_mAP_copypaste: 0.084 0.171 0.072 0.027 0.148 0.209
# 03/03 18:40:16 - mmengine - INFO - Epoch(val) [264][135/135]    coco/bbox_mAP: 0.0840  coco/bbox_mAP_50: 0.1710  coco/bbox_mAP_75: 0.0720  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1480  coco/bbox_mAP_l: 0.2090  data_time: 0.0023  time: 0.1837
# 03/03 18:40:47 - mmengine - INFO - Epoch(train) [265][ 50/236]  lr: 2.0000e-04  eta: 1:30:41  time: 0.6029  data_time: 0.0051  memory: 5510  loss: 0.8906  loss_rpn_cls: 0.0879  loss_rpn_bbox: 0.1465  loss_cls: 0.2330  acc: 90.0391  loss_bbox: 0.4231
# 03/03 18:41:17 - mmengine - INFO - Epoch(train) [265][100/236]  lr: 2.0000e-04  eta: 1:29:38  time: 0.6023  data_time: 0.0044  memory: 4734  loss: 0.8728  loss_rpn_cls: 0.0865  loss_rpn_bbox: 0.1447  loss_cls: 0.2330  acc: 93.5547  loss_bbox: 0.4086
# 03/03 18:41:47 - mmengine - INFO - Epoch(train) [265][150/236]  lr: 2.0000e-04  eta: 1:28:40  time: 0.6017  data_time: 0.0045  memory: 5333  loss: 0.8919  loss_rpn_cls: 0.0905  loss_rpn_bbox: 0.1450  loss_cls: 0.2416  acc: 87.9883  loss_bbox: 0.4147
# 03/03 18:42:17 - mmengine - INFO - Epoch(train) [265][200/236]  lr: 2.0000e-04  eta: 1:27:47  time: 0.6028  data_time: 0.0047  memory: 5760  loss: 0.8718  loss_rpn_cls: 0.0859  loss_rpn_bbox: 0.1446  loss_cls: 0.2343  acc: 90.0000  loss_bbox: 0.4070
# 03/03 18:42:39 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:42:39 - mmengine - INFO - Saving checkpoint at 265 epochs
# 03/03 18:42:49 - mmengine - INFO - Epoch(val) [265][ 50/135]    eta: 0:00:15  time: 0.1826  data_time: 0.0028  memory: 5760
# 03/03 18:42:58 - mmengine - INFO - Epoch(val) [265][100/135]    eta: 0:00:06  time: 0.1831  data_time: 0.0020  memory: 576
# 03/03 18:43:05 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.90s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.084
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.362
# 03/03 18:43:20 - mmengine - INFO - bbox_mAP_copypaste: 0.084 0.171 0.072 0.026 0.149 0.210
# 03/03 18:43:20 - mmengine - INFO - Epoch(val) [265][135/135]    coco/bbox_mAP: 0.0840  coco/bbox_mAP_50: 0.1710  coco/bbox_mAP_75: 0.0720  coco/bbox_mAP_s: 0.0260  coco/bbox_mAP_m: 0.1490  coco/bbox_mAP_l: 0.2100  data_time: 0.0023  time: 0.1829
# 03/03 18:43:50 - mmengine - INFO - Epoch(train) [266][ 50/236]  lr: 2.0000e-04  eta: 1:26:19  time: 0.5995  data_time: 0.0050  memory: 5760  loss: 0.8760  loss_rpn_cls: 0.0842  loss_rpn_bbox: 0.1445  loss_cls: 0.2328  acc: 92.4805  loss_bbox: 0.4146
# 03/03 18:44:20 - mmengine - INFO - Epoch(train) [266][100/236]  lr: 2.0000e-04  eta: 1:25:30  time: 0.5959  data_time: 0.0044  memory: 5510  loss: 0.8654  loss_rpn_cls: 0.0840  loss_rpn_bbox: 0.1463  loss_cls: 0.2283  acc: 90.3320  loss_bbox: 0.4068
# 03/03 18:44:50 - mmengine - INFO - Epoch(train) [266][150/236]  lr: 2.0000e-04  eta: 1:24:44  time: 0.5988  data_time: 0.0044  memory: 5510  loss: 0.9168  loss_rpn_cls: 0.0977  loss_rpn_bbox: 0.1513  loss_cls: 0.2440  acc: 94.1406  loss_bbox: 0.4238
# 03/03 18:45:20 - mmengine - INFO - Epoch(train) [266][200/236]  lr: 2.0000e-04  eta: 1:24:00  time: 0.5994  data_time: 0.0045  memory: 4632  loss: 0.9036  loss_rpn_cls: 0.0939  loss_rpn_bbox: 0.1475  loss_cls: 0.2382  acc: 91.0156  loss_bbox: 0.4240
# 03/03 18:45:41 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:45:41 - mmengine - INFO - Saving checkpoint at 266 epochs
# 03/03 18:45:52 - mmengine - INFO - Epoch(val) [266][ 50/135]    eta: 0:00:15  time: 0.1832  data_time: 0.0029  memory: 5115
# 03/03 18:46:01 - mmengine - INFO - Epoch(val) [266][100/135]    eta: 0:00:06  time: 0.1820  data_time: 0.0019  memory: 576
# 03/03 18:46:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.93s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.072
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.357
# 03/03 18:46:23 - mmengine - INFO - bbox_mAP_copypaste: 0.086 0.177 0.072 0.027 0.152 0.214
# 03/03 18:46:23 - mmengine - INFO - Epoch(val) [266][135/135]    coco/bbox_mAP: 0.0860  coco/bbox_mAP_50: 0.1770  coco/bbox_mAP_75: 0.0720  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1520  coco/bbox_mAP_l: 0.2140  data_time: 0.0023  time: 0.1825
# 03/03 18:46:23 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/best_coco_bbox_mAP_50_epoch_247.pth is removed
# 03/03 18:46:24 - mmengine - INFO - The best checkpoint with 0.1770 coco/bbox_mAP_50 at 266 epoch is saved to best_coco_bbox_mAP_50_epoch_266.pth.
# 03/03 18:46:56 - mmengine - INFO - Epoch(train) [267][ 50/236]  lr: 2.0000e-04  eta: 1:22:46  time: 0.6029  data_time: 0.0051  memory: 5760  loss: 0.8913  loss_rpn_cls: 0.0878  loss_rpn_bbox: 0.1476  loss_cls: 0.2385  acc: 94.2383  loss_bbox: 0.4174
# 03/03 18:47:26 - mmengine - INFO - Epoch(train) [267][100/236]  lr: 2.0000e-04  eta: 1:22:04  time: 0.5937  data_time: 0.0045  memory: 4566  loss: 0.8693  loss_rpn_cls: 0.0793  loss_rpn_bbox: 0.1384  loss_cls: 0.2314  acc: 90.0391  loss_bbox: 0.4200
# 03/03 18:47:56 - mmengine - INFO - Epoch(train) [267][150/236]  lr: 2.0000e-04  eta: 1:21:24  time: 0.5970  data_time: 0.0044  memory: 5760  loss: 0.8868  loss_rpn_cls: 0.0903  loss_rpn_bbox: 0.1453  loss_cls: 0.2356  acc: 97.5586  loss_bbox: 0.4156
# 03/03 18:48:26 - mmengine - INFO - Epoch(train) [267][200/236]  lr: 2.0000e-04  eta: 1:20:46  time: 0.5988  data_time: 0.0044  memory: 5503  loss: 0.9132  loss_rpn_cls: 0.1013  loss_rpn_bbox: 0.1536  loss_cls: 0.2444  acc: 88.7695  loss_bbox: 0.4138
# 03/03 18:48:40 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:48:47 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:48:47 - mmengine - INFO - Saving checkpoint at 267 epochs
# 03/03 18:48:58 - mmengine - INFO - Epoch(val) [267][ 50/135]    eta: 0:00:15  time: 0.1828  data_time: 0.0028  memory: 4742
# 03/03 18:49:07 - mmengine - INFO - Epoch(val) [267][100/135]    eta: 0:00:06  time: 0.1833  data_time: 0.0019  memory: 576
# 03/03 18:49:14 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.67s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.371
# 03/03 18:49:29 - mmengine - INFO - bbox_mAP_copypaste: 0.086 0.175 0.074 0.025 0.150 0.221
# 03/03 18:49:29 - mmengine - INFO - Epoch(val) [267][135/135]    coco/bbox_mAP: 0.0860  coco/bbox_mAP_50: 0.1750  coco/bbox_mAP_75: 0.0740  coco/bbox_mAP_s: 0.0250  coco/bbox_mAP_m: 0.1500  coco/bbox_mAP_l: 0.2210  data_time: 0.0023  time: 0.1832
# 03/03 18:49:58 - mmengine - INFO - Epoch(train) [268][ 50/236]  lr: 2.0000e-04  eta: 1:19:39  time: 0.5955  data_time: 0.0051  memory: 5333  loss: 0.8384  loss_rpn_cls: 0.0771  loss_rpn_bbox: 0.1369  loss_cls: 0.2239  acc: 93.0664  loss_bbox: 0.4005
# 03/03 18:50:28 - mmengine - INFO - Epoch(train) [268][100/236]  lr: 2.0000e-04  eta: 1:19:01  time: 0.5959  data_time: 0.0044  memory: 5760  loss: 0.9015  loss_rpn_cls: 0.0876  loss_rpn_bbox: 0.1509  loss_cls: 0.2417  acc: 88.0859  loss_bbox: 0.4214
# 03/03 18:50:58 - mmengine - INFO - Epoch(train) [268][150/236]  lr: 2.0000e-04  eta: 1:18:27  time: 0.6036  data_time: 0.0105  memory: 5340  loss: 0.9258  loss_rpn_cls: 0.0956  loss_rpn_bbox: 0.1511  loss_cls: 0.2480  acc: 90.7227  loss_bbox: 0.4311
# 03/03 18:51:28 - mmengine - INFO - Epoch(train) [268][200/236]  lr: 2.0000e-04  eta: 1:17:51  time: 0.5986  data_time: 0.0045  memory: 5510  loss: 0.8878  loss_rpn_cls: 0.0928  loss_rpn_bbox: 0.1471  loss_cls: 0.2329  acc: 94.0430  loss_bbox: 0.4150
# 03/03 18:51:50 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:51:50 - mmengine - INFO - Saving checkpoint at 268 epochs
# 03/03 18:52:00 - mmengine - INFO - Epoch(val) [268][ 50/135]    eta: 0:00:15  time: 0.1832  data_time: 0.0028  memory: 5760
# 03/03 18:52:10 - mmengine - INFO - Epoch(val) [268][100/135]    eta: 0:00:06  time: 0.1833  data_time: 0.0020  memory: 576
# 03/03 18:52:16 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.09s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.148
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.380
# 03/03 18:52:32 - mmengine - INFO - bbox_mAP_copypaste: 0.088 0.180 0.073 0.028 0.148 0.224
# 03/03 18:52:32 - mmengine - INFO - Epoch(val) [268][135/135]    coco/bbox_mAP: 0.0880  coco/bbox_mAP_50: 0.1800  coco/bbox_mAP_75: 0.0730  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1480  coco/bbox_mAP_l: 0.2240  data_time: 0.0023  time: 0.1830
# 03/03 18:52:32 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/best_coco_bbox_mAP_50_epoch_266.pth is removed
# 03/03 18:52:33 - mmengine - INFO - The best checkpoint with 0.1800 coco/bbox_mAP_50 at 268 epoch is saved to best_coco_bbox_mAP_50_epoch_268.pth.
# 03/03 18:53:04 - mmengine - INFO - Epoch(train) [269][ 50/236]  lr: 2.0000e-04  eta: 1:16:49  time: 0.5980  data_time: 0.0058  memory: 5760  loss: 0.9004  loss_rpn_cls: 0.0924  loss_rpn_bbox: 0.1456  loss_cls: 0.2426  acc: 94.1406  loss_bbox: 0.4199
# 03/03 18:53:34 - mmengine - INFO - Epoch(train) [269][100/236]  lr: 2.0000e-04  eta: 1:16:15  time: 0.5985  data_time: 0.0047  memory: 5510  loss: 0.9060  loss_rpn_cls: 0.0942  loss_rpn_bbox: 0.1519  loss_cls: 0.2403  acc: 90.7227  loss_bbox: 0.4197
# 03/03 18:54:04 - mmengine - INFO - Epoch(train) [269][150/236]  lr: 2.0000e-04  eta: 1:15:39  time: 0.5946  data_time: 0.0045  memory: 5760  loss: 0.8412  loss_rpn_cls: 0.0766  loss_rpn_bbox: 0.1407  loss_cls: 0.2259  acc: 90.6250  loss_bbox: 0.3979
# 03/03 18:54:34 - mmengine - INFO - Epoch(train) [269][200/236]  lr: 2.0000e-04  eta: 1:15:05  time: 0.5959  data_time: 0.0046  memory: 4742  loss: 0.9075  loss_rpn_cls: 0.0927  loss_rpn_bbox: 0.1460  loss_cls: 0.2428  acc: 91.3086  loss_bbox: 0.4261
# 03/03 18:54:55 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:54:55 - mmengine - INFO - Saving checkpoint at 269 epochs
# 03/03 18:55:06 - mmengine - INFO - Epoch(val) [269][ 50/135]    eta: 0:00:15  time: 0.1859  data_time: 0.0031  memory: 5503
# 03/03 18:55:15 - mmengine - INFO - Epoch(val) [269][100/135]    eta: 0:00:06  time: 0.1828  data_time: 0.0020  memory: 576
# 03/03 18:55:22 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.03s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.086
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.130
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.367
# 03/03 18:55:37 - mmengine - INFO - bbox_mAP_copypaste: 0.086 0.173 0.076 0.027 0.150 0.219
# 03/03 18:55:37 - mmengine - INFO - Epoch(val) [269][135/135]    coco/bbox_mAP: 0.0860  coco/bbox_mAP_50: 0.1730  coco/bbox_mAP_75: 0.0760  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1500  coco/bbox_mAP_l: 0.2190  data_time: 0.0024  time: 0.1838
# 03/03 18:56:07 - mmengine - INFO - Epoch(train) [270][ 50/236]  lr: 2.0000e-04  eta: 1:14:05  time: 0.5953  data_time: 0.0052  memory: 4625  loss: 0.8749  loss_rpn_cls: 0.0851  loss_rpn_bbox: 0.1450  loss_cls: 0.2298  acc: 90.9180  loss_bbox: 0.4150
# 03/03 18:56:37 - mmengine - INFO - Epoch(train) [270][100/236]  lr: 2.0000e-04  eta: 1:13:30  time: 0.5934  data_time: 0.0044  memory: 5115  loss: 0.8507  loss_rpn_cls: 0.0732  loss_rpn_bbox: 0.1415  loss_cls: 0.2249  acc: 93.6523  loss_bbox: 0.4110
# 03/03 18:57:07 - mmengine - INFO - Epoch(train) [270][150/236]  lr: 2.0000e-04  eta: 1:12:57  time: 0.5978  data_time: 0.0046  memory: 5753  loss: 0.8713  loss_rpn_cls: 0.0875  loss_rpn_bbox: 0.1436  loss_cls: 0.2330  acc: 90.2344  loss_bbox: 0.4071
# 03/03 18:57:37 - mmengine - INFO - Epoch(train) [270][200/236]  lr: 2.0000e-04  eta: 1:12:25  time: 0.6004  data_time: 0.0047  memory: 5753  loss: 0.8762  loss_rpn_cls: 0.0954  loss_rpn_bbox: 0.1459  loss_cls: 0.2355  acc: 93.4570  loss_bbox: 0.3994
# 03/03 18:57:58 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 18:57:58 - mmengine - INFO - Saving checkpoint at 270 epochs
# 03/03 18:58:09 - mmengine - INFO - Epoch(val) [270][ 50/135]    eta: 0:00:15  time: 0.1859  data_time: 0.0029  memory: 5503
# 03/03 18:58:18 - mmengine - INFO - Epoch(val) [270][100/135]    eta: 0:00:06  time: 0.1824  data_time: 0.0020  memory: 576
# 03/03 18:58:25 - mmengine - INFO - Evaluating bbox...
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.383
# 03/03 20:15:09 - mmengine - INFO - bbox_mAP_copypaste: 0.087 0.177 0.075 0.027 0.149 0.231
# 03/03 20:15:09 - mmengine - INFO - Epoch(val) [295][135/135]    coco/bbox_mAP: 0.0870  coco/bbox_mAP_50: 0.1770  coco/bbox_mAP_75: 0.0750  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1490  coco/bbox_mAP_l: 0.2310  data_time: 0.0024  time: 0.1850
# 03/03 20:15:38 - mmengine - INFO - Epoch(train) [296][ 50/236]  lr: 2.0000e-04  eta: 0:11:17  time: 0.5951  data_time: 0.0065  memory: 5333  loss: 0.8005  loss_rpn_cls: 0.0705  loss_rpn_bbox: 0.1302  loss_cls: 0.2073  acc: 91.2109  loss_bbox: 0.3925
# 03/03 20:16:08 - mmengine - INFO - Epoch(train) [296][100/236]  lr: 2.0000e-04  eta: 0:10:47  time: 0.5974  data_time: 0.0047  memory: 5760  loss: 0.8044  loss_rpn_cls: 0.0745  loss_rpn_bbox: 0.1386  loss_cls: 0.2062  acc: 93.8477  loss_bbox: 0.3851
# 03/03 20:16:38 - mmengine - INFO - Epoch(train) [296][150/236]  lr: 2.0000e-04  eta: 0:10:17  time: 0.5994  data_time: 0.0047  memory: 5760  loss: 0.8392  loss_rpn_cls: 0.0777  loss_rpn_bbox: 0.1392  loss_cls: 0.2188  acc: 93.8247  loss_bbox: 0.4035
# 03/03 20:17:08 - mmengine - INFO - Epoch(train) [296][200/236]  lr: 2.0000e-04  eta: 0:09:47  time: 0.5972  data_time: 0.0047  memory: 5510  loss: 0.8159  loss_rpn_cls: 0.0737  loss_rpn_bbox: 0.1395  loss_cls: 0.2105  acc: 90.3320  loss_bbox: 0.3922
# 03/03 20:17:30 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:17:30 - mmengine - INFO - Saving checkpoint at 296 epochs
# 03/03 20:17:41 - mmengine - INFO - Epoch(val) [296][ 50/135]    eta: 0:00:15  time: 0.1846  data_time: 0.0029  memory: 5115
# 03/03 20:17:50 - mmengine - INFO - Epoch(val) [296][100/135]    eta: 0:00:06  time: 0.1847  data_time: 0.0019  memory: 576
# 03/03 20:17:57 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.99s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.185
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.156
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.388
# 03/03 20:18:12 - mmengine - INFO - bbox_mAP_copypaste: 0.091 0.185 0.079 0.028 0.156 0.232
# 03/03 20:18:12 - mmengine - INFO - Epoch(val) [296][135/135]    coco/bbox_mAP: 0.0910  coco/bbox_mAP_50: 0.1850  coco/bbox_mAP_75: 0.0790  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1560  coco/bbox_mAP_l: 0.2320  data_time: 0.0023  time: 0.1841
# 03/03 20:18:42 - mmengine - INFO - Epoch(train) [297][ 50/236]  lr: 2.0000e-04  eta: 0:08:56  time: 0.5931  data_time: 0.0058  memory: 4632  loss: 0.7642  loss_rpn_cls: 0.0615  loss_rpn_bbox: 0.1267  loss_cls: 0.1979  acc: 93.5547  loss_bbox: 0.3780
# 03/03 20:19:11 - mmengine - INFO - Epoch(train) [297][100/236]  lr: 2.0000e-04  eta: 0:08:26  time: 0.5956  data_time: 0.0044  memory: 4709  loss: 0.8421  loss_rpn_cls: 0.0870  loss_rpn_bbox: 0.1430  loss_cls: 0.2135  acc: 93.2617  loss_bbox: 0.3987
# 03/03 20:19:38 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:19:41 - mmengine - INFO - Epoch(train) [297][150/236]  lr: 2.0000e-04  eta: 0:07:56  time: 0.5992  data_time: 0.0046  memory: 5760  loss: 0.8340  loss_rpn_cls: 0.0790  loss_rpn_bbox: 0.1416  loss_cls: 0.2138  acc: 92.3828  loss_bbox: 0.3995
# 03/03 20:20:11 - mmengine - INFO - Epoch(train) [297][200/236]  lr: 2.0000e-04  eta: 0:07:26  time: 0.5985  data_time: 0.0045  memory: 5510  loss: 0.8171  loss_rpn_cls: 0.0745  loss_rpn_bbox: 0.1386  loss_cls: 0.2106  acc: 89.6484  loss_bbox: 0.3934
# 03/03 20:20:33 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:20:33 - mmengine - INFO - Saving checkpoint at 297 epochs
# 03/03 20:20:43 - mmengine - INFO - Epoch(val) [297][ 50/135]    eta: 0:00:15  time: 0.1847  data_time: 0.0029  memory: 5753
# 03/03 20:20:53 - mmengine - INFO - Epoch(val) [297][100/135]    eta: 0:00:06  time: 0.1831  data_time: 0.0020  memory: 576
# 03/03 20:20:59 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.68s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.089
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.077
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.384
# 03/03 20:21:14 - mmengine - INFO - bbox_mAP_copypaste: 0.089 0.180 0.077 0.027 0.155 0.226
# 03/03 20:21:14 - mmengine - INFO - Epoch(val) [297][135/135]    coco/bbox_mAP: 0.0890  coco/bbox_mAP_50: 0.1800  coco/bbox_mAP_75: 0.0770  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.1550  coco/bbox_mAP_l: 0.2260  data_time: 0.0023  time: 0.1834
# 03/03 20:21:44 - mmengine - INFO - Epoch(train) [298][ 50/236]  lr: 2.0000e-04  eta: 0:06:34  time: 0.6003  data_time: 0.0062  memory: 5510  loss: 0.7867  loss_rpn_cls: 0.0755  loss_rpn_bbox: 0.1332  loss_cls: 0.2008  acc: 90.1367  loss_bbox: 0.3772
# 03/03 20:22:14 - mmengine - INFO - Epoch(train) [298][100/236]  lr: 2.0000e-04  eta: 0:06:04  time: 0.5986  data_time: 0.0047  memory: 5510  loss: 0.8306  loss_rpn_cls: 0.0782  loss_rpn_bbox: 0.1392  loss_cls: 0.2133  acc: 88.3789  loss_bbox: 0.3999
# 03/03 20:22:44 - mmengine - INFO - Epoch(train) [298][150/236]  lr: 2.0000e-04  eta: 0:05:34  time: 0.5977  data_time: 0.0046  memory: 5753  loss: 0.8221  loss_rpn_cls: 0.0781  loss_rpn_bbox: 0.1434  loss_cls: 0.2095  acc: 96.6797  loss_bbox: 0.3912
# 03/03 20:23:14 - mmengine - INFO - Epoch(train) [298][200/236]  lr: 2.0000e-04  eta: 0:05:04  time: 0.5977  data_time: 0.0050  memory: 5115  loss: 0.8452  loss_rpn_cls: 0.0790  loss_rpn_bbox: 0.1440  loss_cls: 0.2140  acc: 90.1367  loss_bbox: 0.4082
# 03/03 20:23:35 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:23:35 - mmengine - INFO - Saving checkpoint at 298 epochs
# 03/03 20:23:46 - mmengine - INFO - Epoch(val) [298][ 50/135]    eta: 0:00:15  time: 0.1843  data_time: 0.0029  memory: 5753
# 03/03 20:23:55 - mmengine - INFO - Epoch(val) [298][100/135]    eta: 0:00:06  time: 0.1837  data_time: 0.0019  memory: 576
# 03/03 20:24:02 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.89s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.405
# 03/03 20:24:17 - mmengine - INFO - bbox_mAP_copypaste: 0.098 0.198 0.085 0.028 0.170 0.258
# 03/03 20:24:17 - mmengine - INFO - Epoch(val) [298][135/135]    coco/bbox_mAP: 0.0980  coco/bbox_mAP_50: 0.1980  coco/bbox_mAP_75: 0.0850  coco/bbox_mAP_s: 0.0280  coco/bbox_mAP_m: 0.1700  coco/bbox_mAP_l: 0.2580  data_time: 0.0023  time: 0.1838
# 03/03 20:24:17 - mmengine - INFO - The previous best checkpoint /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/best_coco_bbox_mAP_50_epoch_293.pth is removed
# 03/03 20:24:18 - mmengine - INFO - The best checkpoint with 0.1980 coco/bbox_mAP_50 at 298 epoch is saved to best_coco_bbox_mAP_50_epoch_298.pth.
# 03/03 20:24:50 - mmengine - INFO - Epoch(train) [299][ 50/236]  lr: 2.0000e-04  eta: 0:04:12  time: 0.5983  data_time: 0.0059  memory: 4702  loss: 0.8053  loss_rpn_cls: 0.0762  loss_rpn_bbox: 0.1357  loss_cls: 0.2065  acc: 94.0828  loss_bbox: 0.3870
# 03/03 20:25:20 - mmengine - INFO - Epoch(train) [299][100/236]  lr: 2.0000e-04  eta: 0:03:42  time: 0.5975  data_time: 0.0049  memory: 5760  loss: 0.8160  loss_rpn_cls: 0.0723  loss_rpn_bbox: 0.1391  loss_cls: 0.2120  acc: 90.6250  loss_bbox: 0.3927
# 03/03 20:25:50 - mmengine - INFO - Epoch(train) [299][150/236]  lr: 2.0000e-04  eta: 0:03:13  time: 0.6020  data_time: 0.0047  memory: 5753  loss: 0.8142  loss_rpn_cls: 0.0808  loss_rpn_bbox: 0.1411  loss_cls: 0.2113  acc: 92.5781  loss_bbox: 0.3810
# 03/03 20:26:20 - mmengine - INFO - Epoch(train) [299][200/236]  lr: 2.0000e-04  eta: 0:02:43  time: 0.5959  data_time: 0.0046  memory: 5115  loss: 0.8106  loss_rpn_cls: 0.0713  loss_rpn_bbox: 0.1347  loss_cls: 0.2060  acc: 90.6250  loss_bbox: 0.3985
# 03/03 20:26:41 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:26:41 - mmengine - INFO - Saving checkpoint at 299 epochs
# 03/03 20:26:52 - mmengine - INFO - Epoch(val) [299][ 50/135]    eta: 0:00:15  time: 0.1871  data_time: 0.0028  memory: 4632
# 03/03 20:27:01 - mmengine - INFO - Epoch(val) [299][100/135]    eta: 0:00:06  time: 0.1847  data_time: 0.0020  memory: 576
# 03/03 20:27:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=14.80s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.083
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.395
# 03/03 20:27:23 - mmengine - INFO - bbox_mAP_copypaste: 0.094 0.189 0.083 0.026 0.162 0.247
# 03/03 20:27:23 - mmengine - INFO - Epoch(val) [299][135/135]    coco/bbox_mAP: 0.0940  coco/bbox_mAP_50: 0.1890  coco/bbox_mAP_75: 0.0830  coco/bbox_mAP_s: 0.0260  coco/bbox_mAP_m: 0.1620  coco/bbox_mAP_l: 0.2470  data_time: 0.0023  time: 0.1855
# 03/03 20:27:53 - mmengine - INFO - Epoch(train) [300][ 50/236]  lr: 2.0000e-04  eta: 0:01:51  time: 0.6005  data_time: 0.0052  memory: 5753  loss: 0.8286  loss_rpn_cls: 0.0741  loss_rpn_bbox: 0.1410  loss_cls: 0.2160  acc: 95.5078  loss_bbox: 0.3975
# 03/03 20:28:23 - mmengine - INFO - Epoch(train) [300][100/236]  lr: 2.0000e-04  eta: 0:01:21  time: 0.5949  data_time: 0.0046  memory: 5333  loss: 0.7835  loss_rpn_cls: 0.0681  loss_rpn_bbox: 0.1341  loss_cls: 0.1996  acc: 93.4570  loss_bbox: 0.3817
# 03/03 20:28:53 - mmengine - INFO - Epoch(train) [300][150/236]  lr: 2.0000e-04  eta: 0:00:51  time: 0.5995  data_time: 0.0047  memory: 5510  loss: 0.8542  loss_rpn_cls: 0.0853  loss_rpn_bbox: 0.1481  loss_cls: 0.2214  acc: 91.6016  loss_bbox: 0.3994
# 03/03 20:29:22 - mmengine - INFO - Epoch(train) [300][200/236]  lr: 2.0000e-04  eta: 0:00:21  time: 0.5929  data_time: 0.0045  memory: 5510  loss: 0.7766  loss_rpn_cls: 0.0665  loss_rpn_bbox: 0.1290  loss_cls: 0.1980  acc: 92.4805  loss_bbox: 0.3832
# 03/03 20:29:44 - mmengine - INFO - Exp name: custom-faster-rcnn_r50_fpn_1x_coco-cbam_20240303_183334
# 03/03 20:29:44 - mmengine - INFO - Saving checkpoint at 300 epochs
# 03/03 20:29:55 - mmengine - INFO - Epoch(val) [300][ 50/135]    eta: 0:00:15  time: 0.1830  data_time: 0.0028  memory: 5760
# 03/03 20:30:04 - mmengine - INFO - Epoch(val) [300][100/135]    eta: 0:00:06  time: 0.1816  data_time: 0.0020  memory: 576
# 03/03 20:30:10 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=15.07s).
# Accumulating evaluation results...
# DONE (t=0.28s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.159
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.394
# 03/03 20:30:26 - mmengine - INFO - bbox_mAP_copypaste: 0.092 0.186 0.079 0.029 0.159 0.235
# 03/03 20:30:26 - mmengine - INFO - Epoch(val) [300][135/135]    coco/bbox_mAP: 0.0920  coco/bbox_mAP_50: 0.1860  coco/bbox_mAP_75: 0.0790  coco/bbox_mAP_s: 0.0290  coco/bbox_mAP_m: 0.1590  coco/bbox_mAP_l: 0.2350  data_time: 0.0023  time: 0.1824

# %%
CONFIDENCE_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{custom_model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[0]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

def callback(image: np.ndarray) -> sv.Detections:
    result = inference_detector(model, image)
    detections = sv.Detections.from_mmdetection(result)
    return detections[detections.confidence > CONFIDENCE_THRESHOLD].with_nms(threshold=NMS_IOU_THRESHOLD)


mean_average_precision = sv.MeanAveragePrecision.benchmark(
    dataset = ds,
    callback = callback
)

print('mAP:', mean_average_precision.map50_95)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/best_coco_bbox_mAP_50_epoch_298.pth
# mAP: 0.32640031258336616

# %%
ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset_location}/test",
    annotations_path=f"{dataset_location}/test/_annotations.coco.json",
)

images = list(ds.images.values())
CUSTOM_WEIGHTS_PATH = glob.glob(f"{HOME}/mmdetection/work_dirs/{custom_model_name}/best_coco_bbox_mAP_50_epoch_*.pth")[0]
model = init_detector(CUSTOM_CONFIG_PATH, CUSTOM_WEIGHTS_PATH, device=DEVICE)

best_map, best_params = optimize_params(ds, model, param_space)
print('Best mAP:', best_map)
print('Best Parameters:', best_params)
# Out:
# Loads checkpoint by local backend from path: /work/van-speech-nlp/jindaznb/j-vis/mmdetection/work_dirs/custom-faster-rcnn_r50_fpn_1x_coco-cbam/best_coco_bbox_mAP_50_epoch_298.pth
# |   iter    |  target   | confid... | nms_io... |
# -------------------------------------------------
# | 1         | 0.3219    | 0.4371    | 0.9556    |
# | 2         | 0.3502    | 0.7588    | 0.6388    |
# | 3         | 0.3366    | 0.2404    | 0.2404    |
# | 4         | 0.3097    | 0.1523    | 0.8796    |
# | 5         | 0.3367    | 0.641     | 0.7373    |
# | 6         | 0.3865    | 0.8994    | 0.3813    |
# | 7         | 0.0       | 1.0       | 0.1       |
# | 8         | 0.3576    | 0.7639    | 0.4472    |
# | 9         | 0.0       | 1.0       | 0.566     |
# | 10        | 0.3696    | 0.8055    | 0.3326    |
# | 11        | 0.3336    | 0.6025    | 0.551     |
# | 12        | 0.3262    | 0.4976    | 0.8419    |
# | 13        | 0.3439    | 0.4921    | 0.2995    |
# | 14        | 0.3836    | 0.8926    | 0.3936    |
# | 15        | 0.3145    | 0.2725    | 0.5231    |
# | 16        | 0.3865    | 0.8984    | 0.383     |
# | 17        | 0.3532    | 0.7733    | 1.0       |
# | 18        | 0.3484    | 0.4336    | 0.1       |
# | 19        | 0.0       | 1.0       | 1.0       |
# | 20        | 0.3374    | 0.1012    | 0.1013    |
# | 21        | 0.3349    | 0.6196    | 1.0       |
# | 22        | 0.3224    | 0.1       | 0.4007    |
# | 23        | 0.3626    | 0.8373    | 0.7127    |
# | 24        | 0.3078    | 0.1       | 0.6572    |
# | 25        | 0.3586    | 0.6294    | 0.1       |
# | 26        | 0.3499    | 0.7535    | 0.8464    |
# | 27        | 0.3177    | 0.3366    | 0.7264    |
# | 28        | 0.3543    | 0.645     | 0.2763    |
# | 29        | 0.3138    | 0.2583    | 1.0       |
# | 30        | 0.3263    | 0.4437    | 0.4715    |
# =================================================
# Best mAP: 0.38653258669753315
# Best Parameters: [0.898384540775208, 0.38299213942809107]

# %%
print()
